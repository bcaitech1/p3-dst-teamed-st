# %% [markdown]
# # TAPT-Pretraining
#
# ### 외부 데이터셋을 활용하여 나만의 conversationBERT를 만들어보세요 ! 🤗
#
# Pretrained BERT + 추가 데이터를 활용한 Pretraining
#
# * 본 코드는 Huggingface와 BERT 저자 코드를 기반으로 작성되었습니다

# %%
# !pip install transformers==4.5.1
# Out:
# Collecting transformers==4.5.1
#   Downloading transformers-4.5.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (0.0.45)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (2021.4.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (3.0.12)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 7.7 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (20.9)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (4.46.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (1.19.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from transformers==4.5.1) (4.0.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers==4.5.1) (7.1.2)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers==4.5.1) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers==4.5.1) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers==4.5.1) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers==4.5.1) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers==4.5.1) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers==4.5.1) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers==4.5.1) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers==4.5.1) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->transformers==4.5.1) (3.4.1)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.9.3
#     Uninstalling tokenizers-0.9.3:
#       Successfully uninstalled tokenizers-0.9.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 3.5.1
#     Uninstalling transformers-3.5.1:
#       Successfully uninstalled transformers-3.5.1
# Successfully installed tokenizers-0.10.2 transformers-4.5.1

# %%
import os
import time
import random
import pickle
import numpy as np
from tqdm import tqdm
from filelock import FileLock

import json
import pandas as pd
import numpy as np
from korean_preprocessor import *

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset

from transformers import BertTokenizer, BertConfig, BertForPreTraining
from transformers import DataCollatorForLanguageModeling
from transformers.utils import logging

from transformers import Trainer, TrainingArguments
from transformers import EarlyStoppingCallback # transformers 4.5.1에서 가능


logger = logging.get_logger(__name__)

# %%
# set seed 
# reference : https://hoya012.github.io/blog/reproducible_pytorch/
def set_seed(random_seed):
    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(random_seed)
    random.seed(random_seed)
    
set_seed(42)

# %% [markdown]
# ### ♻ Raw data preprocessing
# 1. tweeter_dialogue : xlsx
# 2. speech : trn
# 3. office_dialogue : json
# 4. KETI_dialogue : txt
#
# txt로 전처리

# %%
#띄어쓰기 검사
#!pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-s5sjiqew
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-s5sjiqew
# Collecting tensorflow==2.4.0
#   Downloading tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7 MB)
#      |████████████████████████████████| 394.7 MB 16 kB/s s eta 0:00:01    |█▌                              | 19.0 MB 17.4 MB/s eta 0:00:22     |█▉                              | 22.3 MB 17.4 MB/s eta 0:00:22     |██                              | 24.5 MB 17.4 MB/s eta 0:00:22     |██▎                             | 28.5 MB 17.4 MB/s eta 0:00:22     |██▍                             | 29.6 MB 17.4 MB/s eta 0:00:21     |██▌                             | 30.7 MB 20.5 MB/s eta 0:00:18     |███▋                            | 44.2 MB 20.5 MB/s eta 0:00:18     |█████                           | 63.0 MB 97.1 MB/s eta 0:00:04     |████████▍                       | 103.3 MB 17.6 MB/s eta 0:00:17     |█████████▊                      | 120.4 MB 17.6 MB/s eta 0:00:16     |██████████                      | 122.8 MB 27.5 MB/s eta 0:00:10     |██████████                      | 124.1 MB 27.5 MB/s eta 0:00:10     |██████████▎                     | 126.6 MB 27.5 MB/s eta 0:00:10     |█████████████                   | 159.5 MB 21.8 MB/s eta 0:00:11     |█████████████▎                  | 163.3 MB 21.8 MB/s eta 0:00:11     |█████████████▍                  | 164.7 MB 21.8 MB/s eta 0:00:11     |███████████████████████▍        | 287.8 MB 31.5 MB/s eta 0:00:04     |████████████████████████        | 296.3 MB 31.5 MB/s eta 0:00:04     |████████████████████████▌       | 302.7 MB 31.5 MB/s eta 0:00:03
# Collecting keras>=2.4.3
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 61.9 MB/s eta 0:00:01
# Collecting argparse>=1.4.0
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 53.3 MB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.9.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.15.8)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 59.3 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/conda/lib/python3.7/site-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.7.4.3)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 9.4 MB/s  eta 0:00:01
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 68.2 MB/s eta 0:00:01
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 54.2 MB/s eta 0:00:01
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 7.0 MB/s  eta 0:00:01
# Collecting wheel~=0.35
#   Downloading wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 35.5 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 436 kB/s  eta 0:00:01
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from keras>=2.4.3->pykospacing==0.4) (1.6.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras>=2.4.3->pykospacing==0.4) (5.3.1)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.30.0-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 41.3 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 53.3 MB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 1.1 MB/s  eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (46.4.0.post20200518)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 26.2 MB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 32.4 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (4.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.25.8)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 9.8 MB/s  eta 0:00:01
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.4.1)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 70.2 MB/s eta 0:00:01
# Building wheels for collected packages: pykospacing, wrapt, termcolor
#   Building wheel for pykospacing (setup.py) ... done
#   Created wheel for pykospacing: filename=pykospacing-0.4-py3-none-any.whl size=2255456 sha256=fbddc38e6051b24798bd352cbb6252b1915f7d46525192c33316267a8fd817e0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nmr27xfz/wheels/9b/93/81/a2a7dc8c66ede5bf30634d20635f32b95eac7ca2ea8844058b
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=70934 sha256=f13d614d6c3bd27dfd588d5c4b77e0265faab9ca40e85432040a387e094441bf
#   Stored in directory: /opt/ml/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=25eb9db0c110276876ed28af38c922fb3402c5040020f5dd738286d6a75f0e1d
#   Stored in directory: /opt/ml/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built pykospacing wrapt termcolor
# Installing collected packages: six, tensorflow-estimator, numpy, h5py, flatbuffers, wrapt, grpcio, google-pasta, wheel, astunparse, termcolor, absl-py, gast, pyasn1, pyasn1-modules, rsa, cachetools, google-auth, tensorboard-plugin-wit, markdown, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard-data-server, tensorboard, opt-einsum, keras-preprocessing, tensorflow, keras, argparse, pykospacing
#   Attempting uninstall: six
#     Found existing installation: six 1.14.0
#     Uninstalling six-1.14.0:
#       Successfully uninstalled six-1.14.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.34.2
#     Uninstalling wheel-0.34.2:
#       Successfully uninstalled wheel-0.34.2
# Successfully installed absl-py-0.12.0 argparse-1.4.0 astunparse-1.6.3 cachetools-4.2.2 flatbuffers-1.12 gast-0.3.3 google-auth-1.30.0 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 keras-2.4.3 keras-preprocessing-1.1.2 markdown-3.3.4 numpy-1.19.5 oauthlib-3.1.0 opt-einsum-3.3.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pykospacing-0.4 requests-oauthlib-1.3.0 rsa-4.7.2 six-1.15.0 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.0 tensorflow-estimator-2.4.0 termcolor-1.1.0 wheel-0.36.2 wrapt-1.12.1

# %%
#맞춤법 검사
#!pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# Collecting git+https://github.com/ssut/py-hanspell.git
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-3g5n5a1y
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-3g5n5a1y
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from py-hanspell==1.1) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->py-hanspell==1.1) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->py-hanspell==1.1) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->py-hanspell==1.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->py-hanspell==1.1) (2.9)
# Building wheels for collected packages: py-hanspell
#   Building wheel for py-hanspell (setup.py) ... done
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4853 sha256=79283f5035d9fd97653d2c2b110b27e88fa4ef76aacdc80b08f41ba21cf799bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pdq13hh4/wheels/ab/f5/7b/d4124bb329c905301baed80e2ae45aa14e824f62ebc3ec2cc4
# Successfully built py-hanspell
# Installing collected packages: py-hanspell
# Successfully installed py-hanspell-1.1

# %%
# `!pip install opnpyxl
url = '/opt/ml/input/data/bert_dataset/raw/'
file_name = ['tweeter_dialogue.xlsx', 'KETI_dialogue_daily.txt', 'KETI_dialogue_emergency.txt', 'output_ daily_1st.json', 'output_daily_2nd.json', 'output_daily_3rd.json', 'output_task.json', 'speech_dev.trn', 'speech_eval_clean.trn', 'speech_eval_other.trn', 'speech_train.trn']
for name in tqdm(file_name[1:3]):
    text = []
    #1. tweeter_dialogue
    if 'tweeter' in name:
        text = pd.read_excel(url + name, header=None)
    #2. KETI
    elif 'KETI' in name:
        with open(url + name, 'r') as texts:
            for t in texts:
                text.append(t)
    #3.output
    elif 'output' in name:
        with open(url + name, 'r') as t:
            json_text = json.load(t)
            print(len(json_text))
            for i in json_text:
                if i['user_utterance'] != "null":
                    text.append(i['user_utterance'])
                if i['system_utterance'] != "null":
                    text.append(i['system_utterance'])
    else:
        with open(url + name, 'r') as t:
            for i in t:
                #print(i, type(i))
                text.append(i.split('::')[1])
text = pd.DataFrame(text)
text
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 140.62it/s]
#                                                       0
# 0                                 ﻿1\t﻿아빠가 숨을 잘 못쉬어요.\n
# 1                                2\t그래요. 주소가 어떻게 되나요?\n
# 2                              3\t한남동 123번지 고마스빌딩이예요.\n
# 3                              4\t가슴에 통증이 있는지 물어봐줄래요?\n
# 4                             5\t있다고 해요. 이런경우는 처음이래요.\n
# ...                                                 ...
# 4970                                     2\t네 말씀하세요. \n
# 4971                        3\t버스 안에서 할머니 한분이 쓰러졌어요. \n
# 4972                               4\t지금 학생 상태가 어떤가요?\n
# 4973                5\t숨을 안쉬고 있어서 어떤 분이 CPR을 하고 계세요. \n
# 4974  6\t알겠습니다. 계속 진행해주시면서 기다려주세요. 그쪽으로 구급대원을 빠르게 보내...
#
# [4975 rows x 1 columns]

# %%
train_data_file = "/opt/ml/input/data/train_dataset/train_dials.json"
dev_data_file = "/opt/ml/input/data/eval_dataset/eval_dials.json"

def load_WOS(url):
    with open(url, 'r') as t:
        json_text = json.load(t)
        text = []
        for turn in json_text:
            for dialogue in turn['dialogue']:
                text.append(dialogue['text'])
    return text

text = load_WOS(dev_data_file) + load_WOS(train_data_file)
len(text)
# Out:
# 132032

# %%
a = delete_nan(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-eab1bfc05390> in <module>
# ----> 1 a = delete_nan(text)
#
# ~/code/korean_preprocessor.py in delete_nan(text)
#      10     text:str 를 input으로 받아 nan을 제거하여 return
#      11     '''
# ---> 12     text = text.fillna(0)
#      13     ret = [ele for value in text.values for ele in value if ele]
#      14     return ret
#
# AttributeError: 'list' object has no attribute 'fillna'

# %%
b = split_text(text)
b
# Out:
# ['안녕하세요.',
#  '적당한 가격대의 스파가 가능한 호텔을 찾아주세요.',
#  '안녕하세요.',
#  '원하시는 지역이 있으세요?',
#  '지역 상관없이 찾아주세요.',
#  '4곳이 검색되었습니다.',
#  '그중 평점이 가장 높은 행복 호텔을 추천드리는데 어떠세요?',
#  '좋아요.',
#  '화요일에 2일동안 4명 예약될까요?',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '예약해 주세요.',
#  '예약번호는 IDUJ3입니다.',
#  '같은 지역에 관광지도 있을까요?',
#  '선호하시는 관광 종류가 있으신가요?',
#  '종류는 상관없습니다.',
#  '8곳이 검색되었습니다.',
#  '역에서도 가까운 롯데월드 아쿠아리움을 추천드리는데 어떠세요?',
#  '좋네요.',
#  '그곳의 입장 비용은 얼마인가요?',
#  '4000원입니다.',
#  '궁금증이 다 해결되셨나요?',
#  '네 감사합니다.',
#  '네 감사합니다.',
#  '즐거운 하루 보내세요.',
#  '친구들이랑 갈 일식당 예약 좀 할게요.',
#  '서울 중앙쪽에 가격은 상관없으니까 맛있는 곳으로 부탁드려요.',
#  '안녕하세요?',
#  '규동이 대표 메뉴로 평가도 좋은 곳입니다.',
#  '네 예약할게요.',
#  '월요일 12시 34분에 10명이거든요.',
#  '가능한가요?',
#  '원하시는대로 예약되셨습니다.',
#  '더 필요한 건 없으세요?',
#  '인터넷되고 비싼 호텔로 찾아주세요.',
#  '죄송하지만 식당에 주차는 불가로 확인됩니다.',
#  '그 중 명동역에서 가깝고 평점도 높은 프리미어 호텔은 어떠세요?',
#  '네 거기로 할게요.',
#  '식당 예약한 날부터 4일이구요.',
#  '인원도 같은데 예약되나요?',
#  '네 가능합니다.',
#  '말씀주신대로 진행해드렸습니다.',
#  '질문 있으세요?',
#  '아 걸어서 갈 수 있는지랑 흡연 가능한지도 확인 부탁드려요.',
#  '네 도보 가능합니다.',
#  '흡연은 불가로 확인되네요.',
#  '알겠습니다.',
#  '그 담에 서울 북쪽에 아무거나 문화와 예술관련해서 괜찮은 곳 좀 찾아주세요.',
#  '안국역쪽의 국립현대미술관 서울관 확인됩니다.',
#  '네 좋아요.',
#  '여긴 주차 여부랑 평점 좀 알려주세요.',
#  '평점은 4.',
#  '5점입니다.',
#  '더 궁금한 점 있으세요?',
#  '아 이제 없네요.',
#  '수고하세요.',
#  '감사합니다.',
#  '즐거운 시간 되세요.',
#  '식당 예약 좀 도와주실 수 있나요?',
#  '그럼요.',
#  '어떻게 예약 도와드리면 될까요?',
#  '먼저 역사랑 관련되어 있는 랜드마크 좀 찾아봐 주실 수 있나요?',
#  '지역은 어디로 찾아봐드리면 될까요?',
#  '지역은 서울 내면 어디든 괜찮습니다.',
#  '이쪽으로 가보시는 건 어떠신가요?',
#  '그래요?',
#  '평점이 높으면 그만큼 볼 게 많겠죠?',
#  '거기 주소랑 영업시간 좀 알려주실래요?',
#  '잠시만요.',
#  '운영은 아침 9시 반부터 오후 5시 30분까지입니다.',
#  '아 혹시 거기 주변 경관은 좀 어때요?',
#  '좋은 편이에요?',
#  '음 아무래도 주변에 건물들도 있고 해서 경치가 좋다고 말씀드리기는 어려울 것 같습니다.',
#  '또 궁금하신 점 있으실까요?',
#  '아까 말씀드렸던 것처럼 숙소도 예약을 해야 되는데 그 서울중앙성원과 가까운 곳에 게스트하우스 괜찮은 곳 있을까요?',
#  '서울중앙성원과 가까운 곳이라면 서울 중앙 쪽을 말씀하시는 거죠?',
#  '이쪽으로 알아봐드리면 될까요?',
#  '그쪽으로요.',
#  '가격대는 어느 정도로 책정해두셨는지 여쭤봐도 될까요?',
#  '정해두신 범위가 있으실까요?',
#  '어.',
#  '그런 건 딱히 없어요.',
#  '동키 게스트 하우스와 서촌 한옥 게스트하우스가 있네요.',
#  '평점은 서촌 쪽이 더 높은데 이쪽으로 예약해보시겠어요?',
#  '거기로 갈게요.',
#  '한옥이면 더 좋죠.',
#  '그 목요일부터 5일 간 묵을 거고 인원은 2명으로 해주시면 되세요.',
#  '인원 2명으로 해서 게스트하우스 예약해드렸습니다.',
#  '더 필요하신 것 있으시면 편하게 말씀해주세요.',
#  '그러면 마지막으로 식당 예약 좀 도와주세요.',
#  '그 숙소랑 가까워야 돼서 그 서울 중앙 쪽에 한식당으로 가고 싶은데요.',
#  '음식 가격은 어느 정도인 것이 좋으실까요?',
#  '아 가능하면 야외석이 있으면 더 좋구요.',
#  '혹시 괜찮으시다면 서울 남쪽으로 한번 찾아봐드려도 괜찮으실까요?',
#  '그래요?',
#  '음.',
#  '어쩔 수 없죠.',
#  '서울 남쪽 지역엔 있나 봐주세요.',
#  '이쪽으로 예약 도와드려도 괜찮으실까요?',
#  '좋아요.',
#  '목요일 오후 4시 45분에 2명으로 예약해주실 수 있어요?',
#  '두유노코리안으로 예약 도와드렸습니다.',
#  'GPWA1이니까 미리 확인하시고 식당 이용하시면 될 것 같습니다.',
#  '고마워요.',
#  '그 한 가지 좀 궁금한 게 있는데 거기 주차 되나요?',
#  '아 주차는 어려우실 것 같아요.',
#  '따로 주차장이 없는 것 같습니다.',
#  '아 그래요.',
#  '그러면 택시 타고 가게 주소 좀 불러주실래요?',
#  '서울 강남구 05699입니다.',
#  '또 문의해주실 사항 있으신가요?',
#  '이제 더 없는 거 같네요.',
#  '번거롭게 해드려서 죄송해요.',
#  '아닙니다.',
#  '오늘도 행복한 하루 보내시길 바랍니다.',
#  '어떤 도움이 필요하세요?',
#  '필요하신 정보가 어떻게 되세요?',
#  '서울 어린이 대공원은 어느 지역에 있어여?',
#  '30 입니다.',
#  '거기 역사적인곳이져?',
#  '서울 어린이 대공원은 역사적인 곳이라고 볼 수는 없습니다.',
#  '아 그렇군여.',
#  '다른 도움 필요하신건 없으세요?',
#  '네 감사합니다.',
#  '온김에 여기저기 가보려구요.',
#  '일단 이쪽에 적당한 가격의 맛난 일식당이 있을까요?',
#  '제가 뚜벅이라 걸어서 갈 수 있어야 되구요.',
#  '안녕하세요?',
#  '시청역의 라멘 맛집 회오리라멘 어떠실까요?',
#  '역에서 도보 3분 거리로 가깝습니다.',
#  '네 가깝고 좋네요.',
#  '흡연석은 있을까요?',
#  '흡연석은 따로 없는 걸로 확인됩니다.',
#  '아 네 확인 감사해요.',
#  '글구 식당 가까이에 기타 타입의 관광지가 있을까요?',
#  '역시 걸어서 갈 수 있어야 되구요.',
#  '충무로역에서 도보 2분이면 도착하는 한국의 집은 어떠실까요?',
#  '입장료도 2천원으로 저렴한 편입니다.',
#  '네 괜찮겠네요.',
#  '그럼 경치가 좋은 곳은 아니겠네요?',
#  '네 맞습니다.',
#  '더 필요하신 거 있으세요?',
#  '네 마지막으로 지하철 정보만 좀 찾을게요.',
#  '요금이랑 도착지 라인이 어떻게 되는지도 좀 알려주세요.',
#  '도착지 라인은 6호선입니다.',
#  '더 확인하실 부분 있으실까요?',
#  '아아 다 됐습니다.',
#  '감사합니다.',
#  '네 이용 감사합니다.',
#  '제가 비싼 한식당을 찾고 있는데요.',
#  '원하시는 지역이 있을까요?',
#  '서울 내에 있으면 되요.',
#  '아 주차는 가능해야해요.',
#  '네.',
#  '4곳이 검색되는데 다른 조건은 없을까요?',
#  '뭐.',
#  '없는데.',
#  '추천해주시겠어요?',
#  '그럼 제가 추천해드리겠습니다.',
#  '평점 4.',
#  '3점에 압구정역 근처에 있는 식객이라는 한식당을 추천드립니다.',
#  '네 좋네요.',
#  '그럼 화요일 07시50분에 5명 예약 가능할까요?',
#  '네 가능합니다.',
#  '진행할까요?',
#  '네 예약 해주시고 예약 번호와 라스트 오더 시간도 알려주세요.',
#  '예약되셨습니다.',
#  '이고 라스트 오더 시간은 22시입니다.',
#  '감사합니다.',
#  '이용해 주셔서 감사합니다.',
#  '무엇을 도와드릴까요?',
#  '생각하신 가격대와 지역이 있으신가요?',
#  '아뇨.',
#  '서울 중구에 위치한 친구를 만나느라 샵샵샵이 있습니다.',
#  '어떠신가요?',
#  '금요일 16시20분에 4명 예약해주시겠어요?',
#  '예약 완료되셨습니다.',
#  '입니다.',
#  '궁금하신점 있으신가요?',
#  '영업시간은 몇시인가요?',
#  '네.',
#  '00입니다.',
#  '더 필요하신점 있으신가요?',
#  '서울 서쪽에 위치한 곳으로요.',
#  '선호하시는 숙소종류가 있으신가요?',
#  '아뇨 괜찮습니다.',
#  '네.',
#  '진하우스라는 에어비엔비가 있습니다.',
#  '어떠신가요?',
#  '죄송합니다.',
#  '5일까지는 예약이 잡이지 않아 기간을 변경해야 할것 같은데 어떻게 해드릴까요?',
#  '음.',
#  '일요일 3명 하루 예약 완료되었습니다.',
#  '입니다.',
#  '궁금하신 사항 있으신가요?',
#  '거기 수영장은 있나요?',
#  '아쉽게도 진하우스에는 수영장을 운영하지 않습니다.',
#  '주소는 서울 마포구 10506 입니다.',
#  '더 궁금하신 점 있으신가요?',
#  '아뇨.',
#  '없어요.',
#  '감사합니다.',
#  '이용해주셔서 감사합니다.',
#  '식당이랑 관광할 곳을 알아보려고 하거든요.',
#  '안녕하세요?',
#  '지역을 말씀해주시면 찾아드리겠습니다.',
#  '가격은 상관없고요.',
#  '인터넷을 계속 써야 되서 인터넷 되는 곳으로 좀 찾아주세요.',
#  '신촌역 부근의 피에르 오뎅 확인됩니다.',
#  '예약해드릴까요?',
#  '아 그럼 일요일 10시 10분에 2명으로 부탁드릴게요.',
#  '식당 주소랑 도보가 가능한지도 궁금하네요.',
#  '도보도 가능합니다.',
#  '관광지는 어떤 곳으로 찾으실까요?',
#  '아 네 식당 가까이에 쇼핑할 곳으로 찾는데요.',
#  '신도림역의 디큐브시브는 어떠세요?',
#  '역에서 도보 2분 거리로 가깝고 입장료는 9000원입니다.',
#  '아 괜찮네요.',
#  '마지막으로 디큐브시브 거기서 15시 30분에 출발가능한 택시도 좀 부탁드릴게요.',
#  '택시 종류도 말씀 부탁드립니다.',
#  '일단 그렇게만 결정한거라 일단 다른 조건은 안 넣고 찾아주시겠어요?',
#  '네 알겠습니다.',
#  '택시 조회되네요.',
#  '요금은 5천원입니다.',
#  '확인이 다 되셨을까요?',
#  '아 네 물어볼걸 다 말씀해주셨네요.',
#  '감사합니다.',
#  '네 이용 감사합니다.',
#  '저 디큐브시브에 가려는데 궁금한게 있어요.',
#  '네 어떤게 궁금하신가요?',
#  '평점이랑 그 곳 경치가 좋은지요.',
#  '먼저 평점은 4점입니다.',
#  '그리고 경치는 좋지 않다고 쓰여있습니다.',
#  '아 그래요?',
#  '그래도 뭐 가긴 갈꺼라서.',
#  '영업시간 좀 알려주세요.',
#  '디큐브시브의 영업시간은 09시30분 부터 17시 30분까지 입니다.',
#  '네 감사합니다.',
#  '더 궁금하신 사항 있으신가요?',
#  '아뇨 없습니다.',
#  '네.',
#  '감사합니다.',
#  '안녕하세요.',
#  '흡연 가능한 곳으로 찾아주세요.',
#  '안녕하세요.',
#  '생각하시는 금액대가 있으신가요?',
#  '정모텔이있습니다.',
#  '사당역에서 도보 7분입니다.',
#  '어떠세요?',
#  '좋아요 수요일 4일간 10명 예약되나요?',
#  '수요일은 이용불가합니다.',
#  '다른 요일을 말해주세요.',
#  '월요일도 괜찮습니다.',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '예약해 주세요.',
#  '예약 번호는 AMWN4입니다.',
#  '더 궁금한 점이 있으세요?',
#  '없습니다.',
#  '네 감사합니다.',
#  '처음으로 서울에 놀러왔는데 무작정 온거라 숙소를 예약 못해서요.',
#  '도와주시겠어요?',
#  '안녕하세요.',
#  '가격대를 말씀해주시면 안내해드리겠습니다.',
#  '제가 지금 서울 서쪽에 있어서 이 쪽에 있는 숙소였으면 합니다.',
#  '가격은 저렴한 곳으로 조식 제공되면 종류는 뭐든 괜찮아요.',
#  '그럼 마포구에 심미 호스텔이 조식 제공되는 곳인데 괜찮으실까요?',
#  '근데 제가 이동하기 쉽게 지하철역 근처에 있는 곳이었으면 하는데 역 근처에 있나요?',
#  '네.',
#  '월드컵경기역에서 도보 3분 거리에 있습니다.',
#  '와 가깝네요.',
#  '그럼 오늘부터 7일간 머무를건데 예약해주세요.',
#  '저 혼자입니다.',
#  '예약 진행해드렸습니다.',
#  '예약 번호는 GNVM0입니다.',
#  '더 필요한건 없으세요?',
#  '서울 관광 좀 하다가 9시 40분쯤 숙소로 가려고 하는데 택시도 알아봐주시겠어요?',
#  '출발하시는 곳과 도착 시간을 말씀해주시면 안내해드리겠습니다.',
#  '제가 계속 이동 중이고 여기 뭐가 있는지 잘 몰라서 어디서 출발해야할지 모르겠어요.',
#  '9시 40분에 출발하는 택시가 있으면 그쪽으로 제가 이동하겠습니다.',
#  '원하시는 택시 종류는 따로 있으세요?',
#  '아니요.',
#  '종류 상관없습니다.',
#  '그럼 9시 40분에 예술의전당에서 출발하는 고급 택시가 있는데 이 택시를 이용하시면 될 것 같습니다.',
#  '소요 시간 45분으로 심미 호스텔에 10시 25분쯤 도착하실거예요.',
#  '기사님 전화번호는 06379810254 이니 출발지에서 기사님께 연락하시면 됩니다.',
#  '그렇게 하도록 할게요.',
#  '감사합니다.',
#  '제가 더 도와드릴건 없나요?',
#  '네.',
#  '이제 괜찮습니다.',
#  '알겠습니다.',
#  '문의하실게 있으시면 언제든 다시 연락 주세요.',
#  '이용해 주셔서 감사합니다.',
#  '안녕하세요.',
#  '서울 북쪽에 있는 저렴한 가격대의 호스텔을 알아봐주세요.',
#  '동문 호스텔 이라는 곳 어떠세요?',
#  '평점은 4.',
#  '1 입니다.',
#  '좋아요.',
#  '금요일부터 3일동안 2명이 머무를 예정이에요.',
#  '예약 해주세요.',
#  '예약이 되었습니다.',
#  '예약 번호는 FBOI4 입니다.',
#  '네 감사해요.',
#  '그리고 경복궁의 입장료랑 영업 시간 그리고 주소도 알아봐주세요.',
#  '입장료는 9000원 입니다.',
#  '00 로 나오네요.',
#  '주소는 서울 종로구 05481 입니다.',
#  '네.',
#  '전화 번호도 알려주세요.',
#  '전화번호는 108270327 입니다.',
#  '다른 궁금하신 사항이 더 있으세요?',
#  '하나만 더 부탁드려요.',
#  '서울 중앙에 있는 저렴한 한식당 중에서 괜찮은 곳 알아봐주세요.',
#  '돼지조아소조아 라는 식당 어떠세요?',
#  '찾아보니 좋네요.',
#  '숙소를 예약한 날에 15시로 3명 예약 해주세요.',
#  '아 그런데 주차가 가능한 식당인가요?',
#  '예약 번호는 ACKW6 입니다.',
#  '주차가 가능한 식당입니다.',
#  '다른 궁금하신 사항이 더 있으세요?',
#  '그렇군요.',
#  '감사합니다.',
#  '덕분에 편하게 알아봤네요.',
#  '다음에 또 이용할께요.',
#  '감사합니다.',
#  '안녕하세요.',
#  '정모텔이라는 이름의 숙소 주소랑 전화번호를 알고 싶어서 문의드려요.',
#  '안녕하세요.',
#  '전화번호는 7269223521입니다.',
#  '네 감사합니다.',
#  '또 하나 더 있는데요.',
#  '서울 중앙에 랜드마크가 있나요?',
#  '서울 중앙에는 남산골 한옥 마을이 대표적인 랜드마크 입니다.',
#  '거긴 역에서 얼마나 걸려요?',
#  '지하철 충무로역에서 도보로 3분정도 소요됩니다.',
#  '그렇군요.',
#  '정보 감사합니다.',
#  '다른 궁금하신 점 있으세요?',
#  '다른건 없습니다.',
#  '알겠습니다.',
#  '감사합니다.',
#  '관광지 좀 찾고싶은데요.',
#  '안녕하세요?',
#  '숙소부터 도와드릴게요.',
#  '지역을 말씀해주시면 됩니다.',
#  '아 네 서울 북쪽에 가격은 적당한 데로 게스트 하우스면 괜찮아요.',
#  '죄송하지만 가격대 변경을 하셔야 할 거 같습니다.',
#  '조회가 안되네요.',
#  '그래요 그면 저렴한 데는 있어요?',
#  '네 저렴한 곳은 확인됩니다.',
#  '명동역 부근의 인터넷 제공되는 호두나무집인데요.',
#  '예약하시겠어요?',
#  '네 할게요.',
#  '일요일부터 이틀 있으려구요.',
#  '예약완료되셨습니다.',
#  '궁금한 점 있으세요?',
#  '아니요.',
#  '식당도 찾아주세요.',
#  '네 확인됩니다.',
#  '예약해드릴까요?',
#  '네 좋아요.',
#  '같은 날 같은 인원이구요.',
#  '14시 10분으로 해주세요.',
#  '네 원하시는대로 예약되셨습니다.',
#  '관광지는 어떤 곳으로 찾으시나요?',
#  '아 서울 중앙쪽에 공원으로요.',
#  '있나요?',
#  '네 확인됩니다.',
#  '여의나루역에서 도보 2분 거리의 여의도 한강공원입니다.',
#  '어떠신가요?',
#  '좋아요.',
#  '도보는 가능한거고.',
#  '문화 예술이랑 관련있나요?',
#  '문화 예술과는 관련이 없는 곳입니다.',
#  '이제 없어요.',
#  '감사합니다.',
#  '즐거운 여행 되세요.',
#  '친구들이랑 서울 남쪽에 있는 주점을 가볼까 해요.',
#  '괜찮은곳으로 예약 좀 부탁드릴게요.',
#  '안녕하세요.',
#  '가격대는 어느정도로 생각하세요?',
#  '애들이랑 나눠서 낼꺼라 가격 상관없이 알아봐주세요.',
#  '그럼 적당한 가격대의 이기자카야를 추천해 드립니다.',
#  '평점 4.',
#  '3으로 남쪽에서 꽤 유명한 주점입니다.',
#  '오 그래요?',
#  '그럼 토요일 4시20분에 9명으로 예약할게요.',
#  '워낙 유명한 곳이다보니 토요일은 이미 예약이 마감된 것으로 확인되는데 다른 요일도 괜찮으세요?',
#  '우와 역시.',
#  '그럼 일요일은 가능할까요?',
#  '네.',
#  '일요일은 가능합니다.',
#  '일요일 4시20분으로 진행해 드릴까요?',
#  '그렇게 해주세요.',
#  '네.',
#  '알려주신 정보대로 예약 해 드렸습니다.',
#  '관련해서 필요하신 사항 있으실까요?',
#  '음.',
#  '찾아가야되니까 주소도 알려주세요.',
#  '예약번호는 VHRD4이고 주소는 서울 서초구 46141입니다.',
#  '감사합니다.',
#  '그리고 이번에는 중앙쪽에서 괜찮은 게스트 하우스도 찾아봐 주세요.',
#  '숙소의 가격대는 어떻게 알아봐드릴까요?',
#  '숙소도 가격대는 상관없이 알아봐 주시고 애들이랑 게임하는게 큰 목적이라 원할하게 인터넷 이용이 가능한 곳으로 부탁드려요.',
#  '말씀하신 조건으로는 동키 게스트 하우스와 서촌 한옥 게스트하우스가 괜찮아 보입니다.',
#  '둘 다 저렴한 가격대의 숙소 입니다.',
#  '그중에서 평점 더 높은데로 예약해주세요.',
#  '서촌 한옥 게스트하우스가 4.',
#  '7점의 높은 평점을 자랑하는것으로 확인되는데 여기로 예약 도와 드리면 될까요?',
#  '네네.',
#  '그렇게 해주세요.',
#  '인원수도 함께 말씀해 주시면 예약 도와 드리겠습니다.',
#  '아 참.',
#  '그게 애들이 많아서 아직 일정 조율중인데 정해진게 하나도 없어서 다 미정으로 우선 예약 부탁드릴게요.',
#  '네 알겠습니다.',
#  '숙소는 그럼 투숙 정보는 설정하지 않고 도와 드리겠습니다.',
#  '숙소도 예약번호 필요하신가요?',
#  '네 감사합니다.',
#  '예약번호 주시고 가까운 지하철역도 알려주세요.',
#  '숙소 예약번호는 IMAO2입니다.',
#  '종각역 부근에 위치하고 있는 숙소이구요.',
#  '그리고 마지막으로 관광지 문의도 드릴게요.',
#  '서울에서 역사적인 곳이 어디에요?',
#  '관광지의 지역과 종류는 어떻게 알아봐드릴까요?',
#  '잘 모르겠어요.',
#  '가장 괜찮은 곳으로 추천해 주시면 안될까요?',
#  '그러시다면 서울 중앙에 위치한 랜드마크 타입의 관광지인 남산골 한옥 마을 어떠세요?',
#  '재밌을꺼 같네요.',
#  '주소도 알 수 있을까요?',
#  '네.',
#  '주소는 서울 중구 85530입니다.',
#  '감사합니다.',
#  '정말 많이 도움됐어요.',
#  '또 다른 도움 필요하신 부분은 없으신가요?',
#  '네 이제 없어요.',
#  '알겠습니다.',
#  '이용해 주셔서 감사합니다.',
#  '서울 남쪽에 저렴한 숙소를 찾고 있습니다.',
#  '안녕하세요.',
#  '원하시는 숙소 종류가 있으신가요?',
#  '주차 가능한 곳이면 어디든 괜찮습니다.',
#  '그럼 서초구에 고속터미널 싱글 원룸이라는 에어비엔비가 있는데 여기 어떠세요?',
#  '조식도 제공되는 곳입니다.',
#  '저렴한데 조식도 준다니 좋네요.',
#  '그럼 거기로 갈게요.',
#  '일요일 하루만 예약해주세요.',
#  '저 혼자 갈겁니다.',
#  '네.',
#  '예약되었습니다.',
#  '예약 번호는 WGLI1입니다.',
#  '더 필요한건 없으세요?',
#  '서울 중앙에 일이 있어 가는 김에 그 쪽에서 교통편 관광지도 다녀오려고 하는데 어디로 가면 될까요?',
#  '서울 중앙에 교통편을 찾으시면 남산 케이블카가 있는데 여기 어떠세요?',
#  '좋아요.',
#  '그럼 아까 예약한 숙소에서 남산 케이블카로 가는 택시를 알아봐주세요.',
#  '출발 시간과 원하시는 택시 종류를 말씀해 주시면 안내해드리겠습니다.',
#  '4시 30분에 출발할건데 택시 종류는 아무거나 괜찮아요.',
#  '그럼 4시 30분에 출발하여 4시 45분에 남산 케이블카에 도착하는 에코 택시가 있는데 이 택시를 이용하시겠어요?',
#  '네.',
#  '그거 탈게요.',
#  '네.',
#  '출발지에서 택시를 못 찾으시면 기사님께 연락하셔서 만나시면 됩니다.',
#  '그럼 더 필요한건 없으세요?',
#  '이제 다 됐어요.',
#  '감사합니다.',
#  '네.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '주소좀 알려주세요.',
#  '안녕하세요.',
#  '30이고 입장료는 5000원입니다.',
#  '주소는 서울 서대문구 40352입니다.',
#  '감사합니다.',
#  '그리고 요기할만한 식당으로 서울 중앙에 있는 한식당으로 가격 상관없이 알아봐 주세요.',
#  '맥주도 한잔 할까해서 주류를 판매하는 곳으로 알아봐 주세요.',
#  '알겠습니다.',
#  '돼지조아소조아 등의 식당이 검색되었습니다.',
#  '이 중에서 마음에 드는곳이 있으세요?',
#  '거기 평점이랑 역에서 걷는 시간도 알려주세요.',
#  '돼지조아소조아에서 식사하실 수 있도록 예약 잘 도와 드렸습니다.',
#  '해당 식당의 평점은 3.',
#  '1점이고 역에서 걷는 시간은 7분입니다.',
#  '그리고 서울 북쪽에서 숙소도 찾아봐 주세요.',
#  '비싼 에어비엔비로요.',
#  '체리라는 평점 4.',
#  '5점의 에어비엔비가 있는데 한번 가 보시겠어요?',
#  '네 가볼게요.',
#  '화요일 하루 4명으로 예약해 주세요.',
#  '흡연이 가능한지도 같이 알아봐 주세요.',
#  '말씀하신대로 체리에 예약 해 드렸습니다.',
#  '흡연은 가능하지 않은 호텔로 확인됩니다.',
#  '또 다른 문의 사항 있으실까요?',
#  '아 네.',
#  '잘 알겠습니다.',
#  '다른 궁금한건 이제 없어요.',
#  '도와주셔서 감사합니다.',
#  '네.',
#  '이용해 주셔서 감사합니다.',
#  '여보세요?',
#  '애들하고 갈만한 박물관에 대해 안내받으려고 전화드렸어요.',
#  '네 반갑습니다.',
#  '박물관말씀이시죠.',
#  '원하시는 지역은 어디신가요?',
#  '서울 북쪽에 있는 교육에 도움이 되는 곳으로 알아봐주세요.',
#  '말씀하신 조건에 서울 역사 박물관이 가장 평점이 높습니다.',
#  '이곳으로 안내드릴까요?',
#  '네 좋은것 같아요.',
#  '거기 주소를 알려주세요.',
#  '아 그리고 입장료는 얼마에요?',
#  '네 주소는 서울 종로구 75461이며 입장료는 2000원입니다.',
#  '알겠습니다.',
#  '그리고 숙소는 좀 비싸도 서울 중앙에 있는 괜찮은 호텔로 예약하고 싶어요.',
#  '네 그렇다면 종로구에 위치한 프리미어호텔이 있습니다.',
#  '이곳으로 예약해드릴까요?',
#  '좋습니다.',
#  '그럼 금요일부터 2일동안 8명이 묵을수 있도록 예약해주세요.',
#  '네 예약되었습니다.',
#  '입니다.',
#  '네 고맙습니다.',
#  '그리고 숙소 근처에 괜찮은 한식당도 예약하고 싶어요.',
#  '가격대는 상관없으신가요?',
#  '좀 가격대가 있는곳이면 좋겠습니다.',
#  '그리고 주차가 돼야해요.',
#  '말씀하신 조건에 평점이 가장 높은 식당은 외계인의 맛집이라는 곳입니다.',
#  '이곳은 어떠실까요?',
#  '그럼 거기로 예약할게요.',
#  '45에 8명이 식사할수 있는 자리로 해주세요.',
#  '네 예약되었습니다.',
#  '거기 대표메뉴가 뭔가요?',
#  '그리고 주차는 가능하겠죠?',
#  '네 대표메뉴는 한정식이고 주차 가능하십니다.',
#  '네 알겠습니다.',
#  '감사합니다.',
#  '네 감사합니다.',
#  '네 안녕하세요 원하시는 지역은 있으신가요?',
#  '네 총4건 뜨시는데 용산구 소재의 역사적 교육적 가치가 높은 서울중앙성원은 어떠세요?',
#  '아 네네 괜찮네요 거기 입장료도 있죠?',
#  '네 입장료는 따로 없고 주소는 서울 용산구 14155입니다.',
#  '더 궁금하신 점 있으세요?',
#  '안녕하세요.',
#  '명수를 알 수 있을까요?',
#  '예약 도와드렸습니다.',
#  '궁금하신 점 있으신가요?',
#  '가격대는 저렴한 편이고 스파는 없습니다.',
#  '생각하고 계신 출발시간이랑 택시종류가 있으신가요?',
#  '고급 택시를 찾았습니다.',
#  '궁금하신 점 있으신가요?',
#  '소요시간은 45분입니다.',
#  '질문 더 있으실까요?',
#  '이용해주셔서 감사합니다.',
#  '오늘도 좋은 하루 보내세요.',
#  '안녕하세요.',
#  '경치가 좋은 관광지를 찾아주세요.',
#  '지역이랑 종류는 상관없어요.',
#  '안녕하세요.',
#  '여러 곳이 있습니다.',
#  '그중 입장료 7000원인 하늘공원을 추천드리는데 어떠세요?',
#  '좋아요.',
#  '근처 역은 어디인가요?',
#  '역에서 걸어서 얼마나 걸리나요?',
#  '근처 역은 월드컵경기장역입니다.',
#  '역에서 걸어서 16분 소요됩니다.',
#  '회오리라멘의 근처 역은 어디인가요?',
#  '28에 2명 예약해주세요.',
#  '시청역입니다.',
#  '예약되셨습니다.',
#  '관광지 근처 역에서 식당 근처 역으로 가는 지하철의 요금을 알려주세요.',
#  '1250원입니다.',
#  '제가 더 도울 일이 있을까요?',
#  '없습니다.',
#  '수고하세요.',
#  '네 감사합니다.',
#  '서울 아무곳이나 경치가 좋은 공원을 하나 추천해 주시겠어요?',
#  '안녕하세요?',
#  '서울의 경치 좋은 공원으로 총 9곳이 있는데 하늘공원은 어떠신가요?',
#  '평점도 높고 주변에 다른 관광지도 많아 추천 드립니다.',
#  '그러면 하늘공원 거기 주소하고 평점을 알려주세요.',
#  '하늘공원의 주소는 서울 마포구 45152 이고 평점은 4.',
#  '5점 입니다.',
#  '알겠습니다.',
#  '그리고 서울 북쪽에 있는 적당한 가격대의 헬스장이 있는 호텔도 검색해 주세요.',
#  '서울 북쪽의 적당한 가격대의 호텔로 오미야게 호텔은 어떠신가요?',
#  '혜화역에 위치해 접근성이 좋은 호텔 입니다.',
#  '네 그럼 거기로 예약 부탁 드려요.',
#  '화요일 부터 5일간 5명으로요.',
#  '알겠습니다.',
#  '요청하신 조건으로 오미야게 호텔 예약 번호 IRSO2로 예약 완료 했습니다.',
#  '궁금하신 사항이 있으신가요?',
#  '그러면 그 숙소 근처의 지하철역에서 서울역으로 가는 노선이 뭐가 있나요?',
#  '숙소근처의 혜화역에서 서울역으로 가신다면 4호선을 이용해 환승없이 가시면 됩니다.',
#  '시간은 얼마나 걸리죠?',
#  '16분 소요 됩니다.',
#  '네 알겠습니다.',
#  '감사합니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '네 알겠습니다.',
#  '이용 감사합니다.',
#  '좋은 하루 되세요.',
#  '안녕하세요.',
#  '서울 중앙에 있는 야외석 있는 일식당이 있을까요?',
#  '안녕하세요.',
#  '원하시는 가격대가 있을까요?',
#  '가격은 상관 없어요.',
#  '주차장 있으면 좋겠네요.',
#  '이라는 가게 한 곳이 있습니다.',
#  '좋네요.',
#  '27에 두명 예약해주세요.',
#  '죄송합니다.',
#  '그 요일에는 예약이 불가하세요.',
#  '금요일에 예약해주세요.',
#  '가장 가까운 지하철 역은 어디에요?',
#  '네.',
#  '예약해드렸습니다.',
#  '명동역에서 가장 가까워요.',
#  '그리고 택시를 예약하고 싶은데요.',
#  '오동통규동동에서 심미호스텔로 가고 싶어요.',
#  '57까지 도착해야해요.',
#  '출발시간은 언제로 하시겠어요?',
#  '택시 종류도 고르실 수 있어요.',
#  '둘다 지금은 설정안할게요.',
#  '기사님 전화번호만 알려주세요.',
#  '기사님 전화번호는 04236859017입니다.',
#  '택시 종류는 무엇이에요?',
#  '종류는 개인입니다.',
#  '또 무엇을 도와드릴까요?',
#  '없어요.',
#  '감사합니다.',
#  '감사합니다.',
#  '안녕하세요.',
#  '인터넷이 되는 호텔을 찾아주세요.',
#  '안녕하세요.',
#  '원하시는 가격대가 있으세요?',
#  '가격은 상관없습니다.',
#  '2곳이 있습니다.',
#  '그중 역에서 더 가까운 에버뉴 호텔을 추천드리는데 어떠세요?',
#  '네좋아요.',
#  '목요일에 3명 2일동안 예약될까요?',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '네 해주세요.',
#  '가까운 역은 어디인가요?',
#  '영업시간은요?',
#  '건대입구역입니다.',
#  '00입니다.',
#  '서울 남쪽에 흡연이 가능한 비싼 한식당을 찾고있어요.',
#  '식객이 있습니다.',
#  '대표메뉴 한정식인 곳인데 어떠세요?',
#  '맘에드네요.',
#  '30에 예약되나요?',
#  '네 가능한데 예약 도와드릴까요?',
#  '네 해주세요.',
#  '예약 번호와 전화번호 알려주세요.',
#  '전화번호는 4903129156입니다.',
#  '궁금증이 다 해결되셨나요?',
#  '네 감사해요.',
#  '네.',
#  '이용해 주셔서 감사합니다.',
#  '안녕하세요?',
#  '사차원주머니라는 식당을 찾고 있는데요.',
#  '가격대와 주류 판매 여부가 궁금합니다.',
#  '안녕하세요.',
#  '가격대는 적당한 가격대로 만원대 정도 예상되며 주류는 판매하지 않는 것으로 확인됩니다.',
#  '아 알겠습니다.',
#  '저 그리고 서울 중앙에 위치한 박물관을 찾고 있는데요.',
#  '한 곳 좀 추천 해주실 수 있나요?',
#  '네.',
#  '혹시 서울 용산구에 위치한 평점 4.',
#  '5의 삼성미술관 리움은 어떠신가요?',
#  '아 여기 전시는 진짜 괜찮다고 들었어요.',
#  '방문해보고 싶은데 입장료와 전화번호 좀 알려주세요.',
#  '입장료는 4천원이며 전화번호는 2424244346입니다.',
#  '추가로 궁금하신 점 있으신가요?',
#  '아니요.',
#  '없습니다.',
#  '확인 감사드려요.',
#  '네.',
#  '이용해주셔서 감사합니다.',
#  '안녕하세요.',
#  '머니볼 숙소에 수요일 1일동안 한명 예약해주세요.',
#  '네.',
#  '예약해드렸습니다.',
#  '주소랑 가장 가까운 지하철역 좀 알려주세요.',
#  '예약 번호도 알려주시겠어요?',
#  '국회의사당역에서 가깝습니다.',
#  '예약 번호는 KVUE7 입니다.',
#  '인터넷이 되는 곳이에요?',
#  '조식도 주나요?',
#  '조식은 제공되지 않습니다.',
#  '숙소랑 같은 위치의 관광지도 알려주세요.',
#  '관광 종류는 원하시는 것이 있으실까요?',
#  '다 상관 없어요.',
#  '이 평점도 4.',
#  '5고 역에서도 가깝습니다.',
#  '어떠세요?',
#  '좋네요.',
#  '가장 가까운 지하철역은 어디세요?',
#  '영업 시간도 알려주세요.',
#  '30 입니다.',
#  '감사합니다.',
#  '에서 가장 가까운 지하철역은 어디에요?',
#  '지역하고 영업시간 알 수 있을까요?',
#  '서울 중앙 지역에 위치하고 있습니다.',
#  '30 동안 하고 있습니다.',
#  '궁금하신 것 또 있으실까요?',
#  '감사합니다.',
#  '더 없어요.',
#  '네.',
#  '감사합니다.',
#  '동창들이랑 역사적인 곳으로 관광을 가려고 하는데 어디가 좋을까요?',
#  '안녕하세요.',
#  '선호하시는 종류와 지역이 어떻게 되세요?',
#  '저희는 어디든지 좋아요.',
#  '그러시면 교육적인 곳으로 안내해드릴까요?',
#  '아뇨.',
#  '굳이 그렇지는 않아도 돼요.',
#  '감남구에 선릉과 정릉이 적합하실것 같은데 어디가 괜찮으세요?',
#  '한옥 마을 구경하면 좋을 것 같네요.',
#  '여기로 가볼게요.',
#  '근데 중구면 지역이 어디인거죠?',
#  '남산골 한옥 마을은 서울 중앙에 있습니다.',
#  '아 중앙쪽이구나.',
#  '거기 상세 주소는 어떻게 되나요?',
#  '네.',
#  '주소는 서울 중구 85530입니다.',
#  '더 궁금하신건 없으세요?',
#  '없습니다.',
#  '알려주셔서 감사합니다.',
#  '네.',
#  '그럼 친구분들과 즐거운 시간 보내시길 바랍니다.',
#  '안녕하세요.',
#  '서울 북쪽에 주차 가능한 관광지 추천해주세요.',
#  '종류는 상관 없어요.',
#  '여러 곳이 있어서요.',
#  '어떠신가요?',
#  '좋네요.',
#  '그리고 서울중앙에 한식당도 찾고 있어요.',
#  '가격은 상관 없어요.',
#  '이럴순없는대라는 곳이 있습니다.',
#  '25에 7명 예약해주세요.',
#  '예약번호 알려주세요.',
#  '예약번호는 VNYO1입니다.',
#  '또 궁금하신 것 있으세요?',
#  '없어요.',
#  '감사합니다.',
#  '감사합니다.',
#  '식당 예약 좀 도와주세요.',
#  '안녕하세요.',
#  '예약 도와드리겠습니다.',
#  '혹시 생각해두신 식당이 있으신가요?',
#  '아니요.',
#  '연인이랑 특별한 날에 가려고 하는데 어디가 좋을지 모르겠어서요.',
#  '야외석이 있는 양식당이 괜찮을것 같은데 어디가 좋을까요?',
#  '그럼 원하시는 지역과 가격대는 어떻게 되세요?',
#  '지역은 상관없고 비싸고 좋은 곳으로 가려구요.',
#  '네.',
#  '조건에 맞는 곳이 강남구에 있는 팁 앤 스테이크와 강서구에 있는 피렌체의밤 이렇게 두 곳이 있는데 어디가 좋으세요?',
#  '강남구에 있는게 가기 좋을것 같네요.',
#  '거기로 목요일 20시 30분에 2명 예약이 가능한가요?',
#  '죄송하지만 목요일은 예약이 안되네요.',
#  '다른 날은 안되시나요?',
#  '그러면 화요일은 될까요?',
#  '네.',
#  '화요일은 가능합니다.',
#  '예약 하시겠어요?',
#  '네.',
#  '예약하고 예약번호랑 가까운 지하철역 좀 알려주세요.',
#  '알겠습니다.',
#  '예약 완료되셨구요.',
#  '가까운 지하철역은 강남역입니다.',
#  '더 필요하신거 있으세요?',
#  '아니요.',
#  '이제 다 됐어요.',
#  '네.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '행복한 시간 보내십시오.',
#  '서울에서 뭐하고 놀지 고민중인데 평점 4점이상인 기타 타입의 관광지가 있을까요?',
#  '안녕하세요.',
#  '생각하시는 지역이 있으신가요?',
#  '그건 딱히 없어요.',
#  '그럼 평점 4점의 이화 벽화마을은 어떠세요?',
#  '오 색다른 곳이네요.',
#  '거기 경치도 좋아요?',
#  '경치는 아쉽게도 좋지는 않습니다.',
#  '그렇구나.',
#  '알겠습니다.',
#  '그리고 인터넷 잘되는 중식당도 알아봐 주세요.',
#  '식당도 지역이나 가격대는 상관 없으신가요?',
#  '네 상관없어요.',
#  '그러시다면 엄중식이라는 곳을 추천해 드립니다.',
#  '가격대는 비싼곳이지만 평점 4.',
#  '3에 대표 메뉴로 탕수육을 판매하는 곳입니다.',
#  '탕수육 맛있겠네요.',
#  '월요일 12시50분에 4명으로 예약해주세요.',
#  '네.',
#  '말씀하신대로 엄중식에 식사 예약 해 드렸습니다.',
#  '예약번호 필요하신가요?',
#  '네.',
#  '예약번호랑 주소도 알려주세요.',
#  '예약번호는 OFXZ9이고 주소는 서울 강북구 86033입니다.',
#  '네 감사합니다.',
#  '또 다른 도움 필요하신건 없으세요?',
#  '네 없어요.',
#  '알겠습니다.',
#  '감사합니다.',
#  '안녕하세요 제가 특정 관광지 정보가 필요한데 여쭤보면 확인 가능하신가요?',
#  '안녕하세요.',
#  '어떤 관광지인지 말씀 주시면 확인 도와 드리겠습니다.',
#  '우와 신기하네요.',
#  '한국의 집의 어떤 정보가 필요하신가요?',
#  '아 참 거기 평점이랑 영업시간이랑 그리고.',
#  '영업 시간은 오전 10시부터 오후 6시 까지 입니다.',
#  '특별히 경치가 좋은곳은 아닙니다.',
#  '아아 그렇군요.',
#  '암튼 정보 주셔서 감사합니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '네 다 여쭤봤어요.',
#  '알겠습니다.',
#  '감사합니다.',
#  '서울 북쪽에 친구랑 묵을 모텔을 예약하려구요.',
#  '안녕하세요.',
#  '생각하시는 가격대가 어떻게 되세요?',
#  '가격은 상관없는데 흡연이 가능해야합니다.',
#  '그럼 동대문구에 있는 힐 모텔 서울과 성동구에 있는 모텔 킹 중에서 어디가 괜찮으실까요?',
#  '성동구가 괜찮네요.',
#  '모텔 킹에 토요일부터 5일 예약해주세요.',
#  '인원은 5명이 갈거예요.',
#  '죄송하지만 토요일은 예약이 안되는데 다른 날은 안되시나요?',
#  '그럼 화요일은 되나요?',
#  '가능하면 화요일로 예약하고 주소 알려주세요.',
#  '네.',
#  '화요일은 가능하여 화요일로 예약해드렸습니다.',
#  '주소는 서울 성동구 58673입니다.',
#  '예약 번호는 UHPR8이니 참고해주세요.',
#  '감사합니다.',
#  '더 필요한건 없으세요?',
#  '없습니다.',
#  '네.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '안녕하세요.',
#  '친구 결혼식 전날 미리 서울에 올라왔는데 식사할 곳이랑 묵을 곳을 찾고 있어요.',
#  '안녕하세요.',
#  '원하시는 조건을 말씀해주시면 거기에 맞춰서 도와드리겠습니다.',
#  '감사합니다.',
#  '그럼 숙소 들어가기 전에 식사할 만한 곳 먼저 알아봐 주세요.',
#  '서울 동쪽에 있는 비싼 가격대의 중식당으로 부탁드려요.',
#  '그런 곳으로는 홀럭키하우스라는 중식당이 있습니다.',
#  '그럼 거기로 예약해 주시겠어요?',
#  '금요일 18시 40분에 4명이 갈꺼에요.',
#  '네 알겠습니다.',
#  '말씀하신 대로 숙사 예약해 드렸습니다.',
#  '그럼 숙소는 서울 서쪽으로 알아볼게요.',
#  '비싼 가격대의 에어비앤비로 알아봐 주세요.',
#  '서쪽으로 알아보신다면 평점 4.',
#  '7점의 쉼 인 서울이라는 에어비엔비를 추천해 드립니다.',
#  '그럼 거기로 토요일부터 이틀간 9명으로 예약할게요.',
#  '네.',
#  '쉼 인 서울에 묵으시는 것으로 예약해 드렸습니다.',
#  '근처 지하철역은 어디에요?',
#  '홍대입구역입니다.',
#  '아 그러면 그 역에서 음.',
#  '사람들이 가장 많이 가는 역은 어디에요?',
#  '을지로4가역이 볼 것도 많고 관광하기 좋아 인기가 많습니다.',
#  '요새 또 을지로가 핫해서 사람들이 많이 가는 편입니다.',
#  '홍대입구역에서 환승없이 14분만에 갈 수도 있습니다.',
#  '친절히 말씀해주셔서 감사합니다.',
#  '더 필요하신 정보 있으신가요?',
#  '없습니다.',
#  '감사합니다.',
#  '안녕하세요.',
#  '서울로 여행 왔는데 서울 중앙쪽에 있는 모텔로 저렴한데로 알아봐 주세요.',
#  '안녕하세요.',
#  '해당 조건에 맞는 숙소는 확인되지 않아서 다른 가격대로 찾아봐 드려도 괜찮으실까요?',
#  '아 그럼.',
#  '비싼 가격대는 있을까요?',
#  '비싼 가격대로는 야드 서울이라는 숙소가 확인됩니다.',
#  '평점 3점의 모텔입니다.',
#  '생각보다 평점이 좋지는 않네요.',
#  '거기밖에 없는거죠?',
#  '네.',
#  '서울 중앙에서는 해당 숙소만 검색되고 있습니다.',
#  '할 수 없네요.',
#  '거기로라도 예약해주세요.',
#  '월요일 하루 묵을꺼고 인원은 총 8명이에요.',
#  '네 알겠습니다.',
#  '야드 서울에 월요일 하루 투숙 하시는 일정으로 예약 해 드렸습니다.',
#  '같은 서울 중앙 지역에서 비싼 가격의 일식당도 찾고 있는데 어디가 좋을까요?',
#  '믿고맡기는초밥이라는 오마카세 전문점이 서울 중앙에 있습니다.',
#  '평점도 4.',
#  '5로 매우 높은 곳입니다.',
#  '오 거기 마음에 드네요.',
#  '거기도 월요일에 8명으로 14시반에 예약해 주세요.',
#  '네 알겠습니다.',
#  '믿고맡기는초밥에서 식사 하실 수 있게 예약 해 드렸습니다.',
#  '또 필요한 사항 있으세요?',
#  '식사 후엔 일행이랑 관광을 좀 할려구요.',
#  '서울 중앙에 랜드마크 관광지 괜찮은곳이 있을까요?',
#  '평점 4.',
#  '5점의 서울중앙성원에 가보시는 것을 추천합니다.',
#  '거긴 도보로 도착 가능한곳이에요?',
#  '네.',
#  '지하철역에서 도보로 이동 가능하십니다.',
#  '그럼 문화 예술을 관람할 수 있는 곳이기도 해요?',
#  '그렇지는 않은것으로 확인됩니다.',
#  '알겠습니다.',
#  '한번 가볼게요.',
#  '감사합니다.',
#  '또 다른 문의사항이나 도움 필요하신 부분 있으세요?',
#  '다른건 없어요.',
#  '알겠습니다.',
#  '이용 감사드립니다.',
#  '안녕하세요.',
#  '영업시간을 알려주세요.',
#  '안녕하세요.',
#  '30입니다.',
#  '관광지와 같은 지역에 한식당이 있을까요?',
#  '원하시는 가격대가 있으세요?',
#  '가격대는 상관없습니다.',
#  '그중 평점이 높으며 저렴한 만칠천무한리필을 추천드리는데 어떠세요?',
#  '좋네요.',
#  '이름이 만칠천무한리필인가요?',
#  '영업 시간은 어떻게되죠?',
#  '네 이름 맞습니다.',
#  '00입니다.',
#  '15시 수요일 10명으로 예약해주세요.',
#  '네 예약되셨습니다.',
#  '더 도와드릴 부분 있을까요?',
#  '없습니다.',
#  '수고하세요.',
#  '네 감사합니다.',
#  '저기요.',
#  '즐길거리 중에 주차 가능한 곳을 찾고 싶은데요.',
#  '안녕하세요?',
#  '어느 지역의 즐길거리를 안내해 드릴까요?',
#  '잘 모르겠는데 아무데나요.',
#  '그럼 잠실 야구 경기장을 추천 드립니다.',
#  '서울 동쪽에 위치 해 있습니다.',
#  '야구 좋네요 감사합니다.',
#  '그리고 택시도 예약 되죠?',
#  '네 가능합니다.',
#  '출발 시간과 택시 종류를 알려 주시면 예약해 드리겠습니다.',
#  '6시 45분 노원역에 출발해서 13시 까지 혜화역 도착가능한 택시로 아무거나요.',
#  '죄송하지만 도착시간 13시 가능한 택시가 없어가 출발시간만 원하시는 시간에 가능한 택시로 찾아 드려도 될까요?',
#  '네네 그래도 됩니다.',
#  '45에서 노원역 출발 혜화역 도착하는 택시를 예약해 드리겠습니다.',
#  '네 그리고 전화번호 하고 예상 요금도 알려주세요.',
#  '네 알겠습니다.',
#  '예상 되는 요금은 25000원 입니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '네 감사합니다.',
#  '네 이용 감사합니다.',
#  '좋은 하루 되세요.',
#  '저 지금 친구들이랑 서울 왔는데 저녁 먹을 식당 예약 좀 할라고 하거든요.',
#  '네 안녕하세요.',
#  '식당 종류를 말씀해주시면 도와드리겠습니다.',
#  '서울 중앙쪽에 좀 저렴한 데로요.',
#  '종류는 딱히 상관없거든요.',
#  '한 곳 찾았습니다.',
#  '시청역에 인접한 순대국이 대표 메뉴인 이럴순없는대라는 곳입니다.',
#  '예약하시겠어요?',
#  '네 순대국 좋네요.',
#  '거기 월요일에 18시 30분에 될까요?',
#  '5명이거든요.',
#  '네 말씀주신대로 예약되셨습니다.',
#  '더 필요하신 거 있으세요?',
#  '음.',
#  '시청역이랑 가깝죠?',
#  '거기 자세한 주소하고 예약 번호 좀 알려주세요.',
#  '주소는 서울 중구 50461이며 예약번호는 BNYA8입니다.',
#  '추가 질문 있으실까요?',
#  '아 이제 없어요.',
#  '수고하세요.',
#  '네 이용 감사합니다.',
#  '고구려 호스텔에서 화요일부터 5일간 한명 예약해주세요.',
#  '로 예약되었습니다.',
#  '그리고 서울 북쪽에 있는 랜드마크에 추천해주세요.',
#  '그럼 신촌역 근처에 있는 이화여자대학교를 추천합니다.',
#  '그 관광지는 도보로 이동가능한가요?',
#  '역사적인 곳인지 경치가 좋은지까지 알려주세요.',
#  '먼저 도보로 이동가능한거리에 있고 역사적인 곳은 아닌것 같습니다.',
#  '경치 또한 안좋은듯 합니다.',
#  '그럼 관광지에서 18시에 출발해서 강남역으로 가는 택시를 찾아주세요.',
#  '종류는 상관없습니다.',
#  '네 어떤걸 알려드릴까요?',
#  '요금이랑 소요시간을 알려주세요.',
#  '요금은 3000원이고 소요시간은 15분정도 입니다.',
#  '네 감사합니다.',
#  '감사합니다.',
#  '안녕하세요.',
#  '스타필드 코엑스몰의 영업 시간과 입장료 그리고 주소를 알아봐주세요.',
#  '00 입니다.',
#  '주소는 서울 강남구 70562 입니다.',
#  '감사해요.',
#  '그리고 서울 북쪽에 있는 한식당 중에서 술을 판매하는 곳도 알아봐주세요.',
#  '가격대는 어떻게 할까요?',
#  '술을 판매하는 곳이라면 가격이 어떻게 됐던 괜찮아요.',
#  '닭발먹고오리발내민다 어떠세요?',
#  '평점은 4.',
#  '5 입니다.',
#  '평점 높은거 보면 괜찮은 곳인가봐요.',
#  ...]

# %%
c = remove_repeated_space(b)
c
# Out:
# ['안녕하세요.',
#  '적당한 가격대의 스파가 가능한 호텔을 찾아주세요.',
#  '안녕하세요.',
#  '원하시는 지역이 있으세요?',
#  '지역 상관없이 찾아주세요.',
#  '4곳이 검색되었습니다.',
#  '그중 평점이 가장 높은 행복 호텔을 추천드리는데 어떠세요?',
#  '좋아요.',
#  '화요일에 2일동안 4명 예약될까요?',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '예약해 주세요.',
#  '예약번호는 IDUJ3입니다.',
#  '같은 지역에 관광지도 있을까요?',
#  '선호하시는 관광 종류가 있으신가요?',
#  '종류는 상관없습니다.',
#  '8곳이 검색되었습니다.',
#  '역에서도 가까운 롯데월드 아쿠아리움을 추천드리는데 어떠세요?',
#  '좋네요.',
#  '그곳의 입장 비용은 얼마인가요?',
#  '4000원입니다.',
#  '궁금증이 다 해결되셨나요?',
#  '네 감사합니다.',
#  '네 감사합니다.',
#  '즐거운 하루 보내세요.',
#  '친구들이랑 갈 일식당 예약 좀 할게요.',
#  '서울 중앙쪽에 가격은 상관없으니까 맛있는 곳으로 부탁드려요.',
#  '안녕하세요?',
#  '규동이 대표 메뉴로 평가도 좋은 곳입니다.',
#  '네 예약할게요.',
#  '월요일 12시 34분에 10명이거든요.',
#  '가능한가요?',
#  '원하시는대로 예약되셨습니다.',
#  '더 필요한 건 없으세요?',
#  '인터넷되고 비싼 호텔로 찾아주세요.',
#  '죄송하지만 식당에 주차는 불가로 확인됩니다.',
#  '그 중 명동역에서 가깝고 평점도 높은 프리미어 호텔은 어떠세요?',
#  '네 거기로 할게요.',
#  '식당 예약한 날부터 4일이구요.',
#  '인원도 같은데 예약되나요?',
#  '네 가능합니다.',
#  '말씀주신대로 진행해드렸습니다.',
#  '질문 있으세요?',
#  '아 걸어서 갈 수 있는지랑 흡연 가능한지도 확인 부탁드려요.',
#  '네 도보 가능합니다.',
#  '흡연은 불가로 확인되네요.',
#  '알겠습니다.',
#  '그 담에 서울 북쪽에 아무거나 문화와 예술관련해서 괜찮은 곳 좀 찾아주세요.',
#  '안국역쪽의 국립현대미술관 서울관 확인됩니다.',
#  '네 좋아요.',
#  '여긴 주차 여부랑 평점 좀 알려주세요.',
#  '평점은 4.',
#  '5점입니다.',
#  '더 궁금한 점 있으세요?',
#  '아 이제 없네요.',
#  '수고하세요.',
#  '감사합니다.',
#  '즐거운 시간 되세요.',
#  '식당 예약 좀 도와주실 수 있나요?',
#  '그럼요.',
#  '어떻게 예약 도와드리면 될까요?',
#  '먼저 역사랑 관련되어 있는 랜드마크 좀 찾아봐 주실 수 있나요?',
#  '지역은 어디로 찾아봐드리면 될까요?',
#  '지역은 서울 내면 어디든 괜찮습니다.',
#  '이쪽으로 가보시는 건 어떠신가요?',
#  '그래요?',
#  '평점이 높으면 그만큼 볼 게 많겠죠?',
#  '거기 주소랑 영업시간 좀 알려주실래요?',
#  '잠시만요.',
#  '운영은 아침 9시 반부터 오후 5시 30분까지입니다.',
#  '아 혹시 거기 주변 경관은 좀 어때요?',
#  '좋은 편이에요?',
#  '음 아무래도 주변에 건물들도 있고 해서 경치가 좋다고 말씀드리기는 어려울 것 같습니다.',
#  '또 궁금하신 점 있으실까요?',
#  '아까 말씀드렸던 것처럼 숙소도 예약을 해야 되는데 그 서울중앙성원과 가까운 곳에 게스트하우스 괜찮은 곳 있을까요?',
#  '서울중앙성원과 가까운 곳이라면 서울 중앙 쪽을 말씀하시는 거죠?',
#  '이쪽으로 알아봐드리면 될까요?',
#  '그쪽으로요.',
#  '가격대는 어느 정도로 책정해두셨는지 여쭤봐도 될까요?',
#  '정해두신 범위가 있으실까요?',
#  '어.',
#  '그런 건 딱히 없어요.',
#  '동키 게스트 하우스와 서촌 한옥 게스트하우스가 있네요.',
#  '평점은 서촌 쪽이 더 높은데 이쪽으로 예약해보시겠어요?',
#  '거기로 갈게요.',
#  '한옥이면 더 좋죠.',
#  '그 목요일부터 5일 간 묵을 거고 인원은 2명으로 해주시면 되세요.',
#  '인원 2명으로 해서 게스트하우스 예약해드렸습니다.',
#  '더 필요하신 것 있으시면 편하게 말씀해주세요.',
#  '그러면 마지막으로 식당 예약 좀 도와주세요.',
#  '그 숙소랑 가까워야 돼서 그 서울 중앙 쪽에 한식당으로 가고 싶은데요.',
#  '음식 가격은 어느 정도인 것이 좋으실까요?',
#  '아 가능하면 야외석이 있으면 더 좋구요.',
#  '혹시 괜찮으시다면 서울 남쪽으로 한번 찾아봐드려도 괜찮으실까요?',
#  '그래요?',
#  '음.',
#  '어쩔 수 없죠.',
#  '서울 남쪽 지역엔 있나 봐주세요.',
#  '이쪽으로 예약 도와드려도 괜찮으실까요?',
#  '좋아요.',
#  '목요일 오후 4시 45분에 2명으로 예약해주실 수 있어요?',
#  '두유노코리안으로 예약 도와드렸습니다.',
#  'GPWA1이니까 미리 확인하시고 식당 이용하시면 될 것 같습니다.',
#  '고마워요.',
#  '그 한 가지 좀 궁금한 게 있는데 거기 주차 되나요?',
#  '아 주차는 어려우실 것 같아요.',
#  '따로 주차장이 없는 것 같습니다.',
#  '아 그래요.',
#  '그러면 택시 타고 가게 주소 좀 불러주실래요?',
#  '서울 강남구 05699입니다.',
#  '또 문의해주실 사항 있으신가요?',
#  '이제 더 없는 거 같네요.',
#  '번거롭게 해드려서 죄송해요.',
#  '아닙니다.',
#  '오늘도 행복한 하루 보내시길 바랍니다.',
#  '어떤 도움이 필요하세요?',
#  '필요하신 정보가 어떻게 되세요?',
#  '서울 어린이 대공원은 어느 지역에 있어여?',
#  '30 입니다.',
#  '거기 역사적인곳이져?',
#  '서울 어린이 대공원은 역사적인 곳이라고 볼 수는 없습니다.',
#  '아 그렇군여.',
#  '다른 도움 필요하신건 없으세요?',
#  '네 감사합니다.',
#  '온김에 여기저기 가보려구요.',
#  '일단 이쪽에 적당한 가격의 맛난 일식당이 있을까요?',
#  '제가 뚜벅이라 걸어서 갈 수 있어야 되구요.',
#  '안녕하세요?',
#  '시청역의 라멘 맛집 회오리라멘 어떠실까요?',
#  '역에서 도보 3분 거리로 가깝습니다.',
#  '네 가깝고 좋네요.',
#  '흡연석은 있을까요?',
#  '흡연석은 따로 없는 걸로 확인됩니다.',
#  '아 네 확인 감사해요.',
#  '글구 식당 가까이에 기타 타입의 관광지가 있을까요?',
#  '역시 걸어서 갈 수 있어야 되구요.',
#  '충무로역에서 도보 2분이면 도착하는 한국의 집은 어떠실까요?',
#  '입장료도 2천원으로 저렴한 편입니다.',
#  '네 괜찮겠네요.',
#  '그럼 경치가 좋은 곳은 아니겠네요?',
#  '네 맞습니다.',
#  '더 필요하신 거 있으세요?',
#  '네 마지막으로 지하철 정보만 좀 찾을게요.',
#  '요금이랑 도착지 라인이 어떻게 되는지도 좀 알려주세요.',
#  '도착지 라인은 6호선입니다.',
#  '더 확인하실 부분 있으실까요?',
#  '아아 다 됐습니다.',
#  '감사합니다.',
#  '네 이용 감사합니다.',
#  '제가 비싼 한식당을 찾고 있는데요.',
#  '원하시는 지역이 있을까요?',
#  '서울 내에 있으면 되요.',
#  '아 주차는 가능해야해요.',
#  '네.',
#  '4곳이 검색되는데 다른 조건은 없을까요?',
#  '뭐.',
#  '없는데.',
#  '추천해주시겠어요?',
#  '그럼 제가 추천해드리겠습니다.',
#  '평점 4.',
#  '3점에 압구정역 근처에 있는 식객이라는 한식당을 추천드립니다.',
#  '네 좋네요.',
#  '그럼 화요일 07시50분에 5명 예약 가능할까요?',
#  '네 가능합니다.',
#  '진행할까요?',
#  '네 예약 해주시고 예약 번호와 라스트 오더 시간도 알려주세요.',
#  '예약되셨습니다.',
#  '이고 라스트 오더 시간은 22시입니다.',
#  '감사합니다.',
#  '이용해 주셔서 감사합니다.',
#  '무엇을 도와드릴까요?',
#  '생각하신 가격대와 지역이 있으신가요?',
#  '아뇨.',
#  '서울 중구에 위치한 친구를 만나느라 샵샵샵이 있습니다.',
#  '어떠신가요?',
#  '금요일 16시20분에 4명 예약해주시겠어요?',
#  '예약 완료되셨습니다.',
#  '입니다.',
#  '궁금하신점 있으신가요?',
#  '영업시간은 몇시인가요?',
#  '네.',
#  '00입니다.',
#  '더 필요하신점 있으신가요?',
#  '서울 서쪽에 위치한 곳으로요.',
#  '선호하시는 숙소종류가 있으신가요?',
#  '아뇨 괜찮습니다.',
#  '네.',
#  '진하우스라는 에어비엔비가 있습니다.',
#  '어떠신가요?',
#  '죄송합니다.',
#  '5일까지는 예약이 잡이지 않아 기간을 변경해야 할것 같은데 어떻게 해드릴까요?',
#  '음.',
#  '일요일 3명 하루 예약 완료되었습니다.',
#  '입니다.',
#  '궁금하신 사항 있으신가요?',
#  '거기 수영장은 있나요?',
#  '아쉽게도 진하우스에는 수영장을 운영하지 않습니다.',
#  '주소는 서울 마포구 10506 입니다.',
#  '더 궁금하신 점 있으신가요?',
#  '아뇨.',
#  '없어요.',
#  '감사합니다.',
#  '이용해주셔서 감사합니다.',
#  '식당이랑 관광할 곳을 알아보려고 하거든요.',
#  '안녕하세요?',
#  '지역을 말씀해주시면 찾아드리겠습니다.',
#  '가격은 상관없고요.',
#  '인터넷을 계속 써야 되서 인터넷 되는 곳으로 좀 찾아주세요.',
#  '신촌역 부근의 피에르 오뎅 확인됩니다.',
#  '예약해드릴까요?',
#  '아 그럼 일요일 10시 10분에 2명으로 부탁드릴게요.',
#  '식당 주소랑 도보가 가능한지도 궁금하네요.',
#  '도보도 가능합니다.',
#  '관광지는 어떤 곳으로 찾으실까요?',
#  '아 네 식당 가까이에 쇼핑할 곳으로 찾는데요.',
#  '신도림역의 디큐브시브는 어떠세요?',
#  '역에서 도보 2분 거리로 가깝고 입장료는 9000원입니다.',
#  '아 괜찮네요.',
#  '마지막으로 디큐브시브 거기서 15시 30분에 출발가능한 택시도 좀 부탁드릴게요.',
#  '택시 종류도 말씀 부탁드립니다.',
#  '일단 그렇게만 결정한거라 일단 다른 조건은 안 넣고 찾아주시겠어요?',
#  '네 알겠습니다.',
#  '택시 조회되네요.',
#  '요금은 5천원입니다.',
#  '확인이 다 되셨을까요?',
#  '아 네 물어볼걸 다 말씀해주셨네요.',
#  '감사합니다.',
#  '네 이용 감사합니다.',
#  '저 디큐브시브에 가려는데 궁금한게 있어요.',
#  '네 어떤게 궁금하신가요?',
#  '평점이랑 그 곳 경치가 좋은지요.',
#  '먼저 평점은 4점입니다.',
#  '그리고 경치는 좋지 않다고 쓰여있습니다.',
#  '아 그래요?',
#  '그래도 뭐 가긴 갈꺼라서.',
#  '영업시간 좀 알려주세요.',
#  '디큐브시브의 영업시간은 09시30분 부터 17시 30분까지 입니다.',
#  '네 감사합니다.',
#  '더 궁금하신 사항 있으신가요?',
#  '아뇨 없습니다.',
#  '네.',
#  '감사합니다.',
#  '안녕하세요.',
#  '흡연 가능한 곳으로 찾아주세요.',
#  '안녕하세요.',
#  '생각하시는 금액대가 있으신가요?',
#  '정모텔이있습니다.',
#  '사당역에서 도보 7분입니다.',
#  '어떠세요?',
#  '좋아요 수요일 4일간 10명 예약되나요?',
#  '수요일은 이용불가합니다.',
#  '다른 요일을 말해주세요.',
#  '월요일도 괜찮습니다.',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '예약해 주세요.',
#  '예약 번호는 AMWN4입니다.',
#  '더 궁금한 점이 있으세요?',
#  '없습니다.',
#  '네 감사합니다.',
#  '처음으로 서울에 놀러왔는데 무작정 온거라 숙소를 예약 못해서요.',
#  '도와주시겠어요?',
#  '안녕하세요.',
#  '가격대를 말씀해주시면 안내해드리겠습니다.',
#  '제가 지금 서울 서쪽에 있어서 이 쪽에 있는 숙소였으면 합니다.',
#  '가격은 저렴한 곳으로 조식 제공되면 종류는 뭐든 괜찮아요.',
#  '그럼 마포구에 심미 호스텔이 조식 제공되는 곳인데 괜찮으실까요?',
#  '근데 제가 이동하기 쉽게 지하철역 근처에 있는 곳이었으면 하는데 역 근처에 있나요?',
#  '네.',
#  '월드컵경기역에서 도보 3분 거리에 있습니다.',
#  '와 가깝네요.',
#  '그럼 오늘부터 7일간 머무를건데 예약해주세요.',
#  '저 혼자입니다.',
#  '예약 진행해드렸습니다.',
#  '예약 번호는 GNVM0입니다.',
#  '더 필요한건 없으세요?',
#  '서울 관광 좀 하다가 9시 40분쯤 숙소로 가려고 하는데 택시도 알아봐주시겠어요?',
#  '출발하시는 곳과 도착 시간을 말씀해주시면 안내해드리겠습니다.',
#  '제가 계속 이동 중이고 여기 뭐가 있는지 잘 몰라서 어디서 출발해야할지 모르겠어요.',
#  '9시 40분에 출발하는 택시가 있으면 그쪽으로 제가 이동하겠습니다.',
#  '원하시는 택시 종류는 따로 있으세요?',
#  '아니요.',
#  '종류 상관없습니다.',
#  '그럼 9시 40분에 예술의전당에서 출발하는 고급 택시가 있는데 이 택시를 이용하시면 될 것 같습니다.',
#  '소요 시간 45분으로 심미 호스텔에 10시 25분쯤 도착하실거예요.',
#  '기사님 전화번호는 06379810254 이니 출발지에서 기사님께 연락하시면 됩니다.',
#  '그렇게 하도록 할게요.',
#  '감사합니다.',
#  '제가 더 도와드릴건 없나요?',
#  '네.',
#  '이제 괜찮습니다.',
#  '알겠습니다.',
#  '문의하실게 있으시면 언제든 다시 연락 주세요.',
#  '이용해 주셔서 감사합니다.',
#  '안녕하세요.',
#  '서울 북쪽에 있는 저렴한 가격대의 호스텔을 알아봐주세요.',
#  '동문 호스텔 이라는 곳 어떠세요?',
#  '평점은 4.',
#  '1 입니다.',
#  '좋아요.',
#  '금요일부터 3일동안 2명이 머무를 예정이에요.',
#  '예약 해주세요.',
#  '예약이 되었습니다.',
#  '예약 번호는 FBOI4 입니다.',
#  '네 감사해요.',
#  '그리고 경복궁의 입장료랑 영업 시간 그리고 주소도 알아봐주세요.',
#  '입장료는 9000원 입니다.',
#  '00 로 나오네요.',
#  '주소는 서울 종로구 05481 입니다.',
#  '네.',
#  '전화 번호도 알려주세요.',
#  '전화번호는 108270327 입니다.',
#  '다른 궁금하신 사항이 더 있으세요?',
#  '하나만 더 부탁드려요.',
#  '서울 중앙에 있는 저렴한 한식당 중에서 괜찮은 곳 알아봐주세요.',
#  '돼지조아소조아 라는 식당 어떠세요?',
#  '찾아보니 좋네요.',
#  '숙소를 예약한 날에 15시로 3명 예약 해주세요.',
#  '아 그런데 주차가 가능한 식당인가요?',
#  '예약 번호는 ACKW6 입니다.',
#  '주차가 가능한 식당입니다.',
#  '다른 궁금하신 사항이 더 있으세요?',
#  '그렇군요.',
#  '감사합니다.',
#  '덕분에 편하게 알아봤네요.',
#  '다음에 또 이용할께요.',
#  '감사합니다.',
#  '안녕하세요.',
#  '정모텔이라는 이름의 숙소 주소랑 전화번호를 알고 싶어서 문의드려요.',
#  '안녕하세요.',
#  '전화번호는 7269223521입니다.',
#  '네 감사합니다.',
#  '또 하나 더 있는데요.',
#  '서울 중앙에 랜드마크가 있나요?',
#  '서울 중앙에는 남산골 한옥 마을이 대표적인 랜드마크 입니다.',
#  '거긴 역에서 얼마나 걸려요?',
#  '지하철 충무로역에서 도보로 3분정도 소요됩니다.',
#  '그렇군요.',
#  '정보 감사합니다.',
#  '다른 궁금하신 점 있으세요?',
#  '다른건 없습니다.',
#  '알겠습니다.',
#  '감사합니다.',
#  '관광지 좀 찾고싶은데요.',
#  '안녕하세요?',
#  '숙소부터 도와드릴게요.',
#  '지역을 말씀해주시면 됩니다.',
#  '아 네 서울 북쪽에 가격은 적당한 데로 게스트 하우스면 괜찮아요.',
#  '죄송하지만 가격대 변경을 하셔야 할 거 같습니다.',
#  '조회가 안되네요.',
#  '그래요 그면 저렴한 데는 있어요?',
#  '네 저렴한 곳은 확인됩니다.',
#  '명동역 부근의 인터넷 제공되는 호두나무집인데요.',
#  '예약하시겠어요?',
#  '네 할게요.',
#  '일요일부터 이틀 있으려구요.',
#  '예약완료되셨습니다.',
#  '궁금한 점 있으세요?',
#  '아니요.',
#  '식당도 찾아주세요.',
#  '네 확인됩니다.',
#  '예약해드릴까요?',
#  '네 좋아요.',
#  '같은 날 같은 인원이구요.',
#  '14시 10분으로 해주세요.',
#  '네 원하시는대로 예약되셨습니다.',
#  '관광지는 어떤 곳으로 찾으시나요?',
#  '아 서울 중앙쪽에 공원으로요.',
#  '있나요?',
#  '네 확인됩니다.',
#  '여의나루역에서 도보 2분 거리의 여의도 한강공원입니다.',
#  '어떠신가요?',
#  '좋아요.',
#  '도보는 가능한거고.',
#  '문화 예술이랑 관련있나요?',
#  '문화 예술과는 관련이 없는 곳입니다.',
#  '이제 없어요.',
#  '감사합니다.',
#  '즐거운 여행 되세요.',
#  '친구들이랑 서울 남쪽에 있는 주점을 가볼까 해요.',
#  '괜찮은곳으로 예약 좀 부탁드릴게요.',
#  '안녕하세요.',
#  '가격대는 어느정도로 생각하세요?',
#  '애들이랑 나눠서 낼꺼라 가격 상관없이 알아봐주세요.',
#  '그럼 적당한 가격대의 이기자카야를 추천해 드립니다.',
#  '평점 4.',
#  '3으로 남쪽에서 꽤 유명한 주점입니다.',
#  '오 그래요?',
#  '그럼 토요일 4시20분에 9명으로 예약할게요.',
#  '워낙 유명한 곳이다보니 토요일은 이미 예약이 마감된 것으로 확인되는데 다른 요일도 괜찮으세요?',
#  '우와 역시.',
#  '그럼 일요일은 가능할까요?',
#  '네.',
#  '일요일은 가능합니다.',
#  '일요일 4시20분으로 진행해 드릴까요?',
#  '그렇게 해주세요.',
#  '네.',
#  '알려주신 정보대로 예약 해 드렸습니다.',
#  '관련해서 필요하신 사항 있으실까요?',
#  '음.',
#  '찾아가야되니까 주소도 알려주세요.',
#  '예약번호는 VHRD4이고 주소는 서울 서초구 46141입니다.',
#  '감사합니다.',
#  '그리고 이번에는 중앙쪽에서 괜찮은 게스트 하우스도 찾아봐 주세요.',
#  '숙소의 가격대는 어떻게 알아봐드릴까요?',
#  '숙소도 가격대는 상관없이 알아봐 주시고 애들이랑 게임하는게 큰 목적이라 원할하게 인터넷 이용이 가능한 곳으로 부탁드려요.',
#  '말씀하신 조건으로는 동키 게스트 하우스와 서촌 한옥 게스트하우스가 괜찮아 보입니다.',
#  '둘 다 저렴한 가격대의 숙소 입니다.',
#  '그중에서 평점 더 높은데로 예약해주세요.',
#  '서촌 한옥 게스트하우스가 4.',
#  '7점의 높은 평점을 자랑하는것으로 확인되는데 여기로 예약 도와 드리면 될까요?',
#  '네네.',
#  '그렇게 해주세요.',
#  '인원수도 함께 말씀해 주시면 예약 도와 드리겠습니다.',
#  '아 참.',
#  '그게 애들이 많아서 아직 일정 조율중인데 정해진게 하나도 없어서 다 미정으로 우선 예약 부탁드릴게요.',
#  '네 알겠습니다.',
#  '숙소는 그럼 투숙 정보는 설정하지 않고 도와 드리겠습니다.',
#  '숙소도 예약번호 필요하신가요?',
#  '네 감사합니다.',
#  '예약번호 주시고 가까운 지하철역도 알려주세요.',
#  '숙소 예약번호는 IMAO2입니다.',
#  '종각역 부근에 위치하고 있는 숙소이구요.',
#  '그리고 마지막으로 관광지 문의도 드릴게요.',
#  '서울에서 역사적인 곳이 어디에요?',
#  '관광지의 지역과 종류는 어떻게 알아봐드릴까요?',
#  '잘 모르겠어요.',
#  '가장 괜찮은 곳으로 추천해 주시면 안될까요?',
#  '그러시다면 서울 중앙에 위치한 랜드마크 타입의 관광지인 남산골 한옥 마을 어떠세요?',
#  '재밌을꺼 같네요.',
#  '주소도 알 수 있을까요?',
#  '네.',
#  '주소는 서울 중구 85530입니다.',
#  '감사합니다.',
#  '정말 많이 도움됐어요.',
#  '또 다른 도움 필요하신 부분은 없으신가요?',
#  '네 이제 없어요.',
#  '알겠습니다.',
#  '이용해 주셔서 감사합니다.',
#  '서울 남쪽에 저렴한 숙소를 찾고 있습니다.',
#  '안녕하세요.',
#  '원하시는 숙소 종류가 있으신가요?',
#  '주차 가능한 곳이면 어디든 괜찮습니다.',
#  '그럼 서초구에 고속터미널 싱글 원룸이라는 에어비엔비가 있는데 여기 어떠세요?',
#  '조식도 제공되는 곳입니다.',
#  '저렴한데 조식도 준다니 좋네요.',
#  '그럼 거기로 갈게요.',
#  '일요일 하루만 예약해주세요.',
#  '저 혼자 갈겁니다.',
#  '네.',
#  '예약되었습니다.',
#  '예약 번호는 WGLI1입니다.',
#  '더 필요한건 없으세요?',
#  '서울 중앙에 일이 있어 가는 김에 그 쪽에서 교통편 관광지도 다녀오려고 하는데 어디로 가면 될까요?',
#  '서울 중앙에 교통편을 찾으시면 남산 케이블카가 있는데 여기 어떠세요?',
#  '좋아요.',
#  '그럼 아까 예약한 숙소에서 남산 케이블카로 가는 택시를 알아봐주세요.',
#  '출발 시간과 원하시는 택시 종류를 말씀해 주시면 안내해드리겠습니다.',
#  '4시 30분에 출발할건데 택시 종류는 아무거나 괜찮아요.',
#  '그럼 4시 30분에 출발하여 4시 45분에 남산 케이블카에 도착하는 에코 택시가 있는데 이 택시를 이용하시겠어요?',
#  '네.',
#  '그거 탈게요.',
#  '네.',
#  '출발지에서 택시를 못 찾으시면 기사님께 연락하셔서 만나시면 됩니다.',
#  '그럼 더 필요한건 없으세요?',
#  '이제 다 됐어요.',
#  '감사합니다.',
#  '네.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '주소좀 알려주세요.',
#  '안녕하세요.',
#  '30이고 입장료는 5000원입니다.',
#  '주소는 서울 서대문구 40352입니다.',
#  '감사합니다.',
#  '그리고 요기할만한 식당으로 서울 중앙에 있는 한식당으로 가격 상관없이 알아봐 주세요.',
#  '맥주도 한잔 할까해서 주류를 판매하는 곳으로 알아봐 주세요.',
#  '알겠습니다.',
#  '돼지조아소조아 등의 식당이 검색되었습니다.',
#  '이 중에서 마음에 드는곳이 있으세요?',
#  '거기 평점이랑 역에서 걷는 시간도 알려주세요.',
#  '돼지조아소조아에서 식사하실 수 있도록 예약 잘 도와 드렸습니다.',
#  '해당 식당의 평점은 3.',
#  '1점이고 역에서 걷는 시간은 7분입니다.',
#  '그리고 서울 북쪽에서 숙소도 찾아봐 주세요.',
#  '비싼 에어비엔비로요.',
#  '체리라는 평점 4.',
#  '5점의 에어비엔비가 있는데 한번 가 보시겠어요?',
#  '네 가볼게요.',
#  '화요일 하루 4명으로 예약해 주세요.',
#  '흡연이 가능한지도 같이 알아봐 주세요.',
#  '말씀하신대로 체리에 예약 해 드렸습니다.',
#  '흡연은 가능하지 않은 호텔로 확인됩니다.',
#  '또 다른 문의 사항 있으실까요?',
#  '아 네.',
#  '잘 알겠습니다.',
#  '다른 궁금한건 이제 없어요.',
#  '도와주셔서 감사합니다.',
#  '네.',
#  '이용해 주셔서 감사합니다.',
#  '여보세요?',
#  '애들하고 갈만한 박물관에 대해 안내받으려고 전화드렸어요.',
#  '네 반갑습니다.',
#  '박물관말씀이시죠.',
#  '원하시는 지역은 어디신가요?',
#  '서울 북쪽에 있는 교육에 도움이 되는 곳으로 알아봐주세요.',
#  '말씀하신 조건에 서울 역사 박물관이 가장 평점이 높습니다.',
#  '이곳으로 안내드릴까요?',
#  '네 좋은것 같아요.',
#  '거기 주소를 알려주세요.',
#  '아 그리고 입장료는 얼마에요?',
#  '네 주소는 서울 종로구 75461이며 입장료는 2000원입니다.',
#  '알겠습니다.',
#  '그리고 숙소는 좀 비싸도 서울 중앙에 있는 괜찮은 호텔로 예약하고 싶어요.',
#  '네 그렇다면 종로구에 위치한 프리미어호텔이 있습니다.',
#  '이곳으로 예약해드릴까요?',
#  '좋습니다.',
#  '그럼 금요일부터 2일동안 8명이 묵을수 있도록 예약해주세요.',
#  '네 예약되었습니다.',
#  '입니다.',
#  '네 고맙습니다.',
#  '그리고 숙소 근처에 괜찮은 한식당도 예약하고 싶어요.',
#  '가격대는 상관없으신가요?',
#  '좀 가격대가 있는곳이면 좋겠습니다.',
#  '그리고 주차가 돼야해요.',
#  '말씀하신 조건에 평점이 가장 높은 식당은 외계인의 맛집이라는 곳입니다.',
#  '이곳은 어떠실까요?',
#  '그럼 거기로 예약할게요.',
#  '45에 8명이 식사할수 있는 자리로 해주세요.',
#  '네 예약되었습니다.',
#  '거기 대표메뉴가 뭔가요?',
#  '그리고 주차는 가능하겠죠?',
#  '네 대표메뉴는 한정식이고 주차 가능하십니다.',
#  '네 알겠습니다.',
#  '감사합니다.',
#  '네 감사합니다.',
#  '네 안녕하세요 원하시는 지역은 있으신가요?',
#  '네 총4건 뜨시는데 용산구 소재의 역사적 교육적 가치가 높은 서울중앙성원은 어떠세요?',
#  '아 네네 괜찮네요 거기 입장료도 있죠?',
#  '네 입장료는 따로 없고 주소는 서울 용산구 14155입니다.',
#  '더 궁금하신 점 있으세요?',
#  '안녕하세요.',
#  '명수를 알 수 있을까요?',
#  '예약 도와드렸습니다.',
#  '궁금하신 점 있으신가요?',
#  '가격대는 저렴한 편이고 스파는 없습니다.',
#  '생각하고 계신 출발시간이랑 택시종류가 있으신가요?',
#  '고급 택시를 찾았습니다.',
#  '궁금하신 점 있으신가요?',
#  '소요시간은 45분입니다.',
#  '질문 더 있으실까요?',
#  '이용해주셔서 감사합니다.',
#  '오늘도 좋은 하루 보내세요.',
#  '안녕하세요.',
#  '경치가 좋은 관광지를 찾아주세요.',
#  '지역이랑 종류는 상관없어요.',
#  '안녕하세요.',
#  '여러 곳이 있습니다.',
#  '그중 입장료 7000원인 하늘공원을 추천드리는데 어떠세요?',
#  '좋아요.',
#  '근처 역은 어디인가요?',
#  '역에서 걸어서 얼마나 걸리나요?',
#  '근처 역은 월드컵경기장역입니다.',
#  '역에서 걸어서 16분 소요됩니다.',
#  '회오리라멘의 근처 역은 어디인가요?',
#  '28에 2명 예약해주세요.',
#  '시청역입니다.',
#  '예약되셨습니다.',
#  '관광지 근처 역에서 식당 근처 역으로 가는 지하철의 요금을 알려주세요.',
#  '1250원입니다.',
#  '제가 더 도울 일이 있을까요?',
#  '없습니다.',
#  '수고하세요.',
#  '네 감사합니다.',
#  '서울 아무곳이나 경치가 좋은 공원을 하나 추천해 주시겠어요?',
#  '안녕하세요?',
#  '서울의 경치 좋은 공원으로 총 9곳이 있는데 하늘공원은 어떠신가요?',
#  '평점도 높고 주변에 다른 관광지도 많아 추천 드립니다.',
#  '그러면 하늘공원 거기 주소하고 평점을 알려주세요.',
#  '하늘공원의 주소는 서울 마포구 45152 이고 평점은 4.',
#  '5점 입니다.',
#  '알겠습니다.',
#  '그리고 서울 북쪽에 있는 적당한 가격대의 헬스장이 있는 호텔도 검색해 주세요.',
#  '서울 북쪽의 적당한 가격대의 호텔로 오미야게 호텔은 어떠신가요?',
#  '혜화역에 위치해 접근성이 좋은 호텔 입니다.',
#  '네 그럼 거기로 예약 부탁 드려요.',
#  '화요일 부터 5일간 5명으로요.',
#  '알겠습니다.',
#  '요청하신 조건으로 오미야게 호텔 예약 번호 IRSO2로 예약 완료 했습니다.',
#  '궁금하신 사항이 있으신가요?',
#  '그러면 그 숙소 근처의 지하철역에서 서울역으로 가는 노선이 뭐가 있나요?',
#  '숙소근처의 혜화역에서 서울역으로 가신다면 4호선을 이용해 환승없이 가시면 됩니다.',
#  '시간은 얼마나 걸리죠?',
#  '16분 소요 됩니다.',
#  '네 알겠습니다.',
#  '감사합니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '네 알겠습니다.',
#  '이용 감사합니다.',
#  '좋은 하루 되세요.',
#  '안녕하세요.',
#  '서울 중앙에 있는 야외석 있는 일식당이 있을까요?',
#  '안녕하세요.',
#  '원하시는 가격대가 있을까요?',
#  '가격은 상관 없어요.',
#  '주차장 있으면 좋겠네요.',
#  '이라는 가게 한 곳이 있습니다.',
#  '좋네요.',
#  '27에 두명 예약해주세요.',
#  '죄송합니다.',
#  '그 요일에는 예약이 불가하세요.',
#  '금요일에 예약해주세요.',
#  '가장 가까운 지하철 역은 어디에요?',
#  '네.',
#  '예약해드렸습니다.',
#  '명동역에서 가장 가까워요.',
#  '그리고 택시를 예약하고 싶은데요.',
#  '오동통규동동에서 심미호스텔로 가고 싶어요.',
#  '57까지 도착해야해요.',
#  '출발시간은 언제로 하시겠어요?',
#  '택시 종류도 고르실 수 있어요.',
#  '둘다 지금은 설정안할게요.',
#  '기사님 전화번호만 알려주세요.',
#  '기사님 전화번호는 04236859017입니다.',
#  '택시 종류는 무엇이에요?',
#  '종류는 개인입니다.',
#  '또 무엇을 도와드릴까요?',
#  '없어요.',
#  '감사합니다.',
#  '감사합니다.',
#  '안녕하세요.',
#  '인터넷이 되는 호텔을 찾아주세요.',
#  '안녕하세요.',
#  '원하시는 가격대가 있으세요?',
#  '가격은 상관없습니다.',
#  '2곳이 있습니다.',
#  '그중 역에서 더 가까운 에버뉴 호텔을 추천드리는데 어떠세요?',
#  '네좋아요.',
#  '목요일에 3명 2일동안 예약될까요?',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '네 해주세요.',
#  '가까운 역은 어디인가요?',
#  '영업시간은요?',
#  '건대입구역입니다.',
#  '00입니다.',
#  '서울 남쪽에 흡연이 가능한 비싼 한식당을 찾고있어요.',
#  '식객이 있습니다.',
#  '대표메뉴 한정식인 곳인데 어떠세요?',
#  '맘에드네요.',
#  '30에 예약되나요?',
#  '네 가능한데 예약 도와드릴까요?',
#  '네 해주세요.',
#  '예약 번호와 전화번호 알려주세요.',
#  '전화번호는 4903129156입니다.',
#  '궁금증이 다 해결되셨나요?',
#  '네 감사해요.',
#  '네.',
#  '이용해 주셔서 감사합니다.',
#  '안녕하세요?',
#  '사차원주머니라는 식당을 찾고 있는데요.',
#  '가격대와 주류 판매 여부가 궁금합니다.',
#  '안녕하세요.',
#  '가격대는 적당한 가격대로 만원대 정도 예상되며 주류는 판매하지 않는 것으로 확인됩니다.',
#  '아 알겠습니다.',
#  '저 그리고 서울 중앙에 위치한 박물관을 찾고 있는데요.',
#  '한 곳 좀 추천 해주실 수 있나요?',
#  '네.',
#  '혹시 서울 용산구에 위치한 평점 4.',
#  '5의 삼성미술관 리움은 어떠신가요?',
#  '아 여기 전시는 진짜 괜찮다고 들었어요.',
#  '방문해보고 싶은데 입장료와 전화번호 좀 알려주세요.',
#  '입장료는 4천원이며 전화번호는 2424244346입니다.',
#  '추가로 궁금하신 점 있으신가요?',
#  '아니요.',
#  '없습니다.',
#  '확인 감사드려요.',
#  '네.',
#  '이용해주셔서 감사합니다.',
#  '안녕하세요.',
#  '머니볼 숙소에 수요일 1일동안 한명 예약해주세요.',
#  '네.',
#  '예약해드렸습니다.',
#  '주소랑 가장 가까운 지하철역 좀 알려주세요.',
#  '예약 번호도 알려주시겠어요?',
#  '국회의사당역에서 가깝습니다.',
#  '예약 번호는 KVUE7 입니다.',
#  '인터넷이 되는 곳이에요?',
#  '조식도 주나요?',
#  '조식은 제공되지 않습니다.',
#  '숙소랑 같은 위치의 관광지도 알려주세요.',
#  '관광 종류는 원하시는 것이 있으실까요?',
#  '다 상관 없어요.',
#  '이 평점도 4.',
#  '5고 역에서도 가깝습니다.',
#  '어떠세요?',
#  '좋네요.',
#  '가장 가까운 지하철역은 어디세요?',
#  '영업 시간도 알려주세요.',
#  '30 입니다.',
#  '감사합니다.',
#  '에서 가장 가까운 지하철역은 어디에요?',
#  '지역하고 영업시간 알 수 있을까요?',
#  '서울 중앙 지역에 위치하고 있습니다.',
#  '30 동안 하고 있습니다.',
#  '궁금하신 것 또 있으실까요?',
#  '감사합니다.',
#  '더 없어요.',
#  '네.',
#  '감사합니다.',
#  '동창들이랑 역사적인 곳으로 관광을 가려고 하는데 어디가 좋을까요?',
#  '안녕하세요.',
#  '선호하시는 종류와 지역이 어떻게 되세요?',
#  '저희는 어디든지 좋아요.',
#  '그러시면 교육적인 곳으로 안내해드릴까요?',
#  '아뇨.',
#  '굳이 그렇지는 않아도 돼요.',
#  '감남구에 선릉과 정릉이 적합하실것 같은데 어디가 괜찮으세요?',
#  '한옥 마을 구경하면 좋을 것 같네요.',
#  '여기로 가볼게요.',
#  '근데 중구면 지역이 어디인거죠?',
#  '남산골 한옥 마을은 서울 중앙에 있습니다.',
#  '아 중앙쪽이구나.',
#  '거기 상세 주소는 어떻게 되나요?',
#  '네.',
#  '주소는 서울 중구 85530입니다.',
#  '더 궁금하신건 없으세요?',
#  '없습니다.',
#  '알려주셔서 감사합니다.',
#  '네.',
#  '그럼 친구분들과 즐거운 시간 보내시길 바랍니다.',
#  '안녕하세요.',
#  '서울 북쪽에 주차 가능한 관광지 추천해주세요.',
#  '종류는 상관 없어요.',
#  '여러 곳이 있어서요.',
#  '어떠신가요?',
#  '좋네요.',
#  '그리고 서울중앙에 한식당도 찾고 있어요.',
#  '가격은 상관 없어요.',
#  '이럴순없는대라는 곳이 있습니다.',
#  '25에 7명 예약해주세요.',
#  '예약번호 알려주세요.',
#  '예약번호는 VNYO1입니다.',
#  '또 궁금하신 것 있으세요?',
#  '없어요.',
#  '감사합니다.',
#  '감사합니다.',
#  '식당 예약 좀 도와주세요.',
#  '안녕하세요.',
#  '예약 도와드리겠습니다.',
#  '혹시 생각해두신 식당이 있으신가요?',
#  '아니요.',
#  '연인이랑 특별한 날에 가려고 하는데 어디가 좋을지 모르겠어서요.',
#  '야외석이 있는 양식당이 괜찮을것 같은데 어디가 좋을까요?',
#  '그럼 원하시는 지역과 가격대는 어떻게 되세요?',
#  '지역은 상관없고 비싸고 좋은 곳으로 가려구요.',
#  '네.',
#  '조건에 맞는 곳이 강남구에 있는 팁 앤 스테이크와 강서구에 있는 피렌체의밤 이렇게 두 곳이 있는데 어디가 좋으세요?',
#  '강남구에 있는게 가기 좋을것 같네요.',
#  '거기로 목요일 20시 30분에 2명 예약이 가능한가요?',
#  '죄송하지만 목요일은 예약이 안되네요.',
#  '다른 날은 안되시나요?',
#  '그러면 화요일은 될까요?',
#  '네.',
#  '화요일은 가능합니다.',
#  '예약 하시겠어요?',
#  '네.',
#  '예약하고 예약번호랑 가까운 지하철역 좀 알려주세요.',
#  '알겠습니다.',
#  '예약 완료되셨구요.',
#  '가까운 지하철역은 강남역입니다.',
#  '더 필요하신거 있으세요?',
#  '아니요.',
#  '이제 다 됐어요.',
#  '네.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '행복한 시간 보내십시오.',
#  '서울에서 뭐하고 놀지 고민중인데 평점 4점이상인 기타 타입의 관광지가 있을까요?',
#  '안녕하세요.',
#  '생각하시는 지역이 있으신가요?',
#  '그건 딱히 없어요.',
#  '그럼 평점 4점의 이화 벽화마을은 어떠세요?',
#  '오 색다른 곳이네요.',
#  '거기 경치도 좋아요?',
#  '경치는 아쉽게도 좋지는 않습니다.',
#  '그렇구나.',
#  '알겠습니다.',
#  '그리고 인터넷 잘되는 중식당도 알아봐 주세요.',
#  '식당도 지역이나 가격대는 상관 없으신가요?',
#  '네 상관없어요.',
#  '그러시다면 엄중식이라는 곳을 추천해 드립니다.',
#  '가격대는 비싼곳이지만 평점 4.',
#  '3에 대표 메뉴로 탕수육을 판매하는 곳입니다.',
#  '탕수육 맛있겠네요.',
#  '월요일 12시50분에 4명으로 예약해주세요.',
#  '네.',
#  '말씀하신대로 엄중식에 식사 예약 해 드렸습니다.',
#  '예약번호 필요하신가요?',
#  '네.',
#  '예약번호랑 주소도 알려주세요.',
#  '예약번호는 OFXZ9이고 주소는 서울 강북구 86033입니다.',
#  '네 감사합니다.',
#  '또 다른 도움 필요하신건 없으세요?',
#  '네 없어요.',
#  '알겠습니다.',
#  '감사합니다.',
#  '안녕하세요 제가 특정 관광지 정보가 필요한데 여쭤보면 확인 가능하신가요?',
#  '안녕하세요.',
#  '어떤 관광지인지 말씀 주시면 확인 도와 드리겠습니다.',
#  '우와 신기하네요.',
#  '한국의 집의 어떤 정보가 필요하신가요?',
#  '아 참 거기 평점이랑 영업시간이랑 그리고.',
#  '영업 시간은 오전 10시부터 오후 6시 까지 입니다.',
#  '특별히 경치가 좋은곳은 아닙니다.',
#  '아아 그렇군요.',
#  '암튼 정보 주셔서 감사합니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '네 다 여쭤봤어요.',
#  '알겠습니다.',
#  '감사합니다.',
#  '서울 북쪽에 친구랑 묵을 모텔을 예약하려구요.',
#  '안녕하세요.',
#  '생각하시는 가격대가 어떻게 되세요?',
#  '가격은 상관없는데 흡연이 가능해야합니다.',
#  '그럼 동대문구에 있는 힐 모텔 서울과 성동구에 있는 모텔 킹 중에서 어디가 괜찮으실까요?',
#  '성동구가 괜찮네요.',
#  '모텔 킹에 토요일부터 5일 예약해주세요.',
#  '인원은 5명이 갈거예요.',
#  '죄송하지만 토요일은 예약이 안되는데 다른 날은 안되시나요?',
#  '그럼 화요일은 되나요?',
#  '가능하면 화요일로 예약하고 주소 알려주세요.',
#  '네.',
#  '화요일은 가능하여 화요일로 예약해드렸습니다.',
#  '주소는 서울 성동구 58673입니다.',
#  '예약 번호는 UHPR8이니 참고해주세요.',
#  '감사합니다.',
#  '더 필요한건 없으세요?',
#  '없습니다.',
#  '네.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '안녕하세요.',
#  '친구 결혼식 전날 미리 서울에 올라왔는데 식사할 곳이랑 묵을 곳을 찾고 있어요.',
#  '안녕하세요.',
#  '원하시는 조건을 말씀해주시면 거기에 맞춰서 도와드리겠습니다.',
#  '감사합니다.',
#  '그럼 숙소 들어가기 전에 식사할 만한 곳 먼저 알아봐 주세요.',
#  '서울 동쪽에 있는 비싼 가격대의 중식당으로 부탁드려요.',
#  '그런 곳으로는 홀럭키하우스라는 중식당이 있습니다.',
#  '그럼 거기로 예약해 주시겠어요?',
#  '금요일 18시 40분에 4명이 갈꺼에요.',
#  '네 알겠습니다.',
#  '말씀하신 대로 숙사 예약해 드렸습니다.',
#  '그럼 숙소는 서울 서쪽으로 알아볼게요.',
#  '비싼 가격대의 에어비앤비로 알아봐 주세요.',
#  '서쪽으로 알아보신다면 평점 4.',
#  '7점의 쉼 인 서울이라는 에어비엔비를 추천해 드립니다.',
#  '그럼 거기로 토요일부터 이틀간 9명으로 예약할게요.',
#  '네.',
#  '쉼 인 서울에 묵으시는 것으로 예약해 드렸습니다.',
#  '근처 지하철역은 어디에요?',
#  '홍대입구역입니다.',
#  '아 그러면 그 역에서 음.',
#  '사람들이 가장 많이 가는 역은 어디에요?',
#  '을지로4가역이 볼 것도 많고 관광하기 좋아 인기가 많습니다.',
#  '요새 또 을지로가 핫해서 사람들이 많이 가는 편입니다.',
#  '홍대입구역에서 환승없이 14분만에 갈 수도 있습니다.',
#  '친절히 말씀해주셔서 감사합니다.',
#  '더 필요하신 정보 있으신가요?',
#  '없습니다.',
#  '감사합니다.',
#  '안녕하세요.',
#  '서울로 여행 왔는데 서울 중앙쪽에 있는 모텔로 저렴한데로 알아봐 주세요.',
#  '안녕하세요.',
#  '해당 조건에 맞는 숙소는 확인되지 않아서 다른 가격대로 찾아봐 드려도 괜찮으실까요?',
#  '아 그럼.',
#  '비싼 가격대는 있을까요?',
#  '비싼 가격대로는 야드 서울이라는 숙소가 확인됩니다.',
#  '평점 3점의 모텔입니다.',
#  '생각보다 평점이 좋지는 않네요.',
#  '거기밖에 없는거죠?',
#  '네.',
#  '서울 중앙에서는 해당 숙소만 검색되고 있습니다.',
#  '할 수 없네요.',
#  '거기로라도 예약해주세요.',
#  '월요일 하루 묵을꺼고 인원은 총 8명이에요.',
#  '네 알겠습니다.',
#  '야드 서울에 월요일 하루 투숙 하시는 일정으로 예약 해 드렸습니다.',
#  '같은 서울 중앙 지역에서 비싼 가격의 일식당도 찾고 있는데 어디가 좋을까요?',
#  '믿고맡기는초밥이라는 오마카세 전문점이 서울 중앙에 있습니다.',
#  '평점도 4.',
#  '5로 매우 높은 곳입니다.',
#  '오 거기 마음에 드네요.',
#  '거기도 월요일에 8명으로 14시반에 예약해 주세요.',
#  '네 알겠습니다.',
#  '믿고맡기는초밥에서 식사 하실 수 있게 예약 해 드렸습니다.',
#  '또 필요한 사항 있으세요?',
#  '식사 후엔 일행이랑 관광을 좀 할려구요.',
#  '서울 중앙에 랜드마크 관광지 괜찮은곳이 있을까요?',
#  '평점 4.',
#  '5점의 서울중앙성원에 가보시는 것을 추천합니다.',
#  '거긴 도보로 도착 가능한곳이에요?',
#  '네.',
#  '지하철역에서 도보로 이동 가능하십니다.',
#  '그럼 문화 예술을 관람할 수 있는 곳이기도 해요?',
#  '그렇지는 않은것으로 확인됩니다.',
#  '알겠습니다.',
#  '한번 가볼게요.',
#  '감사합니다.',
#  '또 다른 문의사항이나 도움 필요하신 부분 있으세요?',
#  '다른건 없어요.',
#  '알겠습니다.',
#  '이용 감사드립니다.',
#  '안녕하세요.',
#  '영업시간을 알려주세요.',
#  '안녕하세요.',
#  '30입니다.',
#  '관광지와 같은 지역에 한식당이 있을까요?',
#  '원하시는 가격대가 있으세요?',
#  '가격대는 상관없습니다.',
#  '그중 평점이 높으며 저렴한 만칠천무한리필을 추천드리는데 어떠세요?',
#  '좋네요.',
#  '이름이 만칠천무한리필인가요?',
#  '영업 시간은 어떻게되죠?',
#  '네 이름 맞습니다.',
#  '00입니다.',
#  '15시 수요일 10명으로 예약해주세요.',
#  '네 예약되셨습니다.',
#  '더 도와드릴 부분 있을까요?',
#  '없습니다.',
#  '수고하세요.',
#  '네 감사합니다.',
#  '저기요.',
#  '즐길거리 중에 주차 가능한 곳을 찾고 싶은데요.',
#  '안녕하세요?',
#  '어느 지역의 즐길거리를 안내해 드릴까요?',
#  '잘 모르겠는데 아무데나요.',
#  '그럼 잠실 야구 경기장을 추천 드립니다.',
#  '서울 동쪽에 위치 해 있습니다.',
#  '야구 좋네요 감사합니다.',
#  '그리고 택시도 예약 되죠?',
#  '네 가능합니다.',
#  '출발 시간과 택시 종류를 알려 주시면 예약해 드리겠습니다.',
#  '6시 45분 노원역에 출발해서 13시 까지 혜화역 도착가능한 택시로 아무거나요.',
#  '죄송하지만 도착시간 13시 가능한 택시가 없어가 출발시간만 원하시는 시간에 가능한 택시로 찾아 드려도 될까요?',
#  '네네 그래도 됩니다.',
#  '45에서 노원역 출발 혜화역 도착하는 택시를 예약해 드리겠습니다.',
#  '네 그리고 전화번호 하고 예상 요금도 알려주세요.',
#  '네 알겠습니다.',
#  '예상 되는 요금은 25000원 입니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '네 감사합니다.',
#  '네 이용 감사합니다.',
#  '좋은 하루 되세요.',
#  '저 지금 친구들이랑 서울 왔는데 저녁 먹을 식당 예약 좀 할라고 하거든요.',
#  '네 안녕하세요.',
#  '식당 종류를 말씀해주시면 도와드리겠습니다.',
#  '서울 중앙쪽에 좀 저렴한 데로요.',
#  '종류는 딱히 상관없거든요.',
#  '한 곳 찾았습니다.',
#  '시청역에 인접한 순대국이 대표 메뉴인 이럴순없는대라는 곳입니다.',
#  '예약하시겠어요?',
#  '네 순대국 좋네요.',
#  '거기 월요일에 18시 30분에 될까요?',
#  '5명이거든요.',
#  '네 말씀주신대로 예약되셨습니다.',
#  '더 필요하신 거 있으세요?',
#  '음.',
#  '시청역이랑 가깝죠?',
#  '거기 자세한 주소하고 예약 번호 좀 알려주세요.',
#  '주소는 서울 중구 50461이며 예약번호는 BNYA8입니다.',
#  '추가 질문 있으실까요?',
#  '아 이제 없어요.',
#  '수고하세요.',
#  '네 이용 감사합니다.',
#  '고구려 호스텔에서 화요일부터 5일간 한명 예약해주세요.',
#  '로 예약되었습니다.',
#  '그리고 서울 북쪽에 있는 랜드마크에 추천해주세요.',
#  '그럼 신촌역 근처에 있는 이화여자대학교를 추천합니다.',
#  '그 관광지는 도보로 이동가능한가요?',
#  '역사적인 곳인지 경치가 좋은지까지 알려주세요.',
#  '먼저 도보로 이동가능한거리에 있고 역사적인 곳은 아닌것 같습니다.',
#  '경치 또한 안좋은듯 합니다.',
#  '그럼 관광지에서 18시에 출발해서 강남역으로 가는 택시를 찾아주세요.',
#  '종류는 상관없습니다.',
#  '네 어떤걸 알려드릴까요?',
#  '요금이랑 소요시간을 알려주세요.',
#  '요금은 3000원이고 소요시간은 15분정도 입니다.',
#  '네 감사합니다.',
#  '감사합니다.',
#  '안녕하세요.',
#  '스타필드 코엑스몰의 영업 시간과 입장료 그리고 주소를 알아봐주세요.',
#  '00 입니다.',
#  '주소는 서울 강남구 70562 입니다.',
#  '감사해요.',
#  '그리고 서울 북쪽에 있는 한식당 중에서 술을 판매하는 곳도 알아봐주세요.',
#  '가격대는 어떻게 할까요?',
#  '술을 판매하는 곳이라면 가격이 어떻게 됐던 괜찮아요.',
#  '닭발먹고오리발내민다 어떠세요?',
#  '평점은 4.',
#  '5 입니다.',
#  '평점 높은거 보면 괜찮은 곳인가봐요.',
#  ...]

# %%
d = remove_dup_sent(c)

# %%
e = spacing_sent(d)
# Out:
#   0%|          | 102/120705 [00:05<1:49:59, 18.28it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-feb954f3256b> in <module>
# ----> 1 e = spacing_sent(d)
#
# ~/code/korean_preprocessor.py in spacing_sent(texts)
#      45     ret = []
#      46     for text in tqdm(texts):
# ---> 47         text = spacing(text)
#      48         if text:
#      49             ret.append(text)
#
# /opt/conda/lib/python3.7/site-packages/pykospacing/kospacing.py in spacing(sent)
#      66                                for ss in splitted_sent])
#      67     else:
# ---> 68         spaced_sent = PredSpacing.get_spaced_sent(sent)
#      69     return spaced_sent.strip()
#
# /opt/conda/lib/python3.7/site-packages/pykospacing/kospacing.py in get_spaced_sent(self, raw_sent)
#      35             word2idx_dic=self._w2idx, sequences=sents_in, maxlen=200,
#      36             padding='post', truncating='post')
# ---> 37         results = self._model.predict(mat_in)
#      38         mat_set = results[0, ]
#      39         preds = np.array(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
f = spell_check_sent(e)
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-542632f72394> in <module>
# ----> 1 f = spell_check_sent(e)
#       2 f
#
# ~/code/korean_preprocessor.py in spell_check_sent(text)
#      55     """
#      56     ret = []
# ---> 57     for text in texts:
#      58         try:
#      59             spelled_sent = spell_checker.check(text)
#
# NameError: name 'texts' is not defined

# %%
#최소 길이 지정
g = minimize_text(d, 3)
g
# Out:
# ['안녕하세요.',
#  '적당한 가격대의 스파가 가능한 호텔을 찾아주세요.',
#  '원하시는 지역이 있으세요?',
#  '지역 상관없이 찾아주세요.',
#  '4곳이 검색되었습니다.',
#  '그중 평점이 가장 높은 행복 호텔을 추천드리는데 어떠세요?',
#  '좋아요.',
#  '화요일에 2일동안 4명 예약될까요?',
#  '네 가능합니다.',
#  '예약 도와드릴까요?',
#  '예약해 주세요.',
#  '예약번호는 IDUJ3입니다.',
#  '같은 지역에 관광지도 있을까요?',
#  '선호하시는 관광 종류가 있으신가요?',
#  '종류는 상관없습니다.',
#  '8곳이 검색되었습니다.',
#  '역에서도 가까운 롯데월드 아쿠아리움을 추천드리는데 어떠세요?',
#  '좋네요.',
#  '그곳의 입장 비용은 얼마인가요?',
#  '4000원입니다.',
#  '궁금증이 다 해결되셨나요?',
#  '네 감사합니다.',
#  '즐거운 하루 보내세요.',
#  '친구들이랑 갈 일식당 예약 좀 할게요.',
#  '서울 중앙쪽에 가격은 상관없으니까 맛있는 곳으로 부탁드려요.',
#  '안녕하세요?',
#  '규동이 대표 메뉴로 평가도 좋은 곳입니다.',
#  '네 예약할게요.',
#  '월요일 12시 34분에 10명이거든요.',
#  '가능한가요?',
#  '원하시는대로 예약되셨습니다.',
#  '더 필요한 건 없으세요?',
#  '인터넷되고 비싼 호텔로 찾아주세요.',
#  '죄송하지만 식당에 주차는 불가로 확인됩니다.',
#  '그 중 명동역에서 가깝고 평점도 높은 프리미어 호텔은 어떠세요?',
#  '네 거기로 할게요.',
#  '식당 예약한 날부터 4일이구요.',
#  '인원도 같은데 예약되나요?',
#  '말씀주신대로 진행해드렸습니다.',
#  '질문 있으세요?',
#  '아 걸어서 갈 수 있는지랑 흡연 가능한지도 확인 부탁드려요.',
#  '네 도보 가능합니다.',
#  '흡연은 불가로 확인되네요.',
#  '알겠습니다.',
#  '그 담에 서울 북쪽에 아무거나 문화와 예술관련해서 괜찮은 곳 좀 찾아주세요.',
#  '안국역쪽의 국립현대미술관 서울관 확인됩니다.',
#  '네 좋아요.',
#  '여긴 주차 여부랑 평점 좀 알려주세요.',
#  '평점은 4.',
#  '5점입니다.',
#  '더 궁금한 점 있으세요?',
#  '아 이제 없네요.',
#  '수고하세요.',
#  '감사합니다.',
#  '즐거운 시간 되세요.',
#  '식당 예약 좀 도와주실 수 있나요?',
#  '그럼요.',
#  '어떻게 예약 도와드리면 될까요?',
#  '먼저 역사랑 관련되어 있는 랜드마크 좀 찾아봐 주실 수 있나요?',
#  '지역은 어디로 찾아봐드리면 될까요?',
#  '지역은 서울 내면 어디든 괜찮습니다.',
#  '이쪽으로 가보시는 건 어떠신가요?',
#  '그래요?',
#  '평점이 높으면 그만큼 볼 게 많겠죠?',
#  '거기 주소랑 영업시간 좀 알려주실래요?',
#  '잠시만요.',
#  '운영은 아침 9시 반부터 오후 5시 30분까지입니다.',
#  '아 혹시 거기 주변 경관은 좀 어때요?',
#  '좋은 편이에요?',
#  '음 아무래도 주변에 건물들도 있고 해서 경치가 좋다고 말씀드리기는 어려울 것 같습니다.',
#  '또 궁금하신 점 있으실까요?',
#  '아까 말씀드렸던 것처럼 숙소도 예약을 해야 되는데 그 서울중앙성원과 가까운 곳에 게스트하우스 괜찮은 곳 있을까요?',
#  '서울중앙성원과 가까운 곳이라면 서울 중앙 쪽을 말씀하시는 거죠?',
#  '이쪽으로 알아봐드리면 될까요?',
#  '그쪽으로요.',
#  '가격대는 어느 정도로 책정해두셨는지 여쭤봐도 될까요?',
#  '정해두신 범위가 있으실까요?',
#  '그런 건 딱히 없어요.',
#  '동키 게스트 하우스와 서촌 한옥 게스트하우스가 있네요.',
#  '평점은 서촌 쪽이 더 높은데 이쪽으로 예약해보시겠어요?',
#  '거기로 갈게요.',
#  '한옥이면 더 좋죠.',
#  '그 목요일부터 5일 간 묵을 거고 인원은 2명으로 해주시면 되세요.',
#  '인원 2명으로 해서 게스트하우스 예약해드렸습니다.',
#  '더 필요하신 것 있으시면 편하게 말씀해주세요.',
#  '그러면 마지막으로 식당 예약 좀 도와주세요.',
#  '그 숙소랑 가까워야 돼서 그 서울 중앙 쪽에 한식당으로 가고 싶은데요.',
#  '음식 가격은 어느 정도인 것이 좋으실까요?',
#  '아 가능하면 야외석이 있으면 더 좋구요.',
#  '혹시 괜찮으시다면 서울 남쪽으로 한번 찾아봐드려도 괜찮으실까요?',
#  '어쩔 수 없죠.',
#  '서울 남쪽 지역엔 있나 봐주세요.',
#  '이쪽으로 예약 도와드려도 괜찮으실까요?',
#  '목요일 오후 4시 45분에 2명으로 예약해주실 수 있어요?',
#  '두유노코리안으로 예약 도와드렸습니다.',
#  'GPWA1이니까 미리 확인하시고 식당 이용하시면 될 것 같습니다.',
#  '고마워요.',
#  '그 한 가지 좀 궁금한 게 있는데 거기 주차 되나요?',
#  '아 주차는 어려우실 것 같아요.',
#  '따로 주차장이 없는 것 같습니다.',
#  '아 그래요.',
#  '그러면 택시 타고 가게 주소 좀 불러주실래요?',
#  '서울 강남구 05699입니다.',
#  '또 문의해주실 사항 있으신가요?',
#  '이제 더 없는 거 같네요.',
#  '번거롭게 해드려서 죄송해요.',
#  '아닙니다.',
#  '오늘도 행복한 하루 보내시길 바랍니다.',
#  '어떤 도움이 필요하세요?',
#  '필요하신 정보가 어떻게 되세요?',
#  '서울 어린이 대공원은 어느 지역에 있어여?',
#  '30 입니다.',
#  '거기 역사적인곳이져?',
#  '서울 어린이 대공원은 역사적인 곳이라고 볼 수는 없습니다.',
#  '아 그렇군여.',
#  '다른 도움 필요하신건 없으세요?',
#  '온김에 여기저기 가보려구요.',
#  '일단 이쪽에 적당한 가격의 맛난 일식당이 있을까요?',
#  '제가 뚜벅이라 걸어서 갈 수 있어야 되구요.',
#  '시청역의 라멘 맛집 회오리라멘 어떠실까요?',
#  '역에서 도보 3분 거리로 가깝습니다.',
#  '네 가깝고 좋네요.',
#  '흡연석은 있을까요?',
#  '흡연석은 따로 없는 걸로 확인됩니다.',
#  '아 네 확인 감사해요.',
#  '글구 식당 가까이에 기타 타입의 관광지가 있을까요?',
#  '역시 걸어서 갈 수 있어야 되구요.',
#  '충무로역에서 도보 2분이면 도착하는 한국의 집은 어떠실까요?',
#  '입장료도 2천원으로 저렴한 편입니다.',
#  '네 괜찮겠네요.',
#  '그럼 경치가 좋은 곳은 아니겠네요?',
#  '네 맞습니다.',
#  '더 필요하신 거 있으세요?',
#  '네 마지막으로 지하철 정보만 좀 찾을게요.',
#  '요금이랑 도착지 라인이 어떻게 되는지도 좀 알려주세요.',
#  '도착지 라인은 6호선입니다.',
#  '더 확인하실 부분 있으실까요?',
#  '아아 다 됐습니다.',
#  '네 이용 감사합니다.',
#  '제가 비싼 한식당을 찾고 있는데요.',
#  '원하시는 지역이 있을까요?',
#  '서울 내에 있으면 되요.',
#  '아 주차는 가능해야해요.',
#  '4곳이 검색되는데 다른 조건은 없을까요?',
#  '없는데.',
#  '추천해주시겠어요?',
#  '그럼 제가 추천해드리겠습니다.',
#  '평점 4.',
#  '3점에 압구정역 근처에 있는 식객이라는 한식당을 추천드립니다.',
#  '네 좋네요.',
#  '그럼 화요일 07시50분에 5명 예약 가능할까요?',
#  '진행할까요?',
#  '네 예약 해주시고 예약 번호와 라스트 오더 시간도 알려주세요.',
#  '예약되셨습니다.',
#  '이고 라스트 오더 시간은 22시입니다.',
#  '이용해 주셔서 감사합니다.',
#  '무엇을 도와드릴까요?',
#  '생각하신 가격대와 지역이 있으신가요?',
#  '서울 중구에 위치한 친구를 만나느라 샵샵샵이 있습니다.',
#  '어떠신가요?',
#  '금요일 16시20분에 4명 예약해주시겠어요?',
#  '예약 완료되셨습니다.',
#  '입니다.',
#  '궁금하신점 있으신가요?',
#  '영업시간은 몇시인가요?',
#  '00입니다.',
#  '더 필요하신점 있으신가요?',
#  '서울 서쪽에 위치한 곳으로요.',
#  '선호하시는 숙소종류가 있으신가요?',
#  '아뇨 괜찮습니다.',
#  '진하우스라는 에어비엔비가 있습니다.',
#  '죄송합니다.',
#  '5일까지는 예약이 잡이지 않아 기간을 변경해야 할것 같은데 어떻게 해드릴까요?',
#  '일요일 3명 하루 예약 완료되었습니다.',
#  '궁금하신 사항 있으신가요?',
#  '거기 수영장은 있나요?',
#  '아쉽게도 진하우스에는 수영장을 운영하지 않습니다.',
#  '주소는 서울 마포구 10506 입니다.',
#  '더 궁금하신 점 있으신가요?',
#  '없어요.',
#  '이용해주셔서 감사합니다.',
#  '식당이랑 관광할 곳을 알아보려고 하거든요.',
#  '지역을 말씀해주시면 찾아드리겠습니다.',
#  '가격은 상관없고요.',
#  '인터넷을 계속 써야 되서 인터넷 되는 곳으로 좀 찾아주세요.',
#  '신촌역 부근의 피에르 오뎅 확인됩니다.',
#  '예약해드릴까요?',
#  '아 그럼 일요일 10시 10분에 2명으로 부탁드릴게요.',
#  '식당 주소랑 도보가 가능한지도 궁금하네요.',
#  '도보도 가능합니다.',
#  '관광지는 어떤 곳으로 찾으실까요?',
#  '아 네 식당 가까이에 쇼핑할 곳으로 찾는데요.',
#  '신도림역의 디큐브시브는 어떠세요?',
#  '역에서 도보 2분 거리로 가깝고 입장료는 9000원입니다.',
#  '아 괜찮네요.',
#  '마지막으로 디큐브시브 거기서 15시 30분에 출발가능한 택시도 좀 부탁드릴게요.',
#  '택시 종류도 말씀 부탁드립니다.',
#  '일단 그렇게만 결정한거라 일단 다른 조건은 안 넣고 찾아주시겠어요?',
#  '네 알겠습니다.',
#  '택시 조회되네요.',
#  '요금은 5천원입니다.',
#  '확인이 다 되셨을까요?',
#  '아 네 물어볼걸 다 말씀해주셨네요.',
#  '저 디큐브시브에 가려는데 궁금한게 있어요.',
#  '네 어떤게 궁금하신가요?',
#  '평점이랑 그 곳 경치가 좋은지요.',
#  '먼저 평점은 4점입니다.',
#  '그리고 경치는 좋지 않다고 쓰여있습니다.',
#  '아 그래요?',
#  '그래도 뭐 가긴 갈꺼라서.',
#  '영업시간 좀 알려주세요.',
#  '디큐브시브의 영업시간은 09시30분 부터 17시 30분까지 입니다.',
#  '더 궁금하신 사항 있으신가요?',
#  '아뇨 없습니다.',
#  '흡연 가능한 곳으로 찾아주세요.',
#  '생각하시는 금액대가 있으신가요?',
#  '정모텔이있습니다.',
#  '사당역에서 도보 7분입니다.',
#  '어떠세요?',
#  '좋아요 수요일 4일간 10명 예약되나요?',
#  '수요일은 이용불가합니다.',
#  '다른 요일을 말해주세요.',
#  '월요일도 괜찮습니다.',
#  '예약 번호는 AMWN4입니다.',
#  '더 궁금한 점이 있으세요?',
#  '없습니다.',
#  '처음으로 서울에 놀러왔는데 무작정 온거라 숙소를 예약 못해서요.',
#  '도와주시겠어요?',
#  '가격대를 말씀해주시면 안내해드리겠습니다.',
#  '제가 지금 서울 서쪽에 있어서 이 쪽에 있는 숙소였으면 합니다.',
#  '가격은 저렴한 곳으로 조식 제공되면 종류는 뭐든 괜찮아요.',
#  '그럼 마포구에 심미 호스텔이 조식 제공되는 곳인데 괜찮으실까요?',
#  '근데 제가 이동하기 쉽게 지하철역 근처에 있는 곳이었으면 하는데 역 근처에 있나요?',
#  '월드컵경기역에서 도보 3분 거리에 있습니다.',
#  '와 가깝네요.',
#  '그럼 오늘부터 7일간 머무를건데 예약해주세요.',
#  '저 혼자입니다.',
#  '예약 진행해드렸습니다.',
#  '예약 번호는 GNVM0입니다.',
#  '더 필요한건 없으세요?',
#  '서울 관광 좀 하다가 9시 40분쯤 숙소로 가려고 하는데 택시도 알아봐주시겠어요?',
#  '출발하시는 곳과 도착 시간을 말씀해주시면 안내해드리겠습니다.',
#  '제가 계속 이동 중이고 여기 뭐가 있는지 잘 몰라서 어디서 출발해야할지 모르겠어요.',
#  '9시 40분에 출발하는 택시가 있으면 그쪽으로 제가 이동하겠습니다.',
#  '원하시는 택시 종류는 따로 있으세요?',
#  '아니요.',
#  '종류 상관없습니다.',
#  '그럼 9시 40분에 예술의전당에서 출발하는 고급 택시가 있는데 이 택시를 이용하시면 될 것 같습니다.',
#  '소요 시간 45분으로 심미 호스텔에 10시 25분쯤 도착하실거예요.',
#  '기사님 전화번호는 06379810254 이니 출발지에서 기사님께 연락하시면 됩니다.',
#  '그렇게 하도록 할게요.',
#  '제가 더 도와드릴건 없나요?',
#  '이제 괜찮습니다.',
#  '문의하실게 있으시면 언제든 다시 연락 주세요.',
#  '서울 북쪽에 있는 저렴한 가격대의 호스텔을 알아봐주세요.',
#  '동문 호스텔 이라는 곳 어떠세요?',
#  '1 입니다.',
#  '금요일부터 3일동안 2명이 머무를 예정이에요.',
#  '예약 해주세요.',
#  '예약이 되었습니다.',
#  '예약 번호는 FBOI4 입니다.',
#  '네 감사해요.',
#  '그리고 경복궁의 입장료랑 영업 시간 그리고 주소도 알아봐주세요.',
#  '입장료는 9000원 입니다.',
#  '00 로 나오네요.',
#  '주소는 서울 종로구 05481 입니다.',
#  '전화 번호도 알려주세요.',
#  '전화번호는 108270327 입니다.',
#  '다른 궁금하신 사항이 더 있으세요?',
#  '하나만 더 부탁드려요.',
#  '서울 중앙에 있는 저렴한 한식당 중에서 괜찮은 곳 알아봐주세요.',
#  '돼지조아소조아 라는 식당 어떠세요?',
#  '찾아보니 좋네요.',
#  '숙소를 예약한 날에 15시로 3명 예약 해주세요.',
#  '아 그런데 주차가 가능한 식당인가요?',
#  '예약 번호는 ACKW6 입니다.',
#  '주차가 가능한 식당입니다.',
#  '그렇군요.',
#  '덕분에 편하게 알아봤네요.',
#  '다음에 또 이용할께요.',
#  '정모텔이라는 이름의 숙소 주소랑 전화번호를 알고 싶어서 문의드려요.',
#  '전화번호는 7269223521입니다.',
#  '또 하나 더 있는데요.',
#  '서울 중앙에 랜드마크가 있나요?',
#  '서울 중앙에는 남산골 한옥 마을이 대표적인 랜드마크 입니다.',
#  '거긴 역에서 얼마나 걸려요?',
#  '지하철 충무로역에서 도보로 3분정도 소요됩니다.',
#  '정보 감사합니다.',
#  '다른 궁금하신 점 있으세요?',
#  '다른건 없습니다.',
#  '관광지 좀 찾고싶은데요.',
#  '숙소부터 도와드릴게요.',
#  '지역을 말씀해주시면 됩니다.',
#  '아 네 서울 북쪽에 가격은 적당한 데로 게스트 하우스면 괜찮아요.',
#  '죄송하지만 가격대 변경을 하셔야 할 거 같습니다.',
#  '조회가 안되네요.',
#  '그래요 그면 저렴한 데는 있어요?',
#  '네 저렴한 곳은 확인됩니다.',
#  '명동역 부근의 인터넷 제공되는 호두나무집인데요.',
#  '예약하시겠어요?',
#  '네 할게요.',
#  '일요일부터 이틀 있으려구요.',
#  '예약완료되셨습니다.',
#  '궁금한 점 있으세요?',
#  '식당도 찾아주세요.',
#  '네 확인됩니다.',
#  '같은 날 같은 인원이구요.',
#  '14시 10분으로 해주세요.',
#  '네 원하시는대로 예약되셨습니다.',
#  '관광지는 어떤 곳으로 찾으시나요?',
#  '아 서울 중앙쪽에 공원으로요.',
#  '있나요?',
#  '여의나루역에서 도보 2분 거리의 여의도 한강공원입니다.',
#  '도보는 가능한거고.',
#  '문화 예술이랑 관련있나요?',
#  '문화 예술과는 관련이 없는 곳입니다.',
#  '이제 없어요.',
#  '즐거운 여행 되세요.',
#  '친구들이랑 서울 남쪽에 있는 주점을 가볼까 해요.',
#  '괜찮은곳으로 예약 좀 부탁드릴게요.',
#  '가격대는 어느정도로 생각하세요?',
#  '애들이랑 나눠서 낼꺼라 가격 상관없이 알아봐주세요.',
#  '그럼 적당한 가격대의 이기자카야를 추천해 드립니다.',
#  '3으로 남쪽에서 꽤 유명한 주점입니다.',
#  '오 그래요?',
#  '그럼 토요일 4시20분에 9명으로 예약할게요.',
#  '워낙 유명한 곳이다보니 토요일은 이미 예약이 마감된 것으로 확인되는데 다른 요일도 괜찮으세요?',
#  '우와 역시.',
#  '그럼 일요일은 가능할까요?',
#  '일요일은 가능합니다.',
#  '일요일 4시20분으로 진행해 드릴까요?',
#  '그렇게 해주세요.',
#  '알려주신 정보대로 예약 해 드렸습니다.',
#  '관련해서 필요하신 사항 있으실까요?',
#  '찾아가야되니까 주소도 알려주세요.',
#  '예약번호는 VHRD4이고 주소는 서울 서초구 46141입니다.',
#  '그리고 이번에는 중앙쪽에서 괜찮은 게스트 하우스도 찾아봐 주세요.',
#  '숙소의 가격대는 어떻게 알아봐드릴까요?',
#  '숙소도 가격대는 상관없이 알아봐 주시고 애들이랑 게임하는게 큰 목적이라 원할하게 인터넷 이용이 가능한 곳으로 부탁드려요.',
#  '말씀하신 조건으로는 동키 게스트 하우스와 서촌 한옥 게스트하우스가 괜찮아 보입니다.',
#  '둘 다 저렴한 가격대의 숙소 입니다.',
#  '그중에서 평점 더 높은데로 예약해주세요.',
#  '서촌 한옥 게스트하우스가 4.',
#  '7점의 높은 평점을 자랑하는것으로 확인되는데 여기로 예약 도와 드리면 될까요?',
#  '인원수도 함께 말씀해 주시면 예약 도와 드리겠습니다.',
#  '아 참.',
#  '그게 애들이 많아서 아직 일정 조율중인데 정해진게 하나도 없어서 다 미정으로 우선 예약 부탁드릴게요.',
#  '숙소는 그럼 투숙 정보는 설정하지 않고 도와 드리겠습니다.',
#  '숙소도 예약번호 필요하신가요?',
#  '예약번호 주시고 가까운 지하철역도 알려주세요.',
#  '숙소 예약번호는 IMAO2입니다.',
#  '종각역 부근에 위치하고 있는 숙소이구요.',
#  '그리고 마지막으로 관광지 문의도 드릴게요.',
#  '서울에서 역사적인 곳이 어디에요?',
#  '관광지의 지역과 종류는 어떻게 알아봐드릴까요?',
#  '잘 모르겠어요.',
#  '가장 괜찮은 곳으로 추천해 주시면 안될까요?',
#  '그러시다면 서울 중앙에 위치한 랜드마크 타입의 관광지인 남산골 한옥 마을 어떠세요?',
#  '재밌을꺼 같네요.',
#  '주소도 알 수 있을까요?',
#  '주소는 서울 중구 85530입니다.',
#  '정말 많이 도움됐어요.',
#  '또 다른 도움 필요하신 부분은 없으신가요?',
#  '네 이제 없어요.',
#  '서울 남쪽에 저렴한 숙소를 찾고 있습니다.',
#  '원하시는 숙소 종류가 있으신가요?',
#  '주차 가능한 곳이면 어디든 괜찮습니다.',
#  '그럼 서초구에 고속터미널 싱글 원룸이라는 에어비엔비가 있는데 여기 어떠세요?',
#  '조식도 제공되는 곳입니다.',
#  '저렴한데 조식도 준다니 좋네요.',
#  '그럼 거기로 갈게요.',
#  '일요일 하루만 예약해주세요.',
#  '저 혼자 갈겁니다.',
#  '예약되었습니다.',
#  '예약 번호는 WGLI1입니다.',
#  '서울 중앙에 일이 있어 가는 김에 그 쪽에서 교통편 관광지도 다녀오려고 하는데 어디로 가면 될까요?',
#  '서울 중앙에 교통편을 찾으시면 남산 케이블카가 있는데 여기 어떠세요?',
#  '그럼 아까 예약한 숙소에서 남산 케이블카로 가는 택시를 알아봐주세요.',
#  '출발 시간과 원하시는 택시 종류를 말씀해 주시면 안내해드리겠습니다.',
#  '4시 30분에 출발할건데 택시 종류는 아무거나 괜찮아요.',
#  '그럼 4시 30분에 출발하여 4시 45분에 남산 케이블카에 도착하는 에코 택시가 있는데 이 택시를 이용하시겠어요?',
#  '그거 탈게요.',
#  '출발지에서 택시를 못 찾으시면 기사님께 연락하셔서 만나시면 됩니다.',
#  '그럼 더 필요한건 없으세요?',
#  '이제 다 됐어요.',
#  '그럼 이용해 주셔서 감사합니다.',
#  '주소좀 알려주세요.',
#  '30이고 입장료는 5000원입니다.',
#  '주소는 서울 서대문구 40352입니다.',
#  '그리고 요기할만한 식당으로 서울 중앙에 있는 한식당으로 가격 상관없이 알아봐 주세요.',
#  '맥주도 한잔 할까해서 주류를 판매하는 곳으로 알아봐 주세요.',
#  '돼지조아소조아 등의 식당이 검색되었습니다.',
#  '이 중에서 마음에 드는곳이 있으세요?',
#  '거기 평점이랑 역에서 걷는 시간도 알려주세요.',
#  '돼지조아소조아에서 식사하실 수 있도록 예약 잘 도와 드렸습니다.',
#  '해당 식당의 평점은 3.',
#  '1점이고 역에서 걷는 시간은 7분입니다.',
#  '그리고 서울 북쪽에서 숙소도 찾아봐 주세요.',
#  '비싼 에어비엔비로요.',
#  '체리라는 평점 4.',
#  '5점의 에어비엔비가 있는데 한번 가 보시겠어요?',
#  '네 가볼게요.',
#  '화요일 하루 4명으로 예약해 주세요.',
#  '흡연이 가능한지도 같이 알아봐 주세요.',
#  '말씀하신대로 체리에 예약 해 드렸습니다.',
#  '흡연은 가능하지 않은 호텔로 확인됩니다.',
#  '또 다른 문의 사항 있으실까요?',
#  '아 네.',
#  '잘 알겠습니다.',
#  '다른 궁금한건 이제 없어요.',
#  '도와주셔서 감사합니다.',
#  '여보세요?',
#  '애들하고 갈만한 박물관에 대해 안내받으려고 전화드렸어요.',
#  '네 반갑습니다.',
#  '박물관말씀이시죠.',
#  '원하시는 지역은 어디신가요?',
#  '서울 북쪽에 있는 교육에 도움이 되는 곳으로 알아봐주세요.',
#  '말씀하신 조건에 서울 역사 박물관이 가장 평점이 높습니다.',
#  '이곳으로 안내드릴까요?',
#  '네 좋은것 같아요.',
#  '거기 주소를 알려주세요.',
#  '아 그리고 입장료는 얼마에요?',
#  '네 주소는 서울 종로구 75461이며 입장료는 2000원입니다.',
#  '그리고 숙소는 좀 비싸도 서울 중앙에 있는 괜찮은 호텔로 예약하고 싶어요.',
#  '네 그렇다면 종로구에 위치한 프리미어호텔이 있습니다.',
#  '이곳으로 예약해드릴까요?',
#  '좋습니다.',
#  '그럼 금요일부터 2일동안 8명이 묵을수 있도록 예약해주세요.',
#  '네 예약되었습니다.',
#  '네 고맙습니다.',
#  '그리고 숙소 근처에 괜찮은 한식당도 예약하고 싶어요.',
#  '가격대는 상관없으신가요?',
#  '좀 가격대가 있는곳이면 좋겠습니다.',
#  '그리고 주차가 돼야해요.',
#  '말씀하신 조건에 평점이 가장 높은 식당은 외계인의 맛집이라는 곳입니다.',
#  '이곳은 어떠실까요?',
#  '그럼 거기로 예약할게요.',
#  '45에 8명이 식사할수 있는 자리로 해주세요.',
#  '거기 대표메뉴가 뭔가요?',
#  '그리고 주차는 가능하겠죠?',
#  '네 대표메뉴는 한정식이고 주차 가능하십니다.',
#  '네 안녕하세요 원하시는 지역은 있으신가요?',
#  '네 총4건 뜨시는데 용산구 소재의 역사적 교육적 가치가 높은 서울중앙성원은 어떠세요?',
#  '아 네네 괜찮네요 거기 입장료도 있죠?',
#  '네 입장료는 따로 없고 주소는 서울 용산구 14155입니다.',
#  '더 궁금하신 점 있으세요?',
#  '명수를 알 수 있을까요?',
#  '예약 도와드렸습니다.',
#  '궁금하신 점 있으신가요?',
#  '가격대는 저렴한 편이고 스파는 없습니다.',
#  '생각하고 계신 출발시간이랑 택시종류가 있으신가요?',
#  '고급 택시를 찾았습니다.',
#  '소요시간은 45분입니다.',
#  '질문 더 있으실까요?',
#  '오늘도 좋은 하루 보내세요.',
#  '경치가 좋은 관광지를 찾아주세요.',
#  '지역이랑 종류는 상관없어요.',
#  '여러 곳이 있습니다.',
#  '그중 입장료 7000원인 하늘공원을 추천드리는데 어떠세요?',
#  '근처 역은 어디인가요?',
#  '역에서 걸어서 얼마나 걸리나요?',
#  '근처 역은 월드컵경기장역입니다.',
#  '역에서 걸어서 16분 소요됩니다.',
#  '회오리라멘의 근처 역은 어디인가요?',
#  '28에 2명 예약해주세요.',
#  '시청역입니다.',
#  '관광지 근처 역에서 식당 근처 역으로 가는 지하철의 요금을 알려주세요.',
#  '1250원입니다.',
#  '제가 더 도울 일이 있을까요?',
#  '서울 아무곳이나 경치가 좋은 공원을 하나 추천해 주시겠어요?',
#  '서울의 경치 좋은 공원으로 총 9곳이 있는데 하늘공원은 어떠신가요?',
#  '평점도 높고 주변에 다른 관광지도 많아 추천 드립니다.',
#  '그러면 하늘공원 거기 주소하고 평점을 알려주세요.',
#  '하늘공원의 주소는 서울 마포구 45152 이고 평점은 4.',
#  '5점 입니다.',
#  '그리고 서울 북쪽에 있는 적당한 가격대의 헬스장이 있는 호텔도 검색해 주세요.',
#  '서울 북쪽의 적당한 가격대의 호텔로 오미야게 호텔은 어떠신가요?',
#  '혜화역에 위치해 접근성이 좋은 호텔 입니다.',
#  '네 그럼 거기로 예약 부탁 드려요.',
#  '화요일 부터 5일간 5명으로요.',
#  '요청하신 조건으로 오미야게 호텔 예약 번호 IRSO2로 예약 완료 했습니다.',
#  '궁금하신 사항이 있으신가요?',
#  '그러면 그 숙소 근처의 지하철역에서 서울역으로 가는 노선이 뭐가 있나요?',
#  '숙소근처의 혜화역에서 서울역으로 가신다면 4호선을 이용해 환승없이 가시면 됩니다.',
#  '시간은 얼마나 걸리죠?',
#  '16분 소요 됩니다.',
#  '더 궁금하신 사항은 없으신가요?',
#  '이용 감사합니다.',
#  '좋은 하루 되세요.',
#  '서울 중앙에 있는 야외석 있는 일식당이 있을까요?',
#  '원하시는 가격대가 있을까요?',
#  '가격은 상관 없어요.',
#  '주차장 있으면 좋겠네요.',
#  '이라는 가게 한 곳이 있습니다.',
#  '27에 두명 예약해주세요.',
#  '그 요일에는 예약이 불가하세요.',
#  '금요일에 예약해주세요.',
#  '가장 가까운 지하철 역은 어디에요?',
#  '예약해드렸습니다.',
#  '명동역에서 가장 가까워요.',
#  '그리고 택시를 예약하고 싶은데요.',
#  '오동통규동동에서 심미호스텔로 가고 싶어요.',
#  '57까지 도착해야해요.',
#  '출발시간은 언제로 하시겠어요?',
#  '택시 종류도 고르실 수 있어요.',
#  '둘다 지금은 설정안할게요.',
#  '기사님 전화번호만 알려주세요.',
#  '기사님 전화번호는 04236859017입니다.',
#  '택시 종류는 무엇이에요?',
#  '종류는 개인입니다.',
#  '또 무엇을 도와드릴까요?',
#  '인터넷이 되는 호텔을 찾아주세요.',
#  '원하시는 가격대가 있으세요?',
#  '가격은 상관없습니다.',
#  '2곳이 있습니다.',
#  '그중 역에서 더 가까운 에버뉴 호텔을 추천드리는데 어떠세요?',
#  '네좋아요.',
#  '목요일에 3명 2일동안 예약될까요?',
#  '네 해주세요.',
#  '가까운 역은 어디인가요?',
#  '영업시간은요?',
#  '건대입구역입니다.',
#  '서울 남쪽에 흡연이 가능한 비싼 한식당을 찾고있어요.',
#  '식객이 있습니다.',
#  '대표메뉴 한정식인 곳인데 어떠세요?',
#  '맘에드네요.',
#  '30에 예약되나요?',
#  '네 가능한데 예약 도와드릴까요?',
#  '예약 번호와 전화번호 알려주세요.',
#  '전화번호는 4903129156입니다.',
#  '사차원주머니라는 식당을 찾고 있는데요.',
#  '가격대와 주류 판매 여부가 궁금합니다.',
#  '가격대는 적당한 가격대로 만원대 정도 예상되며 주류는 판매하지 않는 것으로 확인됩니다.',
#  '아 알겠습니다.',
#  '저 그리고 서울 중앙에 위치한 박물관을 찾고 있는데요.',
#  '한 곳 좀 추천 해주실 수 있나요?',
#  '혹시 서울 용산구에 위치한 평점 4.',
#  '5의 삼성미술관 리움은 어떠신가요?',
#  '아 여기 전시는 진짜 괜찮다고 들었어요.',
#  '방문해보고 싶은데 입장료와 전화번호 좀 알려주세요.',
#  '입장료는 4천원이며 전화번호는 2424244346입니다.',
#  '추가로 궁금하신 점 있으신가요?',
#  '확인 감사드려요.',
#  '머니볼 숙소에 수요일 1일동안 한명 예약해주세요.',
#  '주소랑 가장 가까운 지하철역 좀 알려주세요.',
#  '예약 번호도 알려주시겠어요?',
#  '국회의사당역에서 가깝습니다.',
#  '예약 번호는 KVUE7 입니다.',
#  '인터넷이 되는 곳이에요?',
#  '조식도 주나요?',
#  '조식은 제공되지 않습니다.',
#  '숙소랑 같은 위치의 관광지도 알려주세요.',
#  '관광 종류는 원하시는 것이 있으실까요?',
#  '다 상관 없어요.',
#  '이 평점도 4.',
#  '5고 역에서도 가깝습니다.',
#  '가장 가까운 지하철역은 어디세요?',
#  '영업 시간도 알려주세요.',
#  '에서 가장 가까운 지하철역은 어디에요?',
#  '지역하고 영업시간 알 수 있을까요?',
#  '서울 중앙 지역에 위치하고 있습니다.',
#  '30 동안 하고 있습니다.',
#  '궁금하신 것 또 있으실까요?',
#  '더 없어요.',
#  '동창들이랑 역사적인 곳으로 관광을 가려고 하는데 어디가 좋을까요?',
#  '선호하시는 종류와 지역이 어떻게 되세요?',
#  '저희는 어디든지 좋아요.',
#  '그러시면 교육적인 곳으로 안내해드릴까요?',
#  '굳이 그렇지는 않아도 돼요.',
#  '감남구에 선릉과 정릉이 적합하실것 같은데 어디가 괜찮으세요?',
#  '한옥 마을 구경하면 좋을 것 같네요.',
#  '여기로 가볼게요.',
#  '근데 중구면 지역이 어디인거죠?',
#  '남산골 한옥 마을은 서울 중앙에 있습니다.',
#  '아 중앙쪽이구나.',
#  '거기 상세 주소는 어떻게 되나요?',
#  '더 궁금하신건 없으세요?',
#  '알려주셔서 감사합니다.',
#  '그럼 친구분들과 즐거운 시간 보내시길 바랍니다.',
#  '서울 북쪽에 주차 가능한 관광지 추천해주세요.',
#  '종류는 상관 없어요.',
#  '여러 곳이 있어서요.',
#  '그리고 서울중앙에 한식당도 찾고 있어요.',
#  '이럴순없는대라는 곳이 있습니다.',
#  '25에 7명 예약해주세요.',
#  '예약번호 알려주세요.',
#  '예약번호는 VNYO1입니다.',
#  '또 궁금하신 것 있으세요?',
#  '식당 예약 좀 도와주세요.',
#  '예약 도와드리겠습니다.',
#  '혹시 생각해두신 식당이 있으신가요?',
#  '연인이랑 특별한 날에 가려고 하는데 어디가 좋을지 모르겠어서요.',
#  '야외석이 있는 양식당이 괜찮을것 같은데 어디가 좋을까요?',
#  '그럼 원하시는 지역과 가격대는 어떻게 되세요?',
#  '지역은 상관없고 비싸고 좋은 곳으로 가려구요.',
#  '조건에 맞는 곳이 강남구에 있는 팁 앤 스테이크와 강서구에 있는 피렌체의밤 이렇게 두 곳이 있는데 어디가 좋으세요?',
#  '강남구에 있는게 가기 좋을것 같네요.',
#  '거기로 목요일 20시 30분에 2명 예약이 가능한가요?',
#  '죄송하지만 목요일은 예약이 안되네요.',
#  '다른 날은 안되시나요?',
#  '그러면 화요일은 될까요?',
#  '화요일은 가능합니다.',
#  '예약 하시겠어요?',
#  '예약하고 예약번호랑 가까운 지하철역 좀 알려주세요.',
#  '예약 완료되셨구요.',
#  '가까운 지하철역은 강남역입니다.',
#  '더 필요하신거 있으세요?',
#  '행복한 시간 보내십시오.',
#  '서울에서 뭐하고 놀지 고민중인데 평점 4점이상인 기타 타입의 관광지가 있을까요?',
#  '생각하시는 지역이 있으신가요?',
#  '그건 딱히 없어요.',
#  '그럼 평점 4점의 이화 벽화마을은 어떠세요?',
#  '오 색다른 곳이네요.',
#  '거기 경치도 좋아요?',
#  '경치는 아쉽게도 좋지는 않습니다.',
#  '그렇구나.',
#  '그리고 인터넷 잘되는 중식당도 알아봐 주세요.',
#  '식당도 지역이나 가격대는 상관 없으신가요?',
#  '네 상관없어요.',
#  '그러시다면 엄중식이라는 곳을 추천해 드립니다.',
#  '가격대는 비싼곳이지만 평점 4.',
#  '3에 대표 메뉴로 탕수육을 판매하는 곳입니다.',
#  '탕수육 맛있겠네요.',
#  '월요일 12시50분에 4명으로 예약해주세요.',
#  '말씀하신대로 엄중식에 식사 예약 해 드렸습니다.',
#  '예약번호 필요하신가요?',
#  '예약번호랑 주소도 알려주세요.',
#  '예약번호는 OFXZ9이고 주소는 서울 강북구 86033입니다.',
#  '또 다른 도움 필요하신건 없으세요?',
#  '네 없어요.',
#  '안녕하세요 제가 특정 관광지 정보가 필요한데 여쭤보면 확인 가능하신가요?',
#  '어떤 관광지인지 말씀 주시면 확인 도와 드리겠습니다.',
#  '우와 신기하네요.',
#  '한국의 집의 어떤 정보가 필요하신가요?',
#  '아 참 거기 평점이랑 영업시간이랑 그리고.',
#  '영업 시간은 오전 10시부터 오후 6시 까지 입니다.',
#  '특별히 경치가 좋은곳은 아닙니다.',
#  '아아 그렇군요.',
#  '암튼 정보 주셔서 감사합니다.',
#  '네 다 여쭤봤어요.',
#  '서울 북쪽에 친구랑 묵을 모텔을 예약하려구요.',
#  '생각하시는 가격대가 어떻게 되세요?',
#  '가격은 상관없는데 흡연이 가능해야합니다.',
#  '그럼 동대문구에 있는 힐 모텔 서울과 성동구에 있는 모텔 킹 중에서 어디가 괜찮으실까요?',
#  '성동구가 괜찮네요.',
#  '모텔 킹에 토요일부터 5일 예약해주세요.',
#  '인원은 5명이 갈거예요.',
#  '죄송하지만 토요일은 예약이 안되는데 다른 날은 안되시나요?',
#  '그럼 화요일은 되나요?',
#  '가능하면 화요일로 예약하고 주소 알려주세요.',
#  '화요일은 가능하여 화요일로 예약해드렸습니다.',
#  '주소는 서울 성동구 58673입니다.',
#  '예약 번호는 UHPR8이니 참고해주세요.',
#  '친구 결혼식 전날 미리 서울에 올라왔는데 식사할 곳이랑 묵을 곳을 찾고 있어요.',
#  '원하시는 조건을 말씀해주시면 거기에 맞춰서 도와드리겠습니다.',
#  '그럼 숙소 들어가기 전에 식사할 만한 곳 먼저 알아봐 주세요.',
#  '서울 동쪽에 있는 비싼 가격대의 중식당으로 부탁드려요.',
#  '그런 곳으로는 홀럭키하우스라는 중식당이 있습니다.',
#  '그럼 거기로 예약해 주시겠어요?',
#  '금요일 18시 40분에 4명이 갈꺼에요.',
#  '말씀하신 대로 숙사 예약해 드렸습니다.',
#  '그럼 숙소는 서울 서쪽으로 알아볼게요.',
#  '비싼 가격대의 에어비앤비로 알아봐 주세요.',
#  '서쪽으로 알아보신다면 평점 4.',
#  '7점의 쉼 인 서울이라는 에어비엔비를 추천해 드립니다.',
#  '그럼 거기로 토요일부터 이틀간 9명으로 예약할게요.',
#  '쉼 인 서울에 묵으시는 것으로 예약해 드렸습니다.',
#  '근처 지하철역은 어디에요?',
#  '홍대입구역입니다.',
#  '아 그러면 그 역에서 음.',
#  '사람들이 가장 많이 가는 역은 어디에요?',
#  '을지로4가역이 볼 것도 많고 관광하기 좋아 인기가 많습니다.',
#  '요새 또 을지로가 핫해서 사람들이 많이 가는 편입니다.',
#  '홍대입구역에서 환승없이 14분만에 갈 수도 있습니다.',
#  '친절히 말씀해주셔서 감사합니다.',
#  '더 필요하신 정보 있으신가요?',
#  '서울로 여행 왔는데 서울 중앙쪽에 있는 모텔로 저렴한데로 알아봐 주세요.',
#  '해당 조건에 맞는 숙소는 확인되지 않아서 다른 가격대로 찾아봐 드려도 괜찮으실까요?',
#  '아 그럼.',
#  '비싼 가격대는 있을까요?',
#  '비싼 가격대로는 야드 서울이라는 숙소가 확인됩니다.',
#  '평점 3점의 모텔입니다.',
#  '생각보다 평점이 좋지는 않네요.',
#  '거기밖에 없는거죠?',
#  '서울 중앙에서는 해당 숙소만 검색되고 있습니다.',
#  '할 수 없네요.',
#  '거기로라도 예약해주세요.',
#  '월요일 하루 묵을꺼고 인원은 총 8명이에요.',
#  '야드 서울에 월요일 하루 투숙 하시는 일정으로 예약 해 드렸습니다.',
#  '같은 서울 중앙 지역에서 비싼 가격의 일식당도 찾고 있는데 어디가 좋을까요?',
#  '믿고맡기는초밥이라는 오마카세 전문점이 서울 중앙에 있습니다.',
#  '평점도 4.',
#  '5로 매우 높은 곳입니다.',
#  '오 거기 마음에 드네요.',
#  '거기도 월요일에 8명으로 14시반에 예약해 주세요.',
#  '믿고맡기는초밥에서 식사 하실 수 있게 예약 해 드렸습니다.',
#  '또 필요한 사항 있으세요?',
#  '식사 후엔 일행이랑 관광을 좀 할려구요.',
#  '서울 중앙에 랜드마크 관광지 괜찮은곳이 있을까요?',
#  '5점의 서울중앙성원에 가보시는 것을 추천합니다.',
#  '거긴 도보로 도착 가능한곳이에요?',
#  '지하철역에서 도보로 이동 가능하십니다.',
#  '그럼 문화 예술을 관람할 수 있는 곳이기도 해요?',
#  '그렇지는 않은것으로 확인됩니다.',
#  '한번 가볼게요.',
#  '또 다른 문의사항이나 도움 필요하신 부분 있으세요?',
#  '다른건 없어요.',
#  '이용 감사드립니다.',
#  '영업시간을 알려주세요.',
#  '30입니다.',
#  '관광지와 같은 지역에 한식당이 있을까요?',
#  '가격대는 상관없습니다.',
#  '그중 평점이 높으며 저렴한 만칠천무한리필을 추천드리는데 어떠세요?',
#  '이름이 만칠천무한리필인가요?',
#  '영업 시간은 어떻게되죠?',
#  '네 이름 맞습니다.',
#  '15시 수요일 10명으로 예약해주세요.',
#  '네 예약되셨습니다.',
#  '더 도와드릴 부분 있을까요?',
#  '저기요.',
#  '즐길거리 중에 주차 가능한 곳을 찾고 싶은데요.',
#  '어느 지역의 즐길거리를 안내해 드릴까요?',
#  '잘 모르겠는데 아무데나요.',
#  '그럼 잠실 야구 경기장을 추천 드립니다.',
#  '서울 동쪽에 위치 해 있습니다.',
#  '야구 좋네요 감사합니다.',
#  '그리고 택시도 예약 되죠?',
#  '출발 시간과 택시 종류를 알려 주시면 예약해 드리겠습니다.',
#  '6시 45분 노원역에 출발해서 13시 까지 혜화역 도착가능한 택시로 아무거나요.',
#  '죄송하지만 도착시간 13시 가능한 택시가 없어가 출발시간만 원하시는 시간에 가능한 택시로 찾아 드려도 될까요?',
#  '네네 그래도 됩니다.',
#  '45에서 노원역 출발 혜화역 도착하는 택시를 예약해 드리겠습니다.',
#  '네 그리고 전화번호 하고 예상 요금도 알려주세요.',
#  '예상 되는 요금은 25000원 입니다.',
#  '저 지금 친구들이랑 서울 왔는데 저녁 먹을 식당 예약 좀 할라고 하거든요.',
#  '네 안녕하세요.',
#  '식당 종류를 말씀해주시면 도와드리겠습니다.',
#  '서울 중앙쪽에 좀 저렴한 데로요.',
#  '종류는 딱히 상관없거든요.',
#  '한 곳 찾았습니다.',
#  '시청역에 인접한 순대국이 대표 메뉴인 이럴순없는대라는 곳입니다.',
#  '네 순대국 좋네요.',
#  '거기 월요일에 18시 30분에 될까요?',
#  '5명이거든요.',
#  '네 말씀주신대로 예약되셨습니다.',
#  '시청역이랑 가깝죠?',
#  '거기 자세한 주소하고 예약 번호 좀 알려주세요.',
#  '주소는 서울 중구 50461이며 예약번호는 BNYA8입니다.',
#  '추가 질문 있으실까요?',
#  '아 이제 없어요.',
#  '고구려 호스텔에서 화요일부터 5일간 한명 예약해주세요.',
#  '로 예약되었습니다.',
#  '그리고 서울 북쪽에 있는 랜드마크에 추천해주세요.',
#  '그럼 신촌역 근처에 있는 이화여자대학교를 추천합니다.',
#  '그 관광지는 도보로 이동가능한가요?',
#  '역사적인 곳인지 경치가 좋은지까지 알려주세요.',
#  '먼저 도보로 이동가능한거리에 있고 역사적인 곳은 아닌것 같습니다.',
#  '경치 또한 안좋은듯 합니다.',
#  '그럼 관광지에서 18시에 출발해서 강남역으로 가는 택시를 찾아주세요.',
#  '네 어떤걸 알려드릴까요?',
#  '요금이랑 소요시간을 알려주세요.',
#  '요금은 3000원이고 소요시간은 15분정도 입니다.',
#  '스타필드 코엑스몰의 영업 시간과 입장료 그리고 주소를 알아봐주세요.',
#  '00 입니다.',
#  '주소는 서울 강남구 70562 입니다.',
#  '감사해요.',
#  '그리고 서울 북쪽에 있는 한식당 중에서 술을 판매하는 곳도 알아봐주세요.',
#  '가격대는 어떻게 할까요?',
#  '술을 판매하는 곳이라면 가격이 어떻게 됐던 괜찮아요.',
#  '닭발먹고오리발내민다 어떠세요?',
#  '5 입니다.',
#  '평점 높은거 보면 괜찮은 곳인가봐요.',
#  '예약 할께요.',
#  '토요일에 01시 30분으로 5명이요.',
#  '예약 번호는 PDAQ9 입니다.',
#  '역에서 걷는 시간이 어떻게 되나요?',
#  '아 맞다.',
#  '호텔도 알아봐야 합니다.',
#  '적당한 가격대로 서울 중앙에 있는 곳으로요.',
#  '7분으로 나옵니다.',
#  '북촌 호텔은 어떠세요?',
#  '평점은 4점 입니다.',
#  '그럼 거기로 식당 예약한 같은 날부터 2일동안 머무는 걸로 2명이요.',
#  '예약 잘 해주세요.',
#  '예약 번호는 EJMT8 입니다.',
#  '흡연이 가능한가요?',
#  '흡연은 불가능합니다.',
#  '학교 과제차 서울에 왔는데 서쪽에 있는 적당한 가격대의 숙소로 알아봐 주세요.',
#  '종류 상관없이 조식 제공하는곳으로 부탁드려요.',
#  '말씀주신 조건으로 검색 결과 평점 4.',
#  '7의 모텔인 아카펠라가 검색되었습니다.',
#  '거기로 그럼 목요일부터 5일동안 5명 예약해주세요.',
#  '말씀하신대로 아카펠라로 숙소 예약 해 드렸습니다.',
#  '가까운 지하철역은 어디에요?',
#  '헬스장이 숙소에 있는지도 알려주세요.',
#  '예약하신 숙소는 홍대입구역 근처에 위치하고 있고 헬스장 시설은 구비하고 있지 않은것으로 확인됩니다.',
#  '그럼 숙소랑 같은 지역에 있는 쇼핑 타입의 관광지도 알려주세요.',
#  '디큐브시브가 서쪽에 위치한 쇼핑 종류의 관광지로 검색되었습니다.',
#  '노량진 수산물 도매시장은 혹시 역사적 의미가 있는곳이에요?',
#  '그런곳은 아닙니다.',
#  '영업시간이랑 요금도 알려주세요.',
#  '영업시간은 9시반에서 17시반까지이고 입장료는 만원입니다.',
#  '마지막으로 숙소에서 말씀하신 관광지로 가는 택시 예약도 해주세요.',
#  '9시반에 출발할꺼고 종류는 아무거나 괜찮아요.',
#  '알려주신대로 택시 예약 해 드렸습니다.',
#  '택시 전화번호도 알려주시겠어요?',
#  '예약해 드린 택시 전화번호는 08513049762입니다.',
#  '더 필요한 사항 있으세요?',
#  '사합니다.',
#  '다른건 괜찮아요.',
#  '저 안녕하세요.',
#  '서울 남쪽에서 식당을 찾고있습니다.',
#  '더 자세한 조건은 없을까요?',
#  '식당 종류라던지 가격대라던지.',
#  '아 그럼 적당한 가격대의 일식당으로 찾아주세요.',
#  '적당한 가격대에 일식당은 없는걸로 나옵니다.',
#  '혹시 식당 종류를 바꾸실 의향이 있으신가요?',
#  '혹시 베이커리도 없을까요?',
#  '있습니다.',
#  '고속터미널역근처 평점4점의 사차원주머니라는 베이커리가 있습니다.',
#  '아 잘됬다.',
#  '그럼 거기로 토요일 18시에 4명 예약 가능할까요?',
#  '그 시간대에는 예약기 불가하다고 합니다.',
#  '시간대를 변경하시겠어요?',
#  '그럼 12시는 가능할까요?',
#  '네 토요일 12시 4명 예약가능합니다.',
#  '그리고 베이커리 전화번호와 제 예약번호도 알려주세요.',
#  '서울 서쪽에 적당한 가격대의 헬스장이 있는 호텔을 찾아주세요.',
#  '더 그레이 호텔이 있습니다.',
#  '인터넷 가능한 곳인데 어떠세요?',
#  '화요일부터 4일동안 1명 예약해 주세요.',
#  '조식 제공하나요?',
#  '전화번호도 알려주세요.',
#  '조식 제공하지 않습니다.',
#  '전화번호는 9936949861입니다.',
#  '서울 서쪽에 적당한 가격대의 인터넷이 가능한 분식집을 알려주세요.',
#  '피에르오뎅이 있습니다.',
#  '오뎅 맛집인데 어떠세요?',
#  '06에 2명 예약해 주세요.',
#  '영업시간 알려주세요.',
#  '야외석은 있나요?',
#  '야외석 없습니다.',
#  '서울숲 역에서 노량진역으로 가는 지하철의 소요 시간과 출발 라인 도착 라인을 알려주세요.',
#  '23분 소요됩니다.',
#  '도착 라인은 1호선입니다.',
#  '질문 더 있으세요?',
#  '문의 좀 할게요.',
#  '국립 민속 박물관에 가려고 하는데 영업 시간을 알려주세요.',
#  '제가 박물관에 갔다와서 근처에서 하루 묵으려고 하는데 박물관이 어느 지역에 있는건가요?',
#  '서울 북쪽지역에 있습니다.',
#  '숙소 예약 도와드릴까요?',
#  '아직 예약을 하려는건 아니라서 일단 알아만 두려구요.',
#  '죄송하지만 그럼 서울 북쪽에 헬스장이랑 수영장이 있는 숙소가 있는지 좀 알려주시겠어요?',
#  '생각하시는 가격대와 숙소의 종류를 말씀해 주시면 안내해드리겠습니다.',
#  '아직 그런것도 생각해두진 않아서요.',
#  '그럼 성동구에 제이 호텔이 있는데 이 곳이 괜찮으실것 같네요.',
#  '더 궁금하신게 있으신가요?',
#  '호텔 주소를 알 수 있을까요?',
#  '주소는 서울 성동구 91461입니다.',
#  '너무 감사합니다.',
#  '그럼 이용해주셔서 감사합니다.',
#  '서울 중앙쪽에 저렴한 식당 아무거나 좀 찾아줘요.',
#  '이럴순없는대 조회됩니다.',
#  '네 목요일 1시 30분으로 8명이요.',
#  '더 필요한 거 있으실까요?',
#  '같은 중앙쪽에 조식 제공되는 데로 찾아줘요.',
#  '비싸도 돼요.',
#  '숙소 종류는 상관없으신가요?',
#  '네 명동역의 프린스 호텔 서울 조회됩니다.',
#  '네 식당이랑 같은 날로 4명 예약해줘요.',
#  '아 식당에서 숙소까지 지하철로 이동할건데 어떻게 가면 되는지 좀 찾아줘요.',
#  '시간 상관없이요.',
#  '네 조회됩니다.',
#  '서울역에서 4호선으로 갈아타시면 되겠습니다.',
#  '더 필요한 정보 있으세요?',
#  '그럼 얼마나 걸리죠?',
#  '네 9분 정도 소요됩니다.',
#  '서울 중앙의 박물관을 찾아 주시고 영업시간 하고 지하철역도 알려 주세요.',
#  '서울 중앙의 박물관은 한국 전쟁 기념관이 있으며 주변에 삼각지역이 위치 해 있습니다.',
#  '그럼 관광지 지하철역에서 천호역까지 오려면 지하철 뭘 타야 하나요?',
#  '삼각지역은 4호선과 6호선이 있고 천호역은 5호선과 8호선이 있으므로 환승을 하셔야 합니다.',
#  '아네네 감사합니다.',
#  '안녕하세요 숙소를 찾고있어요.',
#  '숙소의 종류가 있으신가요?',
#  '여러군데가 뜨는데 그중에 프린스 호텔 서울은 어떠신가요?',
#  '9점이고 수영장과 조식도 이용할 수있습니다.',
#  '좋습니다 토요일 4일동안 4명 예약될까요?',
#  '가능합니다.',
#  '네 주소와 예약 번호는 어떻게 되나요?',
#  '주소는 서울 중구 60927이고 예약 번호는 APMU8입니다.',
#  '더 필요하신 게 있으실까요?',
#  '그러면 서울 서쪽에는 있나요?',
#  '가지가지차이나는 어떠신가요?',
#  '신도림역에서 7분거리로 대표메뉴는 지삼선입니다.',
#  '40에 예약가능한가요?',
#  '예약도와드릴까요?',
#  '주소는 서울 구로구 94375이고 예약번호는 NHTI7입니다.',
#  '즐거운 여행되세요.',
#  '적당한 가격대의 호스텔을 알아보고 있는데요 조식은 제공하지 않는 곳으로 알아봐주세요.',
#  '다이어트중이라.',
#  '숙소의 지역은 어떻게 할까요?',
#  '지역은 크게 상관없습니다.',
#  '괜찮은 곳으로 추천 해주세요.',
#  '고구려 호스텔 어떠세요?',
#  '평점은 2.',
#  '3 이지만 조식을 제공하지 않습니다.',
#  '일요일부터 4일동안 8명 예약 해주세요.',
#  '전화번호도 혹시 모르니 알려주세요.',
#  '예약 번호는 WJAU6 입니다.',
#  '전화번호는 5331312330 으로 나오네요.',
#  '그리고 적당한 가격대의 일식당도 알아봐주세요.',
#  '지역은 서울안으로 알아봐주시면 됩니다.',
#  '회오리라멘 어떠세요?',
#  '평점은 3.',
#  '네 예약 고고 해주세요.',
#  '일요일에 14시30분으로 3명이요.',
#  '가까운 지하철역이 어떻게 되나요?',
#  '현재 일요일에는 예약이 불가능합니다.',
#  '다른 요일로 도와드릴까요?',
#  '가까운 지하철역은 시청역 입니다.',
#  '네 그러면 화요일로 알아봐주세요.',
#  '예약 번호는 WMTF3 입니다.',
#  '네네 그리고 식당 근처 지하철역이 시청역이니까 시청역에서 출바해서 광화문역까지 갈 수 있는 지하철 노선을 좀 알아봐주세요.',
#  '요금은 1250원으로 나오네요.',
#  '참고하세요.',
#  '또 이용할게요.',
#  '안녕하세요 서울 관광지를 보고 있는데요 역사적인 곳이 가고 싶어서요.',
#  '찾아봐 주실 수 있나요?',
#  '네 안녕하세요?',
#  '서울 어느 지역으로 안내 해 드릴까요?',
#  '그냥 서울이면 됩니다.',
#  '그리고 박물관이던 고궁이던 상관없이 다 추천 해 주세요.',
#  '네 검색 결과 남산골 한옥 마을 외 3곳이 있는데 어느곳으로 추천 해 드릴까요?',
#  '제가 지금 명동에 있는데 어디가 가장 가까운가요?',
#  '명동이시라면 충무로 역인 남산골 한옥마을이 가까운 것으로 보입니다.',
#  '서울 중앙에 위치해 있고 주소는 서울 중구 85530입니다.',
#  '다른 궁금하신 사항이 있으신가요?',
#  '아뇨 감사합니다.',
#  '네 문의 감사합니다.',
#  '좋은 여행 되세요.',
#  '서울 아무데나 좋으니까 적당한 가격대의 베이커리 맛있는 데 좀 찾아주세요.',
#  '확인됩니다.',
#  '고속터미널역의 단팥빵 맛집 사차원주머니입니다.',
#  '예약 필요하세요?',
#  '수요일 3시에 2명 갈거거든요.',
#  '아 이번엔 서울 중앙에 볼만한 랜드마크도 찾아주세요.',
#  '네 서울 시청 확인됩니다.',
#  '을지로입구역에서 도보 가능하네요.',
#  '그럼 거기 을지로입구역에서 아까 식당에 지하철타고 갈라고 하는데요.',
#  '어떻게 타면 돼요?',
#  '네 중간에 을지로3가역에서 3호선으로 갈아타시면 3호선 라인인 고속터미널역에 도착합니다.',
#  '음 아뇨 없어요.',
#  '서울 동쪽에 있는 비싼 호텔을 보고 있습니다.',
#  '서울 송파구에 있는 그레이 호텔은 어려울까요?',
#  '5점으로 확인됩니다.',
#  '아 그러면 여기로 수요일부터 4일간 5명으로 예약 부탁드립니다.',
#  '바로 예약 할게요.',
#  '혹시 가까운 지하철역이 어떻게 되나요?',
#  '가까운 지하철역은 잠실역으로 확인됩니다.',
#  '저 그리고 서울 중앙에 있는 저렴한 한식당을 방문하려고 하는데요.',
#  '아 네네.',
#  '잠시만 기다려주세요.',
#  '괜찮네요.',
#  '여기로 화요일에 20시15분으로 예약 좀 해주세요.',
#  '5명이 방문 예정입니다.',
#  '바로 예약 도와드리겠습니다.',
#  '가까운 지하철역은 안국역으로 확인됩니다.',
#  '저 그리고 잠실역에서 안국역으로 가는 지하철을 보고 있습니다.',
#  '혹시 소요시간이 어떻게 되나요?',
#  '확인해보니 소요시간은 30분으로 확인됩니다.',
#  '더 궁금한 점 있으신가요?',
#  '괜찮아요.',
#  '도움 주셔서 감사해요.',
#  '문의사항 있으시면 연락주세요.',
#  '이번에는 남산골 한옥 마을에 꼭 가보고 싶어서요.',
#  '여기 입장료랑 영업시간은 어떻게 되나요?',
#  '영업시간은 9시30분부터 17시30분으로 확인되며 입장료는 7천원입니다.',
#  '혹시 여기가 교육적인 곳으로 봐도 되나요?',
#  '교육적인 곳으로 보기 어려운 것 같습니다.',
#  '저 그리고 택시를 잡으려고 하는데요.',
#  '피에르오뎅에서 남산골 한옥 마을로 가는 경로고 3시에 도착해야 합니다.',
#  '혹시 출발 시간과 택시 종류는 어떻게 설정해드리면 될까요?',
#  '도착시간만 잘 맞추면 되서 출발 시간은 크게 신경쓰지 않아도 될 것 같아요.',
#  '그리고 택시 종류도 아무거나 타도 괜찮습니다.',
#  '저 예약 완료되면 그냥 기사님 전화번호만 좀 알려주세요.',
#  '바로 예약 도와드렸습니다.',
#  '기사님 번호는 02761430598입니다.',
#  '추가로 더 궁금한점 있으세요?',
#  '그럼 수고하세요.',
#  '종묘에서 탈거에요.',
#  '10분까지 도착해야해요.',
#  '출발 시간은 어떻게 되세요?',
#  '도착만 제때 하면되요.',
#  '상관 없습니다.',
#  '10분에 출발하는 택시를 안내드립니다.',
#  '120분 소요되네요.',
#  '택시 전화번호좀 알려주시겠어요?',
#  '전화번호는 01298507346입니다.',
#  '괜찮은 호텔로 추천해주세요.',
#  '가야 호텔 어떠세요?',
#  ...]

# %%
h = open("/opt/ml/input/data/bert_dataset/"+ 'WOS_dataset' +'.txt', 'w') #file_name[1].split('_')[0]
for ele in g:
    h.write(ele+'\n')
h.close()

# %% [markdown]
# ### ✅ 사용한 데이터셋들
# KETI, output, speech, tweeter dataset, WOS dataset
#
# 총 837914개 중복되지 않은 3글자이상의 데이터

# %%
#여러분이 사용하실 적절한 데이터셋을 불러오셔야합니다 !
from glob import glob
import random
import pandas as pd
random.seed(42)
def korean_data_loader(urls):
    ret = []
    for url in urls:
        df = pd.read_csv(url, header=None)
        for sent in df[0].values:
            ret.append(sent)
        ret.append('$$$')
    return ret

def train_dev_split(data):
    train, dev = [], []
    ret = []
    for sent in data:
        ret.append(sent + ' \n')
        if sent == '$$$':
            random.shuffle(ret)
            train += ret + ['\n']
            dev += ret[:len(ret)//10] + ['\n']
            ret = []
    return train[:-1], dev[:-1]

urls = glob('/opt/ml/input/data/bert_dataset/*.txt')
dataset = korean_data_loader(urls)
train_data, dev_data = train_dev_split(dataset)

# with open('/opt/ml/input/data/bert_dataset/preprocessed/train_data.pickle', 'wb') as f:
#     pickle.dump(train_data, f, pickle.HIGHEST_PROTOCOL)
# with open('/opt/ml/input/data/bert_dataset/preprocessed/dev_data.pickle', 'wb') as f:
#     pickle.dump(dev_data, f, pickle.HIGHEST_PROTOCOL)
# with open('/opt/ml/input/data/bert_dataset/preprocessed/train_data.txt', 'w') as f:
#     for i, ele in enumerate(train_data):
#         if ele == '\n':
#         f.write(ele)
with open('/opt/ml/input/data/bert_dataset/preprocessed/dev_data.txt', 'w') as f:
    for i,ele in enumerate(dev_data):
        if ele == '\n':
            print(i)
        f.write(ele)
with open('/opt/ml/input/data/bert_dataset/preprocessed/train_data.txt', 'w') as f:
    for i,ele in enumerate(train_data):
        if ele == '\n':
            print(i)
        f.write(ele)
print(len(dev_data))
print(len(train_data))
# Out:
# 323
# 2226
# 14282
# 81336
# 3237
# 22267
# 142823
# 813359
# 83961
# 839608

# %%
######### dataset 추가
train_data_file = "/opt/ml/input/data/bert_dataset/preprocessed/train_data.txt"
dev_data_file = "/opt/ml/input/data/bert_dataset/preprocessed/dev_data.txt"

# %% [markdown]
# ## Pretraining Dataset
#
# Pretraining을 위한 Dataset을 정의합니다.
#
# 1. 본 데이터셋은 Document 데이터셋을 기준으로 정의되어 있습니다. (각 문장 사이는 \n으로, document 사이는 \n\n으로 구분되어 있습니다) 해당 데이터셋 클래스를 구한 데이터셋에 맞춰 변경해주세요.
#     👉🏻 예시 : `data = ['sentence1 \n', 'sentence2 \n', 'setence3 \n' ,'\n' , 'sentence4 \n', 'sentence5 \n', 'sentence6 \n', '\n' ....]`
#
#
# 2. 현재 데이터셋은 Next Sentence Prediction을 위한 전처리 과정도 포함되어 있습니다. MLM만을 이용하여 pretraining을 진행할 경우 해당 부분을 제거하고 사용하시면 됩니다.

# %%
class TextDatasetForNextSentencePrediction(Dataset):
    def __init__(
        self,
        tokenizer,
        file_path,
        block_size,
        overwrite_cache=False,
        short_seq_probability=0.1,
        nsp_probability=0.5,
    ):
        assert os.path.isfile(file_path), f"Input file path {file_path} not found"

        self.block_size = block_size - tokenizer.num_special_tokens_to_add(pair=True)
        self.short_seq_probability = short_seq_probability
        self.nsp_probability = nsp_probability

        directory, filename = os.path.split(file_path)
        cached_features_file = os.path.join(
            directory,
            "cached_nsp_{}_{}_{}".format(
                tokenizer.__class__.__name__,
                str(block_size),
                filename,
            ),
        )

        self.tokenizer = tokenizer

        lock_path = cached_features_file + ".lock"

        # Input file format:
        # (1) One sentence per line. These should ideally be actual sentences, not
        # entire paragraphs or arbitrary spans of text. (Because we use the
        # sentence boundaries for the "next sentence prediction" task).
        # (2) Blank lines between documents. Document boundaries are needed so
        # that the "next sentence prediction" task doesn't span between documents.
        #
        # Example:
        # I am very happy.
        # Here is the second sentence.
        #
        # A new document.
        
        
        # ✅ 캐시 형태로 파일을 저장합니다 
        with FileLock(lock_path):
            print('캐시 형태로 파일을 저장합니다')
            if os.path.exists(cached_features_file) and not overwrite_cache:
                start = time.time()
                with open(cached_features_file, "rb") as handle:
                    self.examples = pickle.load(handle)
                logger.info(
                    f"Loading features from cached file {cached_features_file} [took %.3f s]",
                    time.time() - start,
                )
            else:
                print(f"Creating features from dataset file at {directory}")
                logger.info(f"Creating features from dataset file at {directory}")
                # Make dataset
                self.documents = [[]]

                # ✅ 기존 코드엔 progress bar가 없어서 추가하였습니다 : 공식코드는 TQDM이 없음 -> pbar로 걸어주자
                cnt = 0
                count_data = len(open(file_path, "r", errors="ignore").readlines())

                pbar = tqdm(total=count_data)
                with open(file_path, encoding="utf-8") as f:
                    while True:  
                        line = f.readline()
                        if not line:
                            break
                        line = line.strip()
                        if not line and len(self.documents[-1]) != 0:
                            self.documents.append([])
                        tokens = tokenizer.tokenize(line)
                        tokens = tokenizer.convert_tokens_to_ids(tokens)
                        if tokens:
                            self.documents[-1].append(tokens)
                        pbar.update(1)
                pbar.close()

                logger.info(f"Creating examples from {len(self.documents)} documents.")
                print("document length : ", len(self.documents))
                self.examples = []

                for doc_index, document in enumerate(tqdm(self.documents)):
                    self.create_examples_from_document(document, doc_index)  

                start = time.time()
                with open(cached_features_file, "wb") as handle:
                    pickle.dump(self.examples, handle, protocol=pickle.HIGHEST_PROTOCOL)
                logger.info(
                    "Saving features into cached file %s [took %.3f s]",
                    cached_features_file,
                    time.time() - start,
                )

    def create_examples_from_document(self, document, doc_index):
        """Creates examples for a single document."""
        max_num_tokens = self.block_size - self.tokenizer.num_special_tokens_to_add(
            pair=True
        )

        # We *usually* want to fill up the entire sequence since we are padding
        # to `block_size` anyways, so short sequences are generally wasted
        # computation. However, we *sometimes*
        # (i.e., short_seq_prob == 0.1 == 10% of the time) want to use shorter
        # sequences to minimize the mismatch between pretraining and fine-tuning.
        # The `target_seq_length` is just a rough target however, whereas
        # `block_size` is a hard limit.

        target_seq_length = max_num_tokens
        if random.random() < self.short_seq_probability:
            target_seq_length = random.randint(2, max_num_tokens)

        current_chunk = []  # a buffer stored current working segments
        current_length = 0
        i = 0
        
        # ✅ NSP를 위한 Preprocessing : NSP가 필요없다면, 이 부분을 제외해주세요 
        while i < len(document):
            segment = document[i]
            current_chunk.append(segment)
            current_length += len(segment)
            if i == len(document) - 1 or current_length >= target_seq_length:
                if current_chunk:
                    # `a_end` is how many segments from `current_chunk` go into the `A`
                    # (first) sentence.
                    a_end = 1
                    if len(current_chunk) >= 2:
                        a_end = random.randint(1, len(current_chunk) - 1)
                    tokens_a = []
                    for j in range(a_end):
                        tokens_a.extend(current_chunk[j])
                    tokens_b = []
                    if (
                        len(current_chunk) == 1
                        or random.random() < self.nsp_probability
                    ):
                        is_random_next = True
                        target_b_length = target_seq_length - len(tokens_a)

                        # This should rarely go for more than one iteration for large
                        # corpora. However, just to be careful, we try to make sure that
                        # the random document is not the same as the document
                        # we're processing.
                        for _ in range(10):
                            random_document_index = random.randint(
                                0, len(self.documents) - 1
                            )
                            if random_document_index != doc_index:
                                break
                        random_document = self.documents[random_document_index]
                        random_start = random.randint(0, len(random_document) - 1)
                        for j in range(random_start, len(random_document)):
                            tokens_b.extend(random_document[j])
                            if len(tokens_b) >= target_b_length:
                                break
                        # We didn't actually use these segments so we "put them back" so
                        # they don't go to waste.
                        num_unused_segments = len(current_chunk) - a_end
                        i -= num_unused_segments
                    else:
                        is_random_next = False
                        for j in range(a_end, len(current_chunk)):
                            tokens_b.extend(current_chunk[j])

                    def truncate_seq_pair(tokens_a, tokens_b, max_num_tokens):
                        """Truncates a pair of sequences to a maximum sequence length."""
                        while True:
                            total_length = len(tokens_a) + len(tokens_b)
                            if total_length <= max_num_tokens:
                                break
                            trunc_tokens = (
                                tokens_a if len(tokens_a) > len(tokens_b) else tokens_b
                            )
                            assert len(trunc_tokens) >= 1
                            # We want to sometimes truncate from the front and sometimes from the
                            # back to add more randomness and avoid biases.
                            if random.random() < 0.5:
                                del trunc_tokens[0]
                            else:
                                trunc_tokens.pop()

                    truncate_seq_pair(tokens_a, tokens_b, max_num_tokens)

                    assert len(tokens_a) >= 1
                    assert len(tokens_b) >= 1

                    # add special tokens
                    input_ids = self.tokenizer.build_inputs_with_special_tokens(
                        tokens_a, tokens_b
                    )
                    # add token type ids, 0 for sentence a, 1 for sentence b
                    token_type_ids = (
                        self.tokenizer.create_token_type_ids_from_sequences(
                            tokens_a, tokens_b
                        )
                    )
                    
                    # ✅ 데이터가 저장되는 형태     
                    example = {
                        "input_ids": torch.tensor(input_ids, dtype=torch.long),
                        "token_type_ids": torch.tensor(
                            token_type_ids, dtype=torch.long
                        ),
                        "next_sentence_label": torch.tensor(
                            1 if is_random_next else 0, dtype=torch.long
                        ),
                    }

                    # ✅ 주의 : 이렇게 append 하는 방식은 대용량 corpus에서 메모리 이슈를 불러올 수 있습니다 ! 
                    self.examples.append(example)

                current_chunk = []
                current_length = 0

            i += 1

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, i):
        return self.examples[i]

# %% [markdown]
# ## Dataset

# %%
tokenizer = BertTokenizer.from_pretrained('kykim/bert-kor-base')

# for dataset
train_dataset = TextDatasetForNextSentencePrediction(
    tokenizer=tokenizer,
    file_path=train_data_file,
    block_size=256,
    overwrite_cache=False,
    short_seq_probability=0.1,
    nsp_probability=0.5,
)

dev_dataset = TextDatasetForNextSentencePrediction(
    tokenizer=tokenizer,
    file_path=dev_data_file,
    block_size=256,
    overwrite_cache=False,
    short_seq_probability=0.1,
    nsp_probability=0.5,
)
# Out:
# 캐시 형태로 파일을 저장합니다
# 캐시 형태로 파일을 저장합니다

# %%
print(len(train_dataset))
print(len(dev_dataset))
# Out:
# 35434
# 3549

# %%
tokenizer.decode(train_dataset[0].get('input_ids'))
# Out:
# '[CLS] 911 입니다. [SEP] 군인 한 명이 황소를 잡으려다 다리 안쪽을 심하게 찔렸어요. 지금 숨쉬기를 너무 힘들어 하세요. 악어가 사람을 물었어요. 옷도 지저분한 사람이 서울 방향을 물었어요. 배수로 작업 중에 기 차가 들어와 작업인부를 쳤습니다. 5살이요. 서빙고 초등학교 뒤쪽이요. 시체를 발견하셨다고요? 조금만 기 다려주세요. 2 cu 매장이요. 윗집에서 이상한 냄새가 나요. 어떤 사람이 절 죽이려고 해요. 강도가 몇 명이였나요? 버스에 노인 2명이 치였거든요? 트럭이 사람들을 향해 돌진하고 있어요. 혹시 나이가 어떻게 되세요? 10년 전에 납치가 되셨다고 하셨죠? 지금 남성은 어디로 갔나요? 어떻게 유출이 됬나요? 어떻게 당하셨나요? 연기 때문에 앞을 볼 수가 없어요. 지금 119 출동했습니다. 검은색 옷을 입은 남자가 떠 있는 것을 발견했어요. 사고난 위치 좀 알수 있을까요? 국민은행 위치가 어디신데요? 목을 심하게 다치신 것 같아요. 현장 실습 중이던 학생이 떨어졌어요. 사람을 치었거든요. 임산부 한 명이 크레인에 깔렸어요. mt 게임을 하다가 초코파이가 목에 막혀서 쓰러졌어요. 어떻게 올라가고 있나요? 집에서 친구가 자살을 했어요. 배가 침몰하고 있어요. 네 집 안에서 보고 있습니다. 어디로 보내면 될까요? [SEP]'

# %% [markdown]
# # Pretraining Model

# %% [markdown]
# ## 모델 및 데이터 Collator 정의

# %%
config = BertConfig.from_pretrained('kykim/bert-kor-base')
config.model_name_or_path = 'kykim/bert-kor-base'
##gaet == 5 
config.n_gate = 5
config.proj_dim = None

model = BertForPreTraining(config=config)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ✅ [MASK] 과정은 Huggingface collator 따름
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)

# %% [markdown]
# ## Trainer 정의

# %%
n_epochs = 10

training_args = TrainingArguments(
    output_dir='./checkpoints',
    learning_rate=4e-4,
    overwrite_output_dir=True,
    num_train_epochs=n_epochs,
    per_gpu_train_batch_size=30, # 서버에 맞게 설정
    save_steps=2000,
    save_total_limit=10, # 메모리 생각해서 알아서 조절 !
    logging_steps=2000,
    load_best_model_at_end=True,
    evaluation_strategy="epoch",  # `epoch`: Evaluate every end of epoch. / mlm평가는 loss로 하는게 편함 
)

early_stopping = EarlyStoppingCallback(
    early_stopping_patience=20, early_stopping_threshold=0.0001
)
trainer = Trainer(
    callbacks=[early_stopping], # callback사용을 위해 필요한 argument
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=dev_dataset,
)

# %% [markdown]
# ## Pretraining

# %%
trainer.train()

trainer.save_model("./checkpoints/final_bert_model")
# Out:
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# wandb: Currently logged in as: bongjinkim (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.30<br/>
#                 Syncing run <strong style="color:#cdcd00">./checkpoints</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/bongjinkim/huggingface" target="_blank">https://wandb.ai/bongjinkim/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/bongjinkim/huggingface/runs/3jmj7pxs" target="_blank">https://wandb.ai/bongjinkim/huggingface/runs/3jmj7pxs</a><br/>
#                 Run data is saved locally in <code>/opt/ml/code/wandb/run-20210517_084659-3jmj7pxs</code><br/><br/>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='11820' max='11820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11820/11820 2:22:41, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>8.242788</td>
#       <td>24.624900</td>
#       <td>144.122000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8.288700</td>
#       <td>8.231514</td>
#       <td>24.359300</td>
#       <td>145.694000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.288700</td>
#       <td>8.220776</td>
#       <td>24.343600</td>
#       <td>145.788000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.230100</td>
#       <td>8.206586</td>
#       <td>24.138000</td>
#       <td>147.030000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8.230100</td>
#       <td>8.249760</td>
#       <td>24.178700</td>
#       <td>146.782000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8.220600</td>
#       <td>8.214318</td>
#       <td>24.184700</td>
#       <td>146.745000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>8.212600</td>
#       <td>8.219191</td>
#       <td>24.141100</td>
#       <td>147.011000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>8.212600</td>
#       <td>8.204929</td>
#       <td>24.154300</td>
#       <td>146.931000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>8.207200</td>
#       <td>8.219840</td>
#       <td>24.028600</td>
#       <td>147.699000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>8.207200</td>
#       <td>8.200818</td>
#       <td>24.162300</td>
#       <td>146.882000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
glob('/opt/ml/code/checkpoints/final_bert_model/*')
# Out:
# ['/opt/ml/code/checkpoints/final_bert_model/training_args.bin',
#  '/opt/ml/code/checkpoints/final_bert_model/config.json',
#  '/opt/ml/code/checkpoints/final_bert_model/pytorch_model.bin']

# %%
#config 확인
with open('/opt/ml/code/checkpoints/final_bert_model/config.json') as f:
    conf = json.load(f)
conf
# Out:
# {'_name_or_path': './checkpoints/checkpoint-11820',
#  'architectures': ['BertForPreTraining'],
#  'attention_probs_dropout_prob': 0.1,
#  'directionality': 'bidi',
#  'embedding_size': 768,
#  'gradient_checkpointing': False,
#  'hidden_act': 'gelu',
#  'hidden_dropout_prob': 0.1,
#  'hidden_size': 768,
#  'initializer_range': 0.02,
#  'intermediate_size': 3072,
#  'layer_norm_eps': 1e-12,
#  'max_position_embeddings': 512,
#  'model_name_or_path': 'kykim/bert-kor-base',
#  'model_type': 'bert',
#  'n_gate': 5,
#  'num_attention_heads': 12,
#  'num_hidden_layers': 12,
#  'pad_token_id': 0,
#  'pooler_fc_size': 768,
#  'pooler_num_attention_heads': 12,
#  'pooler_num_fc_layers': 3,
#  'pooler_size_per_head': 128,
#  'pooler_type': 'first_token_transform',
#  'position_embedding_type': 'absolute',
#  'proj_dim': None,
#  'transformers_version': '4.5.1',
#  'type_vocab_size': 2,
#  'use_cache': True,
#  'vocab_size': 42000}

# %%
# !mv /opt/ml/code/checkpoints/final_bert_model/* /opt/ml/code/dst_kor_bert

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("BonjinKim/dst_kor_bert")
model = AutoModel.from_pretrained("BonjinKim/dst_kor_bert")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=919.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=344259.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=475823670.0, style=ProgressStyle(descri…

# %%
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-884bfde4dfd2> in <module>
# ----> 1 tokenizer("안녕하세요 반갑습니다")
#
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils_base.py in __call__(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2290                 return_length=return_length,
#    2291                 verbose=verbose,
# -> 2292                 **kwargs,
#    2293             )
#    2294
#
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils_base.py in encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2360             return_length=return_length,
#    2361             verbose=verbose,
# -> 2362             **kwargs,
#    2363         )
#    2364
#
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils_fast.py in _encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     473             return_length=return_length,
#     474             verbose=verbose,
# --> 475             **kwargs,
#     476         )
#     477
#
# /opt/conda/lib/python3.7/site-packages/transformers/tokenization_utils_fast.py in _batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     386             batch_text_or_text_pairs,
#     387             add_special_tokens=add_special_tokens,
# --> 388             is_pretokenized=is_split_into_words,
#     389         )
#     390
#
# Exception: WordPiece error: Missing [UNK] token from the vocabulary
