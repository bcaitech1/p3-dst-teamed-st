# %%
cd somdst/son-dst3/
# Out:
# /opt/ml/somdst/son-dst3

# %%
# !nvidia-smi
# Out:
# Wed May 19 07:03:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-PCIE...  On   | 00000000:00:05.0 Off |                  Off |
# | N/A   40C    P0    71W / 250W |   2762MiB / 32480MiB |     39%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !python train_somdst.py --model_name_or_path BonjinKim/dst_kor_bert
# Out:
# 2021-05-19 11:22:57.318807: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-19 11:22:57.318851: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /opt/ml/somdst/son-dst3
# wandb: Currently logged in as: bongjinkim (use `wandb login --relogin` to force relogin)
# 2021-05-19 11:23:00.680145: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-19 11:23:00.680191: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.10.30
# wandb: Syncing run absurd-water-66
# wandb: ⭐️ View project at https://wandb.ai/bongjinkim/Stage2-DST
# wandb: 🚀 View run at https://wandb.ai/bongjinkim/Stage2-DST/runs/27n53cfz
# wandb: Run data is saved locally in /opt/ml/somdst/son-dst3/wandb/run-20210519_112259-27n53cfz
# wandb: Run `wandb offline` to turn off syncing.
#
# dst_kor_bert
# /opt/ml/result/SOMDST_whole12
# wandb: WARNING Calling run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# 6895
# 105
# 100%|█████████████████████████████████████| 6895/6895 [00:00<00:00, 9206.51it/s]
#   0%|                                                   | 0/105 [00:00<?, ?it/s]50498
# 747
# 100%|██████████████████████████████████████| 105/105 [00:00<00:00, 14073.95it/s]
# Cached Input Features not Found.
# Load data and save.
# Save Data
# Model is initialized
# # train: 50498
# # dev: 747
# [1/50] [0/3157] mean_loss : 14.859, state_loss : 11.410, gen_loss : 1.599, dom_loss : 1.851
# [1/50] [50/3157] mean_loss : 14.811, state_loss : 11.343, gen_loss : 1.571, dom_loss : 1.893
# [1/50] [100/3157] mean_loss : 14.776, state_loss : 11.298, gen_loss : 1.564, dom_loss : 1.839
# [1/50] [150/3157] mean_loss : 14.683, state_loss : 11.272, gen_loss : 1.530, dom_loss : 1.784
# [1/50] [200/3157] mean_loss : 14.591, state_loss : 11.189, gen_loss : 1.500, dom_loss : 1.851
# [1/50] [250/3157] mean_loss : 14.413, state_loss : 11.111, gen_loss : 1.428, dom_loss : 1.716
# [1/50] [300/3157] mean_loss : 14.193, state_loss : 10.999, gen_loss : 1.341, dom_loss : 1.662
# [1/50] [350/3157] mean_loss : 13.953, state_loss : 10.908, gen_loss : 1.247, dom_loss : 1.718
# [1/50] [400/3157] mean_loss : 13.665, state_loss : 10.683, gen_loss : 1.156, dom_loss : 1.620
# [1/50] [450/3157] mean_loss : 13.380, state_loss : 10.502, gen_loss : 1.038, dom_loss : 1.477
# [1/50] [500/3157] mean_loss : 13.054, state_loss : 10.300, gen_loss : 0.901, dom_loss : 1.565
# [1/50] [550/3157] mean_loss : 12.702, state_loss : 10.378, gen_loss : 0.798, dom_loss : 1.506
# [1/50] [600/3157] mean_loss : 12.374, state_loss : 9.970, gen_loss : 0.669, dom_loss : 1.608
# [1/50] [650/3157] mean_loss : 11.989, state_loss : 9.628, gen_loss : 0.603, dom_loss : 1.395
# [1/50] [2100/3157] mean_loss : 5.618, state_loss : 4.392, gen_loss : 0.166, dom_loss : 1.538
# [1/50] [2150/3157] mean_loss : 5.598, state_loss : 4.025, gen_loss : 0.163, dom_loss : 1.472
# [1/50] [2200/3157] mean_loss : 5.406, state_loss : 3.811, gen_loss : 0.140, dom_loss : 1.358
# [1/50] [2250/3157] mean_loss : 5.491, state_loss : 3.497, gen_loss : 0.156, dom_loss : 1.503
# [1/50] [2300/3157] mean_loss : 5.462, state_loss : 3.368, gen_loss : 0.184, dom_loss : 1.419
# [1/50] [2350/3157] mean_loss : 5.397, state_loss : 3.941, gen_loss : 0.114, dom_loss : 1.413
# [1/50] [2400/3157] mean_loss : 5.419, state_loss : 3.525, gen_loss : 0.125, dom_loss : 1.401
# [1/50] [2450/3157] mean_loss : 5.242, state_loss : 3.696, gen_loss : 0.147, dom_loss : 1.427
# [1/50] [2500/3157] mean_loss : 5.319, state_loss : 3.723, gen_loss : 0.177, dom_loss : 1.563
# [1/50] [2550/3157] mean_loss : 5.381, state_loss : 3.333, gen_loss : 0.142, dom_loss : 1.408
# [1/50] [2600/3157] mean_loss : 5.323, state_loss : 3.735, gen_loss : 0.142, dom_loss : 1.438
# [1/50] [2650/3157] mean_loss : 5.202, state_loss : 4.064, gen_loss : 0.200, dom_loss : 1.412
# [1/50] [2700/3157] mean_loss : 5.132, state_loss : 4.259, gen_loss : 0.152, dom_loss : 1.469
# [1/50] [2750/3157] mean_loss : 5.285, state_loss : 3.954, gen_loss : 0.151, dom_loss : 1.378
# [1/50] [2800/3157] mean_loss : 5.151, state_loss : 3.237, gen_loss : 0.167, dom_loss : 1.445
# [1/50] [2850/3157] mean_loss : 5.158, state_loss : 4.157, gen_loss : 0.129, dom_loss : 1.603
# [1/50] [2900/3157] mean_loss : 5.043, state_loss : 2.846, gen_loss : 0.192, dom_loss : 1.299
# [1/50] [2950/3157] mean_loss : 5.208, state_loss : 3.124, gen_loss : 0.165, dom_loss : 1.428
# [1/50] [3000/3157] mean_loss : 5.034, state_loss : 3.621, gen_loss : 0.193, dom_loss : 1.628
# [1/50] [3050/3157] mean_loss : 5.149, state_loss : 3.196, gen_loss : 0.132, dom_loss : 1.422
# [1/50] [3100/3157] mean_loss : 5.051, state_loss : 3.518, gen_loss : 0.090, dom_loss : 1.686
# [1/50] [3150/3157] mean_loss : 5.127, state_loss : 2.506, gen_loss : 0.163, dom_loss : 1.531
# 100%|█████████████████████████████████████████| 747/747 [00:10<00:00, 72.95it/s]
# {'joint_goal_accuracy': 0.0214190093708166, 'turn_slot_accuracy': 0.8249590956418229, 'turn_slot_f1': 0.0214190093708166}
# joint_goal_accuracy: 0.0214190093708166
# turn_slot_accuracy: 0.8249590956418229
# turn_slot_f1: 0.0214190093708166
# Update Best checkpoint!
# [2/50] [0/3157] mean_loss : 4.456, state_loss : 2.812, gen_loss : 0.178, dom_loss : 1.465
# [2/50] [50/3157] mean_loss : 4.935, state_loss : 3.548, gen_loss : 0.145, dom_loss : 1.526
# [2/50] [100/3157] mean_loss : 4.982, state_loss : 2.636, gen_loss : 0.181, dom_loss : 1.303
# [2/50] [150/3157] mean_loss : 5.087, state_loss : 3.846, gen_loss : 0.134, dom_loss : 1.878
# [2/50] [200/3157] mean_loss : 5.002, state_loss : 3.551, gen_loss : 0.140, dom_loss : 1.444
# [2/50] [250/3157] mean_loss : 4.971, state_loss : 3.550, gen_loss : 0.168, dom_loss : 1.495
# [2/50] [300/3157] mean_loss : 5.029, state_loss : 4.388, gen_loss : 0.137, dom_loss : 1.649
# [2/50] [350/3157] mean_loss : 5.054, state_loss : 3.954, gen_loss : 0.163, dom_loss : 1.407
# [2/50] [400/3157] mean_loss : 5.011, state_loss : 3.426, gen_loss : 0.192, dom_loss : 1.420
# [2/50] [450/3157] mean_loss : 4.943, state_loss : 3.432, gen_loss : 0.172, dom_loss : 1.358
# [2/50] [500/3157] mean_loss : 5.027, state_loss : 3.370, gen_loss : 0.189, dom_loss : 1.435
# [2/50] [550/3157] mean_loss : 4.892, state_loss : 3.040, gen_loss : 0.160, dom_loss : 1.393
# [2/50] [600/3157] mean_loss : 4.880, state_loss : 2.650, gen_loss : 0.147, dom_loss : 1.481
# [2/50] [650/3157] mean_loss : 4.941, state_loss : 3.865, gen_loss : 0.126, dom_loss : 1.660
# [2/50] [700/3157] mean_loss : 5.011, state_loss : 3.073, gen_loss : 0.179, dom_loss : 1.363
# ^C
# Traceback (most recent call last):
#   File "train_somdst.py", line 256, in <module>
#     teacher=tf,
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/ml/somdst/son-dst3/models/som_dst/modeling_som_dst.py", line 55, in forward
#     teacher,
#   File "/opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/ml/somdst/son-dst3/models/som_dst/modeling_som_dst.py", line 299, in forward
#     slot_value.append([ww.tolist() for ww in w_idx])
#   File "/opt/ml/somdst/son-dst3/models/som_dst/modeling_som_dst.py", line 299, in <listcomp>
#     slot_value.append([ww.tolist() for ww in w_idx])
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# /opt/conda/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# /opt/conda/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# /opt/conda/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# /opt/conda/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# /opt/conda/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-fa0d3b30600d> in <module>
# ----> 1 get_ipython().system('python train_somdst.py --model_name_or_path BonjinKim/dst_kor_bert')
#
# /opt/conda/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     645                 self.user_ns['_exit_code'] = system(cmd)
#     646         else:
# --> 647             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     648
#     649     # Ensure new system_piped implementation is used
#
# /opt/conda/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     184             finally:
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#     188         child.isalive()
#
# /opt/conda/lib/python3.7/site-packages/pexpect/pty_spawn.py in terminate(self, force)
#     640         try:
#     641             self.kill(signal.SIGHUP)
# --> 642             time.sleep(self.delayafterterminate)
#     643             if not self.isalive():
#     644                 return True
#
# KeyboardInterrupt:

# %%
# !python train_somdst.py --model_name_or_path dsksd/bert-ko-small-minimal --model_dir /opt/ml/model --learning_rate 0.000009 --model_name coco_dst --ckpt 41
# Out:
# 2021-05-20 08:07:33.641573: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-20 08:07:33.641628: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /opt/ml/somdst/son-dst3
# wandb: Currently logged in as: bongjinkim (use `wandb login --relogin` to force relogin)
# 2021-05-20 08:07:37.134353: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-20 08:07:37.134475: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#
# CondaEnvException: Unable to determine environment
#
# Please re-run this command with one of the following options:
#
# * Provide an environment name via --name or -n
# * Re-run this command inside an activated conda environment.
#
# wandb: Tracking run with wandb version 0.10.30
# wandb: Syncing run trim-pond-84
# wandb: ⭐️ View project at https://wandb.ai/bongjinkim/Stage2-DST
# wandb: 🚀 View run at https://wandb.ai/bongjinkim/Stage2-DST/runs/172qxlqq
# wandb: Run data is saved locally in /opt/ml/somdst/son-dst3/wandb/run-20210520_080735-172qxlqq
# wandb: Run `wandb offline` to turn off syncing.
#
# bert
# /opt/ml/model/coco_dst
# wandb: WARNING Calling run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# 12601
# 1399
# 100%|███████████████████████████████████| 12601/12601 [00:01<00:00, 8069.40it/s]
#   0%|                                                  | 0/1399 [00:00<?, ?it/s]92409
# 10081
# 100%|████████████████████████████████████| 1399/1399 [00:00<00:00, 15288.85it/s]
# Cached Input Features not Found.
# Load data and save.
# Save Data
# Checkpoint Load
# Model is initialized
# # train: 92409
# # dev: 10081
# [1/50] [0/5776] mean_loss : 0.045, state_loss : 0.004, gen_loss : 0.042, dom_loss : 0.000
# [1/50] [50/5776] mean_loss : 0.381, state_loss : 1.299, gen_loss : 0.054, dom_loss : 0.000
# [1/50] [100/5776] mean_loss : 0.344, state_loss : 0.000, gen_loss : 0.005, dom_loss : 0.000
# [1/50] [150/5776] mean_loss : 0.325, state_loss : 0.280, gen_loss : 0.015, dom_loss : 0.000
# [1/50] [200/5776] mean_loss : 0.455, state_loss : 0.231, gen_loss : 0.001, dom_loss : 0.000
# [1/50] [250/5776] mean_loss : 0.315, state_loss : 1.580, gen_loss : 0.012, dom_loss : 0.000
# [1/50] [300/5776] mean_loss : 0.273, state_loss : 0.014, gen_loss : 0.024, dom_loss : 0.000
# [1/50] [350/5776] mean_loss : 0.306, state_loss : 0.637, gen_loss : 0.020, dom_loss : 0.000
# [1/50] [400/5776] mean_loss : 0.187, state_loss : 0.405, gen_loss : 0.005, dom_loss : 0.000
# [1/50] [450/5776] mean_loss : 0.177, state_loss : 0.000, gen_loss : 0.029, dom_loss : 0.000
# [1/50] [500/5776] mean_loss : 0.216, state_loss : 0.000, gen_loss : 0.011, dom_loss : 0.000
# [1/50] [550/5776] mean_loss : 0.254, state_loss : 0.679, gen_loss : 0.002, dom_loss : 0.000
# [1/50] [600/5776] mean_loss : 0.127, state_loss : 0.000, gen_loss : 0.013, dom_loss : 0.000
# [1/50] [650/5776] mean_loss : 0.324, state_loss : 1.193, gen_loss : 0.000, dom_loss : 0.000
# [1/50]
gen_loss : 0.001, dom_loss : 0.000
# [3/50] [4900/5776] mean_loss : 0.060, state_loss : 0.002, gen_loss : 0.000, dom_loss : 0.000
# [3/50] [4950/5776] mean_loss : 0.066, state_loss : 0.233, gen_loss : 0.000, dom_loss : 0.000
# [3/50] [5000/5776] mean_loss : 0.105, state_loss : 0.098, gen_loss : 0.001, dom_loss : 0.006
# [3/50] [5050/5776] mean_loss : 0.108, state_loss : 0.275, gen_loss : 0.010, dom_loss : 0.000
# [3/50] [5100/5776] mean_loss : 0.081, state_loss : 0.116, gen_loss : 0.018, dom_loss : 0.000
# [3/50] [5150/5776] mean_loss : 0.089, state_loss : 0.064, gen_loss : 0.004, dom_loss : 0.000
# [3/50] [5200/5776] mean_loss : 0.052, state_loss : 0.001, gen_loss : 0.002, dom_loss : 0.000
# [3/50] [5250/5776] mean_loss : 0.095, state_loss : 0.003, gen_loss : 0.000, dom_loss : 0.000
# [3/50] [5300/5776] mean_loss : 0.045, state_loss : 0.001, gen_loss : 0.001, dom_loss : 0.000
# [3/50] [5350/5776] mean_loss : 0.047, state_loss : 0.002, gen_loss : 0.001, dom_loss : 0.000
# [3/50] [5400/5776] mean_loss : 0.071, state_loss : 0.001, gen_loss : 0.001, dom_loss : 0.000
# [3/50] [5450/5776] mean_loss : 0.088, state_loss : 0.001, gen_loss : 0.001, dom_loss : 0.000
# [3/50] [5500/5776] mean_loss : 0.056, state_loss : 0.001, gen_loss : 0.000, dom_loss : 0.000
# [3/50] [5550/5776] mean_loss : 0.062, state_loss : 0.042, gen_loss : 0.005, dom_loss : 0.011
# [3/50] [5600/5776] mean_loss : 0.047, state_loss : 0.003, gen_loss : 0.001, dom_loss : 0.000
# [3/50] [5650/5776] mean_loss : 0.067, state_loss : 0.036, gen_loss : 0.000, dom_loss : 0.000
# [3/50] [5700/5776] mean_loss : 0.090, state_loss : 0.003, gen_loss : 0.002, dom_loss : 0.000
# [3/50] [5750/5776] mean_loss : 0.099, state_loss : 0.001, gen_loss : 0.000, dom_loss : 0.000
# 100%|█████████████████████████████████████| 10081/10081 [05:06<00:00, 32.89it/s]
# {'joint_goal_accuracy': 0.8127169923618689, 'turn_slot_accuracy': 0.994405316932884, 'turn_slot_f1': 0.9717000296363195}
# joint_goal_accuracy: 0.8127169923618689
# turn_slot_accuracy: 0.994405316932884
# turn_slot_f1: 0.9717000296363195
# Update Best checkpoint!
# [4/50] [0/5776] mean_loss : 0.063, state_loss : 0.062, gen_loss : 0.001, dom_loss : 0.000

# %%
# !python train_trade.py
# Out:
# 2021-05-20 16:31:10.382376: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-20 16:31:10.382430: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "train_trade.py", line 77, in <module>
#     train_data, dev_data, dev_labels = load_dataset(train_data_file)
#   File "/opt/ml/somdst/son-dst3/data_utils.py", line 50, in load_dataset
#     data += json.load(open(d, 'rt', encoding='UTF8'))
# IsADirectoryError: [Errno 21] Is a directory: '/'

# %%
import os
os.path.exists(os.path.join("/opt/ml/input/data/train_dataset", f"train_somdst_features_bert.pkl"))
# Out:
# False

# %%
import json
a= json.load(open('/opt/ml/input/data/train_dataset/new_train.json'))
b=json.load(open('/opt/ml/input/data/train_dataset/train_dials.json'))

# %%
len(a)
# Out:
# 7000

# %%
type(b)
# Out:
# list

# %%
from difflib import SequenceMatcher
import json
from tqdm.notebook import tqdm
import nltk
from nltk.translate import bleu
from nltk.translate.bleu_score import SmoothingFunction
smoothie = SmoothingFunction().method4

def similar(a, b, only_bleu=False, with_bleu=False):
    sim = SequenceMatcher(None, a, b).ratio()
    if not only_bleu and not with_bleu:
        return sim
    bleu_score = bleu(a, b)
    if only_bleu:
        return bleu_score
    return (sim + bleu_score) / 2

with open("/opt/predictions/cleaning_1th.csv", "rb") as f:
    a = json.load(f)
cnt = 0
all_cnt = 0
for key, values in a.items():
    for i, value in enumerate(values):
        if "시간" in value:
            continue
        if ":" in value or "=" in value or "&" in value or "(" in value or ")" in value :
            print(f" before : {value}", end="\t")

        if "=" in value:
            a[key][i] = value.replace(" = ", "=")

        if "&" in value:
            a[key][i] = value.replace(" & ", "&")
        if "(" in value:
            value = value.replace("( ", "(")
            value = value.replace(" ) ", ")")
            value = value.replace(" )", ")")
            if value[-1] == "역":
                value = value.replace(" (", "(")
            a[key][i] = value
        if "동대문" in value and value[-1] == "(":
            value = "관광-이름-동대문 (흥인지문)"
            a[key][i] = value
        if "월드컵 경기장(" in value:
            a[key][i] = "관광-이름-서울 월드컵 경기장 (상암 월드컵 경기장)"
            
        if ":" in value or "=" in value or "&" in value or "(" in value or ")" in value:
            print(f" after : {a[key][i]}")
            cnt+=1
        
        all_cnt+=1
print(f"{cnt} / {all_cnt}")

json.dump(
    a,
    open(f"post-cleaning.csv", "w"),
    indent=2,
    ensure_ascii=False,
)



with open("post-cleaning.csv", "rb") as f:
    predctions = json.load(f)
with open("ontology.json", "rb") as f:
    ontology = json.load(f)

all_values = sorted(set(sum(ontology.values(), [])))
name_values = sorted(set(ontology['관광-이름'] + ontology['식당-이름'] + ontology['숙소-이름'] + ontology['택시-도착지'] + ontology['택시-출발지']))
a = ontology['관광-이름'].copy()
b = ontology['숙소-이름'].copy()
c = ontology['식당-이름'].copy()
ontology['관광-이름'] = [n for n in name_values if n not in b + c + ontology['지하철-도착지']]
ontology['숙소-이름'] = [n for n in name_values if n not in a + c + ontology['지하철-도착지']]
ontology['식당-이름'] = [n for n in name_values if n not in a + b + ontology['지하철-도착지']]


cnt = 0
for guid, states in tqdm(predctions.items()):
    flag = False
    for i, state in enumerate(states):
        dom, slot, value = state.split('-')
        domslot = f"{dom}-{slot}"
        if "시간" in slot:
            continue
        if value in all_values:
            continue
        if ('게스트' in value or '호텔' in value or '모텔' in value or '하우스' in value) and '그린' not in value:
            value = value.split(' ')[0]
        if domslot in ['택시-출발지', '택시-도착지']:
            values = all_values
        else:
            values = ontology[domslot]

        similarities = sorted([(v, similar(value, v, with_bleu=True)) for v in values] ,reverse=True, key=lambda x: x[1])
        print(domslot, value, "\t=>\t", similarities[:3])

        predctions[guid][i] = f"{domslot}-{similarities[0][0]}"
        flag = True
    if flag:
        cnt+=1
print(f"{cnt} / 14771")
json.dump(
    predctions,
    open(f"post-cleaning.csv", "w"),
    indent=2,
    ensure_ascii=False,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-f242e3dad76f> in <module>
#       1 import torch
# ----> 2 torch.load('/opt/ml/model/coco_dst/model-30.bin')
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     579         pickle_load_args['encoding'] = 'utf-8'
#     580
# --> 581     with _open_file_like(f, 'rb') as opened_file:
#     582         if _is_zipfile(opened_file):
#     583             # The zipfile reader is going to advance the current file position.
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/opt/ml/model/coco_dst/model-30.bin'
